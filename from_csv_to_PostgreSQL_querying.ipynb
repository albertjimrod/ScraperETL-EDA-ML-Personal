# %% [markdown]
# #  PostgreSQL_queryng (hispasonic 3)
#
# <br>
#
# ### This is the second part of hispasonic project.
#
# ![csv_postgre.png](csv_postgre.png)
#
#
# The aim to be achieved are:
#
# - Establish communication with postgreSQL through jupyter notebooks.
#
# - Create querys into the PostgreSQL database
#
# <br>

# %% [markdown]
# ### Do I have the PostgreSQL service working?
#
# I check it in the terminal:
#
#         (base) $systemctl status postgresql
#         ● postgresql.service - PostgreSQL RDBMS
#              Loaded: loaded (/lib/systemd/system/postgresql.service; enabled; vendor preset: enabled)
#              Active: active (exited) since Sat 2022-09-03 08:26:45 CEST; 7min ago
#             Main PID: 14429 (code=exited, status=0/SUCCESS)
#                Tasks: 0 (limit: 38321)
#              Memory: 0B
#              CGroup: /system.slice/postgresql.service
#
#         sep 03 08:26:45 R7 systemd[1]: Starting PostgreSQL RDBMS...
#         sep 03 08:26:45 R7 systemd[1]: Finished PostgreSQL RDBMS.
#
# yes!

# %%
import sys     #This module provides functions & variables to manipulate parts of Python runtime environment.
import pymysql # pure-Python MySQL client library. installed in env conda
import sqlalchemy 
from sqlalchemy import create_engine # establish connection database, using the create_engine() function of SQLAlchemy.

# %% [markdown]
# ### Accesing into mysql
#
# #### Establish a connection with your existing database, using the `create_engine()`function of `SQLAlchemy`.

# %%
# %load_ext sql

# %%
# %sql postgresql+psycopg2://jupyter:jjxx33pp@localhost/hispasonic
# Out:
# 'Connected: jupyter@hispasonic'

# %% [markdown]
# ### Do I have any databases installed?
#
# - connection established, so I can check which are the existing databases.

# %%
# %%sql
# \l
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 4 rows affected.
# [('hispasonic', 'postgres', 'UTF8', 'es_ES.UTF-8', 'es_ES.UTF-8', None),
#  ('postgres', 'postgres', 'UTF8', 'es_ES.UTF-8', 'es_ES.UTF-8', None),
#  ('template0',
#   'postgres',
#   'UTF8',
#   'es_ES.UTF-8',
#   'es_ES.UTF-8',
#   '=c/postgres\npostgres=CTc/postgres'),
#  ('template1',
#   'postgres',
#   'UTF8',
#   'es_ES.UTF-8',
#   'es_ES.UTF-8',
#   '=c/postgres\npostgres=CTc/postgres')]

# %% [markdown]
# ### I look to see what roles exist in my database.

# %%
# %%sql
#
# \du
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 11 rows affected.
# [('ion', False, True, False, True, True, -1, None, [], False),
#  ('jupyter', False, True, False, True, True, -1, None, [], False),
#  ('pg_execute_server_program',
#   False,
#   True,
#   False,
#   False,
#   False,
#   -1,
#   None,
#   [],
#   False),
#  ('pg_monitor',
#   False,
#   True,
#   False,
#   False,
#   False,
#   -1,
#   None,
#   ['pg_read_all_settings', 'pg_read_all_stats', 'pg_stat_scan_tables'],
#   False),
#  ('pg_read_all_settings',
#   False,
#   True,
#   False,
#   False,
#   False,
#   -1,
#   None,
#   [],
#   False),
#  ('pg_read_all_stats', False, True, False, False, False, -1, None, [], False),
#  ('pg_read_server_files',
#   False,
#   True,
#   False,
#   False,
#   False,
#   -1,
#   None,
#   [],
#   False),
#  ('pg_signal_backend', False, True, False, False, False, -1, None, [], False),
#  ('pg_stat_scan_tables',
#   False,
#   True,
#   False,
#   False,
#   False,
#   -1,
#   None,
#   [],
#   False),
#  ('pg_write_server_files',
#   False,
#   True,
#   False,
#   False,
#   False,
#   -1,
#   None,
#   [],
#   False),
#  ('postgres', True, True, True, True, True, -1, None, [], True)]

# %% [markdown]
# ### First query
#
# ***

# %%
# %%sql
#
# select * from hispasonic
# limit 5;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 5 rows affected.
# [(1, 0, 0, 0, 1, 350, 0, 0, 0, 0, 'dreadbox', 'dreadbox nyx v1 ', 'Valencia', datetime.datetime(2022, 5, 8, 0, 0), datetime.datetime(2022, 9, 30, 0, 0), datetime.datetime(2022, 9, 1, 0, 0), 742, 1073),
#  (2, 0, 0, 0, 1, 350, 0, 0, 0, 0, 'modal electronics ', 'cobalt 5s ', 'Castellón', datetime.datetime(2022, 7, 25, 0, 0), datetime.datetime(2022, 9, 23, 0, 0), datetime.datetime(2022, 9, 1, 0, 0), 350, 1845),
#  (3, 0, 0, 0, 1, 900, 0, 0, 0, 0, 'moog', 'moog little phatty stage 2 ', 'Baleares', datetime.datetime(2021, 7, 10, 0, 0), datetime.datetime(2022, 9, 28, 0, 0), datetime.datetime(2022, 9, 1, 0, 0), 584, 635),
#  (4, 0, 0, 0, 1, 1100, 0, 0, 0, 0, 'kawai', 'kawai mp 11 ', 'Sevilla', datetime.datetime(2022, 8, 31, 0, 0), datetime.datetime(2022, 10, 30, 0, 0), datetime.datetime(2022, 9, 1, 0, 0), 96, 1879),
#  (5, 0, 0, 0, 1, 480, 0, 0, 0, 0, 'mpc', 'mpc live ssd 250 envío incluido ', 'Albacete', datetime.datetime(2022, 8, 25, 0, 0), datetime.datetime(2022, 10, 25, 0, 0), datetime.datetime(2022, 9, 1, 0, 0), 226, 438)]

# %%
# %%sql
# select buy, count(*) as buyed
#     from hispasonic
#     group by buy;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 2 rows affected.
# [(0, 769), (1, 36)]

# %%
# %%sql
#
# select count(distinct urgent) as urgent,
#     count(*) as change,
#     count(*) as sell,
#     count( gift) as gift,
#     count(distinct search) as search,
#     count(distinct parts) as parts,
#     count(distinct city) as cities,
#     count(distinct anon_user) as anon_user,
#     count( date_scrapped) as number_ads
#     from hispasonic;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 1 rows affected.
# [(2, 805, 805, 805, 2, 2, 43, 336, 805)]

# %%
# la celda de arriba es lo que quiero que salga abajo pero

# %%
# %%sql
#
# select buy,synt_brand, city, anon_user,description, published
#     from hispasonic
#     where buy = 1 and city = 'Barcelona';
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 4 rows affected.
# [(1, 'yamaha', 'Barcelona', 870, 'yamaha psr-5700 ', datetime.datetime(2022, 8, 28, 0, 0)),
#  (1, 'eurorack', 'Barcelona', 602, 'varios módulos eurorack ', datetime.datetime(2022, 6, 12, 0, 0)),
#  (1, 'arturia', 'Barcelona', 1121, 'arturia minilab mk2 edición limitada "deep black" ', datetime.datetime(2022, 8, 18, 0, 0)),
#  (1, 'roland', 'Barcelona', 870, 'tarjeta roland sr-jv80-15 ', datetime.datetime(2022, 8, 11, 0, 0))]

# %% [markdown]
# ***

# %%
# %%sql
# select anon_user, synt_brand, description, published
#     from hispasonic
#     where (anon_user = 725);
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 4 rows affected.
# [(725, 'roland', 'roland mv30 ', datetime.datetime(2022, 5, 31, 0, 0)),
#  (725, 'instruments', 'modulos mutable instruments ', datetime.datetime(2022, 8, 11, 0, 0)),
#  (725, 'e-mu', 'e-mu orbit v3 ', datetime.datetime(2022, 8, 11, 0, 0)),
#  (725, 'elektron', 'elektron digitackt ', datetime.datetime(2022, 8, 11, 0, 0))]

# %%
# %%sql
# select distinct synt_brand, city
#     from hispasonic
#     order by city
#     limit 10;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 10 rows affected.
# [('hammond', 'A Coruña'),
#  ('yamaha', 'A Coruña'),
#  ('nord electro ', 'A Coruña'),
#  ('nord modular ', 'A Coruña'),
#  ('m-audio', 'A Coruña'),
#  ('-', 'A Coruña'),
#  ('roland', 'A Coruña'),
#  ('kawai', 'A Coruña'),
#  ('akai', 'A Coruña'),
#  ('system', 'A Coruña')]

# %%
# %%sql city
#
# select
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# (psycopg2.errors.SyntaxError) syntax error at or near "city"
# LINE 1: city
#         ^
#
# [SQL: city
#
# select]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %%sql
#
# select synt_brand, seen
#     from hispasonic
#     where seen > 1000;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 149 rows affected.
# [('roland', 2483),
#  ('roland', 1247),
#  ('nord lead ', 1163),
#  ('4ms', 1082),
#  ('moog', 1010),
#  ('behringer', 1752),
#  ('neutron', 1252),
#  ('eurorack', 14612),
#  ('korg', 1384),
#  ('-', 7964),
#  ('-', 4238),
#  ('kawai', 1404),
#  ('-', 3246),
#  ('electribe', 1911),
#  ('roland', 1711),
#  ('midi', 1105),
#  ('arp', 1308),
#  ('make noise ', 1003),
#  ('nord electro ', 1929),
#  ('nord lead ', 3357),
#  ('hammond', 3319),
#  ('eurorack', 1870),
#  ('yamaha', 3638),
#  ('novation', 1101),
#  ('evolver', 1653),
#  ('-', 1043),
#  ('arturia', 1602),
#  ('-', 1469),
#  ('-', 1344),
#  ('korg', 2672),
#  ('roland', 1684),
#  ('novation', 1062),
#  ('roland', 1035),
#  ('-', 1004),
#  ('eurorack', 2280),
#  ('doepfer', 1168),
#  ('-', 1485),
#  ('midi', 2065),
#  ('roland', 1295),
#  ('roland', 1053),
#  ('roland', 2000),
#  ('maschine', 2518),
#  ('-', 1391),
#  ('teenage engineering ', 1358),
#  ('novation', 1034),
#  ('-', 3817),
#  ('roland', 1020),
#  ('0', 1489),
#  ('-', 3366),
#  ('odyssey', 1073),
#  ('modular', 1141),
#  ('-', 1462),
#  ('elektron', 1494),
#  ('eurorack', 1176),
#  ('-', 1948),
#  ('roland', 6471),
#  ('modular', 2274),
#  ('kurzweil', 1280),
#  ('yamaha', 4735),
#  ('akai', 3471),
#  ('kurzweil', 1446),
#  ('novation', 1698),
#  ('casio', 1092),
#  ('hammond', 4574),
#  ('yamaha', 2126),
#  ('korg', 1814),
#  ('poly', 1055),
#  ('mpc', 1006),
#  ('dreadbox', 1266),
#  ('korg', 2116),
#  ('roland', 4331),
#  ('e', 1120),
#  ('hammond', 1583),
#  ('instruments', 1319),
#  ('korg', 2098),
#  ('waldorf', 1452),
#  ('akai', 1738),
#  ('yamaha', 3396),
#  ('korg', 1792),
#  ('korg', 3117),
#  ('hammond', 4242),
#  ('casio', 1078),
#  ('waldorf', 3751),
#  ('roland', 2081),
#  ('atomo', 3965),
#  ('-', 2592),
#  ('roland', 1455),
#  ('korg', 1286),
#  ('nord stage ', 3060),
#  ('-', 3990),
#  ('eurorack', 1541),
#  ('system', 5720),
#  ('rhodes', 1726),
#  ('roland', 2056),
#  ('volca', 2909),
#  ('bheringer', 1129),
#  ('korg', 1143),
#  ('korg', 1013),
#  ('-', 1444),
#  ('midi', 1131),
#  ('kurzweil', 2104),
#  ('analogue systems ', 1668),
#  ('-', 1146),
#  ('noise', 1381),
#  ('roland', 3027),
#  ('origin', 2018),
#  ('yamaha', 1680),
#  ('uno', 1158),
#  ('-', 1047),
#  ('-', 20160),
#  ('-', 1112),
#  ('-', 1912),
#  ('yamaha', 1845),
#  ('modular', 4528),
#  ('instruments', 1295),
#  ('-', 2430),
#  ('nord lead ', 3737),
#  ('arturia', 1177),
#  ('eurorack', 5963),
#  ('yamaha', 1172),
#  ('origin', 2257),
#  ('virus', 1070),
#  ('roland', 3138),
#  ('modular', 2162),
#  ('yamaha', 2501),
#  ('-', 1004),
#  ('roland', 1034),
#  ('mutable', 2848),
#  ('korg', 1550),
#  ('-', 1624),
#  ('korg', 1009),
#  ('-', 1573),
#  ('yamaha', 1756),
#  ('yamaha', 1209),
#  ('yamaha', 5597),
#  ('-', 1371),
#  ('casio', 1966),
#  ('-', 1219),
#  ('korg', 1529),
#  ('arturia', 1058),
#  ('virus', 4157),
#  ('roland', 1015),
#  ('e-mu', 1696),
#  ('novation', 17048),
#  ('-', 1954),
#  ('yamaha', 2332),
#  ('-', 1534),
#  ('kurzweil', 1308),
#  ('odyssey', 1096)]

# %%
# %%sql
#
# select description, synt_brand, price, seen
#     from hispasonic
#     where synt_brand = 'roland' and price > 1000
#     order by price desc;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 15 rows affected.
# [('roland tr 808 ', 'roland', 5500, 676),
#  ('roland jupiter 4 ', 'roland', 5100, 3027),
#  ('sintetizador roland jupiter-4 compuphonic ', 'roland', 4500, 536),
#  ('roland superjupiter mks 80 + programmer mpg 80 en perfecto estado ', 'roland', 3750, 642),
#  ('roland fantom 6 ', 'roland', 2495, 1015),
#  ('roland juno 106 seminuevo ', 'roland', 2250, 220),
#  ('roland sh 101 ', 'roland', 2000, 1455),
#  ('roland juno 106 ', 'roland', 1800, 322),
#  ('roland jd-800 impecable ', 'roland', 1800, 4331),
#  ('roland júpiter 80 + flight case a medida ', 'roland', 1550, 2056),
#  ('roland fantom 07 ', 'roland', 1450, 840),
#  ('roland fantom g6 ', 'roland', 1300, 580),
#  ('sintetizador roland spv-355 ', 'roland', 1175, 238),
#  ('roland jupiter xm ', 'roland', 1169, 838),
#  ('roland jd xa "reestreno" ', 'roland', 1100, 1034)]

# %%
# %%sql
#
# select min(price)
#     from hispasonic;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 1 rows affected.
# [(0,)]

# %%
# %%sql
#
# select max(price)
#     from hispasonic;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 1 rows affected.
# [(111111,)]

# %%
# %%sql
#
# select sum(price) from hispasonic;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 1 rows affected.
# [(Decimal('581870'),)]

# %% [markdown]
# ### Synthesizer manufacturers in the database.

# %%
# %%sql
#
# select synt_brand, COUNT(DISTINCT "synt_brand") as quantity
#     from hispasonic
#     group by 1
#     order by quantity desc;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 126 rows affected.
# [('-', 1),
#  ('0', 1),
#  ('4ms', 1),
#  ('access', 1),
#  ('acid', 1),
#  ('acidlab', 1),
#  ('adam', 1),
#  ('ajh', 1),
#  ('akai', 1),
#  ('alesis', 1),
#  ('alm busy ', 1),
#  ('analogue solutions ', 1),
#  ('analogue systems ', 1),
#  ('arp', 1),
#  ('arturia', 1),
#  ('atomo', 1),
#  ('atomosynth', 1),
#  ('audio', 1),
#  ('axoloty', 1),
#  ('befaco', 1),
#  ('behringer', 1),
#  ('bheringer', 1),
#  ('boss', 1),
#  ('casio', 1),
#  ('chronograf', 1),
#  ('club', 1),
#  ('cme', 1),
#  ('critter', 1),
#  ('decksaver', 1),
#  ('deepmind 12 ', 1),
#  ('delptronics', 1),
#  ('dexibell', 1),
#  ('doepfer', 1),
#  ('dreadbox', 1),
#  ('dynacord', 1),
#  ('e', 1),
#  ('echo', 1),
#  ('electribe', 1),
#  ('elektron', 1),
#  ('elka', 1),
#  ('e-mu', 1),
#  ('emu', 1),
#  ('erica synths ', 1),
#  ('eurorack', 1),
#  ('evolver', 1),
#  ('expert', 1),
#  ('fairfield', 1),
#  ('finegear', 1),
#  ('frequency', 1),
#  ('gator', 1),
#  ('hammond', 1),
#  ('instruments', 1),
#  ('instruo', 1),
#  ('intellijel ', 1),
#  ('iomega', 1),
#  ('jomox', 1),
#  ('kawai', 1),
#  ('ketron', 1),
#  ('kodamo', 1),
#  ('komplete', 1),
#  ('korg', 1),
#  ('kurzweil', 1),
#  ('make noise ', 1),
#  ('maschine', 1),
#  ('m-audio', 1),
#  ('micro', 1),
#  ('midi', 1),
#  ('miditech', 1),
#  ('modal electronics ', 1),
#  ('modular', 1),
#  ('monome', 1),
#  ('moog', 1),
#  ('mpc', 1),
#  ('music', 1),
#  ('mutable', 1),
#  ('mutant', 1),
#  ('mxr', 1),
#  ('neutron', 1),
#  ('noise', 1),
#  ('nord electro ', 1),
#  ('nord lead ', 1),
#  ('nord modular ', 1),
#  ('nord rack ', 1),
#  ('nord rack nord lead ', 1),
#  ('nord stage ', 1),
#  ('nord wave ', 1),
#  ('novation', 1),
#  ('oberheim', 1),
#  ('odyssey', 1),
#  ('origin', 1),
#  ('oto', 1),
#  ('paratek', 1),
#  ('pearl', 1),
#  ('peavey', 1),
#  ('poly', 1),
#  ('polyend', 1),
#  ('qu', 1),
#  ('quasimidi', 1),
#  ('quiklok', 1),
#  ('rhodes', 1),
#  ('roland', 1),
#  ('sensel', 1),
#  ('sequential circuits ', 1),
#  ('shakmat modular ', 1),
#  ('soundforce', 1),
#  ('squarp', 1),
#  ('studio', 1),
#  ('swissonic', 1),
#  ('synthesis', 1),
#  ('synthrotek', 1),
#  ('system', 1),
#  ('tascam', 1),
#  ('teenage engineering ', 1),
#  ('the', 1),
#  ('tiptop audio ', 1),
#  ('u-he', 1),
#  ('ultimate', 1),
#  ('uno', 1),
#  ('vermona', 1),
#  ('virus', 1),
#  ('volca', 1),
#  ('waldorf', 1),
#  ('wmd make noise erica synth ', 1),
#  ('xaoc', 1),
#  ('yamaha', 1),
#  ('zoom', 1)]

# %% [markdown]
# ### Amount of synthesizer manufacturers in the database.

# %%
# %%sql
#
# select synt_brand, COUNT(*) as quantity
#     from hispasonic
#     group by 1
#     order by quantity desc;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# 126 rows affected.
# [('-', 121),
#  ('roland', 91),
#  ('yamaha', 71),
#  ('korg', 62),
#  ('eurorack', 32),
#  ('arturia', 24),
#  ('doepfer', 21),
#  ('behringer', 18),
#  ('moog', 16),
#  ('akai', 15),
#  ('novation', 13),
#  ('instruments', 13),
#  ('midi', 13),
#  ('kawai', 12),
#  ('kurzweil', 12),
#  ('befaco', 11),
#  ('audio', 10),
#  ('elektron', 10),
#  ('hammond', 10),
#  ('waldorf', 9),
#  ('virus', 8),
#  ('system', 8),
#  ('nord lead ', 8),
#  ('modular', 8),
#  ('mpc', 8),
#  ('e-mu', 6),
#  ('volca', 6),
#  ('dreadbox', 6),
#  ('erica synths ', 5),
#  ('alesis', 5),
#  ('odyssey', 5),
#  ('casio', 5),
#  ('noise', 4),
#  ('decksaver', 4),
#  ('0', 4),
#  ('oberheim', 4),
#  ('m-audio', 3),
#  ('teenage engineering ', 3),
#  ('make noise ', 3),
#  ('nord stage ', 3),
#  ('electribe', 3),
#  ('emu', 3),
#  ('studio', 3),
#  ('komplete', 3),
#  ('4ms', 3),
#  ('nord electro ', 3),
#  ('poly', 2),
#  ('origin', 2),
#  ('jomox', 2),
#  ('critter', 2),
#  ('dynacord', 2),
#  ('the', 2),
#  ('pearl', 2),
#  ('ketron', 2),
#  ('analogue systems ', 2),
#  ('shakmat modular ', 2),
#  ('micro', 2),
#  ('arp', 2),
#  ('maschine', 2),
#  ('iomega', 2),
#  ('vermona', 2),
#  ('uno', 2),
#  ('synthesis', 2),
#  ('echo', 1),
#  ('monome', 1),
#  ('sensel', 1),
#  ('nord modular ', 1),
#  ('delptronics', 1),
#  ('wmd make noise erica synth ', 1),
#  ('mxr', 1),
#  ('nord rack ', 1),
#  ('miditech', 1),
#  ('club', 1),
#  ('rhodes', 1),
#  ('quiklok', 1),
#  ('quasimidi', 1),
#  ('finegear', 1),
#  ('tiptop audio ', 1),
#  ('xaoc', 1),
#  ('dexibell', 1),
#  ('evolver', 1),
#  ('adam', 1),
#  ('acid', 1),
#  ('squarp', 1),
#  ('chronograf', 1),
#  ('oto', 1),
#  ('instruo', 1),
#  ('nord wave ', 1),
#  ('bheringer', 1),
#  ('boss', 1),
#  ('mutable', 1),
#  ('neutron', 1),
#  ('soundforce', 1),
#  ('access', 1),
#  ('cme', 1),
#  ('kodamo', 1),
#  ('gator', 1),
#  ('nord rack nord lead ', 1),
#  ('fairfield', 1),
#  ('acidlab', 1),
#  ('intellijel ', 1),
#  ('alm busy ', 1),
#  ('mutant', 1),
#  ('deepmind 12 ', 1),
#  ('zoom', 1),
#  ('sequential circuits ', 1),
#  ('qu', 1),
#  ('elka', 1),
#  ('atomo', 1),
#  ('analogue solutions ', 1),
#  ('tascam', 1),
#  ('axoloty', 1),
#  ('e', 1),
#  ('paratek', 1),
#  ('frequency', 1),
#  ('peavey', 1),
#  ('ultimate', 1),
#  ('u-he', 1),
#  ('polyend', 1),
#  ('atomosynth', 1),
#  ('ajh', 1),
#  ('music', 1),
#  ('swissonic', 1),
#  ('modal electronics ', 1),
#  ('synthrotek', 1),
#  ('expert', 1)]

# %%
# %%sql
#
# select synt_brand, COUNT(*) as quantity
#     from hispasonic
#     group by
#     order by quantity desc;
# Out:
#  * postgresql+psycopg2://jupyter:***@localhost/hispasonic
# (psycopg2.errors.SyntaxError) syntax error at or near "order"
# LINE 4:     order by quantity desc;
#             ^
#
# [SQL: select synt_brand, COUNT(*) as quantity
#     from hispasonic
#     group by
#     order by quantity desc;]
# (Background on this error at: https://sqlalche.me/e/14/f405)
