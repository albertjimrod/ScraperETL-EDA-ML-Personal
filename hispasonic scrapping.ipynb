# %% [markdown]
# # Hispasonic
#
#
# <br>
#
# A website about musical instruments, recording stuff, and everything related to the world of music. In this place there is also a second-hand market where users sell their musical instruments.
#
# This first part of the project focuses on obtaining relevant ad information, the category I have focused on has been the one that refers to electronic musical instruments.
#
# <br>
#
# Before start obtaining information, the first thing we must know is to understand how the announcement page is organized.
#
# ***
#
# - *Image of one of the pages of hispasonic*
#
#
# ![hispa_1e.png](hispa_1e.png)
#
# <br>
#
# <br>
#
# We can see several important things:
#
# - Selected category is on "teclados y sintetizadores".
#
# - Know the number of pages that we are going to analyze to get **all the ads**.
#
#
#
# ## Function library loading

# %%
import requests               # Is an elegant and simple HTTP library for Python
from bs4 import BeautifulSoup # library for pulling data out of HTML and XML files
import re                     # regular expressions operations
import pandas as pd           # A fast, powerful, flexible and easy to use open source data analysis tool
import os                     # A versatile way to use operating system-dependent functionality.
import datetime as dt         # module for manipulating dates and times.
import time

pd.set_option("display.max_rows", None)

# %% [markdown]
# ### first contact
#
# First of all we must to know if we have a proper response from the server.

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# These are the main possible answers we can get from the server:
#
# |||
# |:--|:--|
# |**1xx informational response –** |the request was received, continuing process|
# |**2xx successful –** |the request was successfully received, understood, and accepted|
# |**3xx redirection –** |further action needs to be taken in order to complete the request|
# |**4xx client error –** |the request contains bad syntax or cannot be fulfilled|
# |**5xx server error –** |the server failed to fulfil an apparently valid request|

# %%
# Enter the address and see the response from the server.

url = "https://www.hispasonic.com/anuncios/teclados-sintetizadores"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %% [markdown]
# #### <Response [200]> means correct connection.
#
# ## Number of pages to analyze
#
# Once we have communication, we have to know how to determine how to obtain the **total number of pages** to scrap.
#
# ![cantidad_iteraciones.png](cantidad_iteraciones.png)
#
# The item is identified as follows.
#
#        'ul', class_='pagination'
#
# <br>
#
# Unordered list from a `pagination` class.
#
#
# To determine the number of iterations, that is, the number of pages on which to extract the information, I must find it inside the html content, find this element within the pages and know what the maximum value is.
#
# We will do this with Beautifulsoup use to extract the contents of an element.

# %%
soup = BeautifulSoup(page.content, 'html.parser')
# soup  # all site code

# %% [markdown]
# Inside `soup` variable we are looking for `'ul', class_='pagination'`
#
# The following code refers to the
#
# - **first 5 links of the pages**,
#
# - the **next 10 pages** and the **last one**, which is the one that interests us.
#
# Save it in a variable of type list, called `unordered_list`

# %%
unordered_list = soup.find('ul', class_='pagination') # into variable
unordered_list = unordered_list.contents # tag's children available in a list called .content. from variable to list
unordered_list                           # list
# Out:
# ['\n',
#  <li>
#  <span class="selected">1</span>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina2" rel="next">2</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina3">3</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina4">4</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina5">5</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina11" title="Siguientes 10 páginas">›</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina33" title="Última página">»</a>
#  </li>,
#  '\n']

# %% [markdown]
# ### Exploring `unordered_list`

# %%
len(unordered_list) # number of elements
# Out:
# 15

# %%
unordered_list[0] # first element
# Out:
# '\n'

# %%
unordered_list[-1] # last element
# Out:
# '\n'

# %%
unordered_list[-2] # this is the one I'm interested in
# Out:
# <li>
# <a href="/anuncios/teclados-sintetizadores/pagina33" title="Última página">»</a>
# </li>

# %% [markdown]
# ### Get the value number from `unordered_list`
#
# As what I need is to access the value within the list the strategy that I will follow is the following:
#
# - Convert the list to a text string
#
# - Filter the characters that correspond to numeric values
#
# - Convert those numeric characters to numbers
#
# No puedo que pueda acceder al valor que me interesa unicamente esperando que el valor que quiero esté en la penultima, asi que lo que haré será convertir el contenido de la lista en una cadena de texto y hacer un filtrado de los caracteres con mayor valor mediante expresiones regulares.
#
# Convierto el contenido de `paginas` en cadena de texto.

# %%
test = str(unordered_list[-2])
test
# Out:
# '<li>\n<a href="/anuncios/teclados-sintetizadores/pagina33" title="Última página">»</a>\n</li>'

# %% [markdown]
# `extractMax` function get the string numbers separated by minuscule characters and convert it to integers.

# %%
def extractMax(input):
     # get a list of all numbers separated by 
     # lower case characters 
     # \d+ is a regular expression which means
     # one or more digit
     # output will be like ['100','564','365']
    numbers = re.findall('\d+',input)
     # now we need to convert each number into integer
     # int(string) converts string into integer
     # we will map int() function onto all elements 
     # of numbers list
    numbers = map(int,numbers)
    return max(numbers) # devuelve un entero

# %%
page_numbers = extractMax(test)
page_numbers
# Out:
# 33

# %% [markdown]
# We already have the number of pages that we will have to analyze.
#
# ***

# %% [markdown]
# ### Get and save all ad links.
#
# Iterating on each of the pages we will extract:
#
# - Everything that is a link.
#
#
# - Those links what I do is stay with what ends in number which is the way to identify those who are ads and what are not.

# %%
links_ads = []        # all the ads on the page
listado_enlaces = []  # all the links on the page

pattern="([0-9]{4,9})" # filtro aquellos enlaces que acaban en numeros.

for pagina in range(page_numbers, 0, -1): 
    url = "https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina{pagina}".format(pagina=pagina)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    
    for link in soup.find_all('a'):       # filter everything that is a link on soup variable
        links_ads.append(link.get('href'))
        
    
    for s in links_ads:                   # of those links what I do is stay with what ends in number
        if re.search(pattern, s):
            listado_enlaces.append(s)
# Out:
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina33
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina32
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina31
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina30
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina29
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina28
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina27
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina26
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina25
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina24
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina23
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina22
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina21
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina20
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina19
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina18
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina17
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina16
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina15
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina14
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina13
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina12
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina11
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina10
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina9
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina8
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina7
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina6
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina5
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina4
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina3
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina2
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina1

# %%
links_ads[5:20] # example
# Out:
# ['/musica',
#  '/productos',
#  '/anuncios',
#  '/anuncios/todo',
#  '/anuncios/todo/f/compra-protegida',
#  '/anuncios',
#  '/anuncios/compraventa',
#  '/anuncios/teclados-sintetizadores',
#  '/anuncios/todo/f/compra-protegida',
#  '/compra-protegida',
#  '/anuncios/todo/f/compra-protegida',
#  '/index.php?controller=ad&action=new_ad_form',
#  '/anuncios/teclados-sintetizadores',
#  '/anuncios/teclados-sintetizadores/pagina23',
#  '/anuncios/teclados-sintetizadores/pagina29']

# %%
listado_enlaces[5:20] # example
# Out:
# ['/anuncios/arturia-matrixbrute/965788',
#  '/anuncios/soporte-guil/900977',
#  '/anuncios/soporte-guil/900977',
#  '/anuncios/trajetas-teclados/949462',
#  '/anuncios/trajetas-teclados/949462',
#  '/anuncios/transient-8s-secuenciador-eurorack-8-pasos/941431',
#  '/anuncios/transient-8s-secuenciador-eurorack-8-pasos/941431',
#  '/anuncios/piano-pearl-river-pd180d/932174',
#  '/anuncios/piano-pearl-river-pd180d/932174',
#  '/anuncios/tascam-246-pinch-roller/876919',
#  '/anuncios/tascam-246-pinch-roller/876919',
#  '/anuncios/soniccell-roland/867426',
#  '/anuncios/soniccell-roland/867426',
#  '/anuncios/korg-vocoder-vc10/866556',
#  '/anuncios/korg-vocoder-vc10/866556']

# %% [markdown]
# ### Cleaning links
#
# Taking a look at the two lists it is striking that there are links that are repeated:
#
#             '...
#             '/anuncios/korg-vocoder-vc10/866556',
#              '/anuncios/korg-vocoder-vc10/866556',
#              '/anuncios/polyend-tracker/1057403',
#              '/anuncios/polyend-tracker/1057403',
#              '/anuncios/trajetas-teclados/949462',
#              '/anuncios/trajetas-teclados/949462',
#                                              ...',
#
#
# To maintain only the links not repeated, we will make a filter from a dictionary and extracting from the link the name that can identify it as a value.
#
# Leaving the link as a key and an identifying name of the url as a value.

# %%
diccionario_enlaces = {}
cnt = 0

listado_marcas = []

patron_marca = "((?<=anuncios\/)[1-9][a-z]{1,})|((?<=anuncios\/)[a-z]{1,})"

for enlace in listado_enlaces:
    if enlace not in diccionario_enlaces:
        
        try:
            marca = re.search(patron_marca, enlace).group()
            diccionario_enlaces[enlace] = marca
        except AttributeError:
            marca = re.search(patron_marca, enlace)

# %% [markdown]
# ![regex_expression.png](regex_expression.png)

# %%
diccionario_enlaces['/anuncios/polyend-tracker/1057403'] # view example
# Out:
# 'polyend'

# %% [markdown]
# With the dictionary that we have just created we are going to download all the ads locally.
#
# The reason is not to overload the server and run the risk of being banned.

# %%
import time

main_path='https://www.hispasonic.com'
local_path = '/home/ion/Documentos/proyectos_personales/syntdata/htmls/'

for enlace in diccionario_enlaces:
    time.sleep(1) # Sleep for 3 seconds
    page = requests.get(main_path + enlace) # https://www.hispasonic.com/anuncios/polyend-tracker/1057403.html
    
    enlace = enlace.split("/")  # filtro para poder extraer
    enlace= enlace[2]           # nombre del anuncio

    with open(local_path + enlace + '.html',"w+") as f:
        f.write(page.text)

# %%
sintes = ['access', 'acidlab', 'akai', 'alembic', 'alesis', 'allen&heath', 'analogue solutions', 'analogue systems',
          'arp', 'arturia', 'asm (ashun sound machines)', 'audio damage', 'audiophile circuits league', 'a-v-p synth',
         'balaguer', 'baloran', 'bastl instruments', 'behringer', 'black corporation', 'böhm', 'boss', 'bubblesound instruments',
         'buchla', 'casio', 'charlie lab', 'charvel', 'circuit abbey', 'clavia nord', 'club of the knobs', 'crumar',
         'custom made synths', 'cyclone', 'cyclone analogic', 'dave jones design', 'dave smith instruments', 'denon dj',
         'dexibell', 'doepfer musikelektronik', 'dreadbox', 'dubreq', 'elby designs', 'electronic music laboratories (eml)', 'elektron',
         'elka', 'elta music', 'e:m:c', 'e-mu systems', 'endorphin.es', 'endorphines', 'ensoniq', 'epiphone', 'erica synths',
         'ernie ball music man', 'esp ltd', 'evh', 'exodus digital', 'farfisa', 'fender', 'fishman', 'fodera', 'formanta',
         'fretlight', 'friedman', 'future retro', 'futuresonus', 'gemini', 'generalmusic', 'gibson', 'godin', 'gotharman',
         'graph tech', 'gretsch', 'guild', 'hammond', 'hartmann', 'hexinverter', 'hinton instruments', 'höfner', 'hypersynth',
         'ibanez', 'ik multimedia', 'intellijel', 'isla instruments', 'jackson', 'john bowen synth design', 'jomox', 'kawai',
         'kenton', 'ketron', 'kilpatrick audio', 'koma elektronik', 'korg', 'kramer', 'kurzweil', 'lakland', 'line 6',
         'linn electronics', 'livid', 'logan electronics', 'macbeth studio systems', 'make noise', 'malekko', 'manikin electronic',
         'm-audio', 'mellotron', 'mfb', 'modal electronics', 'modor', 'modulus', 'moog', 'mutable instruments', 'native instruments',
         'novation', 'numark', 'oberheim', 'orthogonal devices', 'peavey', 'pioneer dj', 'pittsburgh modular', 'polyend', 'ppg (palm products gmbh)',
         'prs', 'quasimidi', 'qu-bit electronix', 'waves grendel', 'radikal technologies', 'rhodes', 'rickenbacker', 'roland',
         'roli', 'schecter', 'sequential', 'sequential circuits', 'sequentix', 'simmons','sintetizador', 'sonicware', 'special waves',
         'spector', 'spectral audio', 'squarp instruments', 'squier', 'ssf', 'stanton', 'steinberger', 'sterling',
         'studio electronics', 'studiologic music', 'synths', 'synthstrom', 'taylor', 'technos', 'teenage engineering', 'tiptop audio',
         'traveler guitar', 'udo audio', 'vermona', 'viscount', 'vox', 'waldorf', 'warwick', 'washburn', 'wersi music', 'winter modular',
         'wurlitzer', 'wmd', 'wmd / ssf', 'yamaha', 'zeppelin design labs', 'synthesis technology', 'nord', 'tascam', 'synthrotek',
         'e-mu', 'transient modules', 'befaco', 'tiptop', 'dynacord', 'dave smith', 'polygraf', 'studiologic', 'corsynth',
         'micro modular', 'mutant', 'chronograf', 'maschine', 'pearl', 'yocto', 'komplete', 'nord electro', 'erica synth',
         'frequency central', 'nord lead 4', 'make noise', 'modal', 'nord stage', 'acces', 'doepfer', 'eventide', 'instruo',
         'atomo synth', 'atomosynth', 'wersi', 'nord lead 3', 'vermona', 'bheringer', 'behringer', 'synamodec', 'teenage enginering',
         'sputnik', 'strymon','synthstrom', 'sequencial', 'sequential', 'sequential circuits', 'kurzweil', 'electribe', 'frap tool', 'synthtech',
         'qubit', 'qu-bit', 'qu bit', 'pittsburgh', 'cre8audio', 'paratek', 'uno synth ', 'bastl', 'volca', 'deepmind', 'deepmind 6',
         'deepmind 12', 'monome', 'neutron', 'asm', 'evolver', 'mpc', 'eurorack', 'controlador', 'teclado', 'octatrack', 'digitack',
         'models', 'bitbox', 'axoloty', 'noise engineering', 'virus ti', '0-coast', '0 coast', 'coast']

# %%
os.chdir('/home/ion/Documentos/proyectos_personales/syntdata/htmls/') # working directory mapping

# %%
os.getcwd() # checking path
# Out:
# '/home/ion/Documentos/proyectos_personales/syntdata/htmls'

# %% [markdown]
# ### Extract parameters from htmls saved by regex:
#
# To be able to extract the price, the username, and other parameters that interest us.
#
# What we are going to do is select that element in **html** that interests us and filter the content through regex (regular expressions).

# %%
def get_data(pay_load, pattern_regex):
    pay_load = str(pay_load)
    pay_load = pay_load.lower()
    
    try:
        data = re.search(pattern_regex, str(pay_load))
        data = data.group()
        
    except AttributeError:
        data = re.search(pattern_regex, str(pay_load))
        
    return data

# %%
list_price = []
list_brand = []
list_model = []
list_user = []
list_date = []
list_expire = []
list_times_seen= [] 
list_city = []

# %% [markdown]
# What we are going to do is read each over the ads that we save locally.
# <br>
#
# ![hispa_4.png](hispa_4.png)
#
# <br>
#
# This is an ad where you can identify the fields we want to get:
#
# - **price**
#
# - **user**
#
# - **city**
#
# - **times seen**
#
# - **date expire**
#
# - **description**
#
#
# **Note:**
#
# The description or title of the advertisement shall be filtered to extract the manufacturer's brand the relevant **model** or **description**.
#
#
# The date on which the ad has been published can change format if the user makes some kind of modification to it! but the date of publication is a good fact to take into account, hoewer due to the internal mechanism of the forum, when the user modifies announcement also does the format of the date, becoming from absolute date to a relative date.
#
# example:
#
# <br>
#
# ![hispa_56.png](hispa_56.png)
#
# <br>
#
#
# As a example in this announcement the publication date disappears to report how much time has passed since the last modification, being variations ranging from seconds, minutes, hours, days and weeks.
#
#
# Therefore the best option to get a consistent publication date is to keep in mind that the **expiration** date refers to you having an initial expiration date of two months.

# %%
for i in os.listdir('.'):
    with open(i,"r") as f:
        pagina = f.read()
        soup = BeautifulSoup(pagina, "html.parser")
    
    # ---    price
        price = soup.find('div',class_='ad-price')
        pattern_price = "([1-9]\w+)"
        
        price = get_data(price,pattern_price)
        list_price.append(price)
        
        
    # ---   title
        title = soup.find('h1',class_='title') 
        pattern_title = "(?<=\">).+(?=<\/)"
        
        title = get_data(title,pattern_title)
        
        
   # ---   brand
        pattern_brand = "^\w+(?=\s)"
        brand = get_data(title,pattern_brand) # brand
        list_brand.append(brand)
        

   # ---   model
        pattern_model = '(?<=\s)\w.+(?=\s)'
        model = get_data(title, pattern_model) # model
        list_model.append(model)
        
        
    # ---  user
        user = soup.find('a',class_='user-link')
        
        pattern_user = '\w+(?=<)'
        user = get_data(user, pattern_user)
        list_user.append(user)
        
        
    # ---  dates
        data_user = soup.find('div',class_='col-lg-7')
        
        pattern_date = '[0-9]{2}\/[0-9]{2}\/[0-9]{4}(?=\s\w)' # formato dd/mm/YYYY
        pattern_semana = '\w+\s\d+\s\w+(?=\s\w{1})' # hace 1 semana
        
        date = get_data(data_user, pattern_date)
        dates = get_data(data_user, pattern_semana)
        
    #### ------------------------------------------------------------------------------------------------
        
        if date != None:
            list_date.append(date)
            
        if dates != None:
            list_date.append(dates)
                        
    #### ------------------------------------------------------------------------------------------------
        
        
    # ---  list_expire
        pattern_expira = '[0-9]{2}\/[0-9]{2}\/[0-9]{4}(?=\s\|)'# formato dd/mm/YYYY
        expire = get_data(data_user, pattern_expira)
        list_expire.append(expire)
        
        
    # ---  list_times_seen
        pattern_visto = '(?<=\s)\d\w+(?=\s)'
        times_seen = get_data(data_user, pattern_visto)
        list_times_seen.append(times_seen)
        
    
    # ---  list_city
        pattern_lugar = '(?<=\w>)\w+(?=\<)'
        city = get_data(data_user, pattern_lugar)
        list_city.append(city)

# %% [markdown]
# ### Data extraction
#
# The next step is to know what date we have on the day on which the data extraction is done, this an important fact since it can be useful when doing the analysis as to have a record of the ads over time.

# %%
hoy = dt.datetime.now()
year=str(hoy.year)
month=str(hoy.month)
day=str(hoy.day)

date_scrapped = day + '/' + month + '/' + year

date_scrapped
# Out:
# '2/8/2022'

# %%
df = pd.DataFrame({'brand':list_brand,
                   'model':list_model,
                   'price':list_price,
                   'times_seen':list_times_seen,
                   'city':list_city,
                   'scrap_date':date_scrapped,
                   'expires':list_expire,
                   'user':list_user,
                  },index = list(range(1,len(list_expire)+1)))

df
# Out:
#               brand                                              model  \
# 1             modal                                 electronics cobalt
# 2              moog                                little phatty stage
# 3              None                               precio)doepfer a-100
# 4              None                                        e-mu planet
# 5          novation                                               sl49
# 6        synthrotek                                               None
# 7            roland                                             fantom
# 8            alesis                                 qx49 - controlador
# 9              roli                                           seaboard
# 10           access                                              virus
# 11             korg       minilogue - behringer rd6 - vermona er9 drum
# 12          kordbot                                               isla
# 13             None                       roland sound library pcm1-06
# 14      controlador                         midi/usb m-audio oxygen 88
# 15         novation                                bass station ii com
# 16           ketron                                                sd9
# 17             None                                         patches de
# 18             korg                                               None
# 19            jomox                                        t-resonator
# 20            piano                                        pearl river
# 21             poly                                          beebo (no
# 22             nord                                               lead
# 23              4ms                       quad pingable lfo+quad clock
# 24        behringer                                             921 vc
# 25          shakmat                               modular clock o'pawn
# 26             moog                                                sub
# 27             make                                              noise
# 28             None                         buchla lem 218e y/o sensel
# 29              set                de tres sintes analógicos enracados
# 30     sintetizador                                               None
# 31              dos  tarjetas para roland r8;  memory card m-256e y...
# 32          neutron                                        semimodular
# 33             korg                                          modwave +
# 34            stand                  akai mpc live 1 (fuera stock)(env
# 35           roland                                               None
# 36             None          cambio novation circuit + mod. vendo: 130
# 37        groovebox                                             roland
# 38          modulos                                           eurorack
# 39           modulo                        eurorack ajh synth entropic
# 40             korg                                              krome
# 41             akai                                               None
# 42             korg                                     triton extreme
# 43           befaco                                               None
# 44             None                  nord stage 3 compact o electro 6d
# 45         tarjetas                                roland sn-u110 02 y
# 46        transient                      8s secuenciador eurorack de 8
# 47            vendo    novation xio 25 2-octave – sintetizador y audio
# 48          teenage                           engineering op-1 + funda
# 49             korg                     ns5r modulo de sonido del korg
# 50         dreadbox                       hysteria, eudemonia, utopia,
# 51       sequential                                          prophet 5
# 52          jaspers                                               None
# 53             akai                              apc key25 en muy buen
# 54             None                                              casio
# 55            vendo                                        yamaha moxf
# 56             korg                                               None
# 57           roland                                        memory card
# 58        swissonic                                            easykey
# 59           roland                                             system
# 60       intellijel                                    buff multiple ·
# 61           roland                                           fantom s
# 62          doepfer                    a-100lc3v low cost case vintage
# 63          teclado                                     digital yamaha
# 64         novation                            remote sl 25 con fundas
# 65             korg                    sp250 nuevo sin uso con atril y
# 66             korg                                             kronos
# 67           yamaha    vrc 101 keyboard plucked &amp; tuned percussion
# 68            vendo  varios módulos make noise, mutable, cwejman en...
# 69             None                                       roland s-220
# 70            modal                                               None
# 71             zoom                            arq anillo sintetizador
# 72             soma                                               lyra
# 73          doepfer                                       a 100 pms 12
# 74             None                                doepfer a-106-5 sem
# 75           modulo                              eurorack neutron flux
# 76           expert                      sleepers disting mk4 - módulo
# 77          mutable                                 instruments braids
# 78             nord                                               lead
# 79             moog                                  werkstatt 01 + cv
# 80     sintetizador                                              kawai
# 81          waldorf                                    micro q [último
# 82           access                                           virus ti
# 83          hammond                                        l122 recien
# 84              asm                                               None
# 85           roland           fa08 impecable casi sin uso ampliado con
# 86             korg                                        electribe s
# 87           maleta                                    sintetizador 61
# 88       flightcase                                           yamaha p
# 89           yamaha                                                rev
# 90             None                        soporte quiklok en perfecto
# 91             toms                                                000
# 92        fairfield                        circuitry meet maude analog
# 93           roland                                                 mc
# 94           roland                                            xv 5080
# 95           clavia                              nord lead 1 rack - 12
# 96             None                                          yamaha sy
# 97            funda                                        clavia nord
# 98             korg                                               ms20
# 99               rd                                              8 mki
# 100       behringer                                deepmind 6 + maleta
# 101          roland                                               None
# 102       cre8audio                                            cellz +
# 103          native  instruments maschine mark 1 controlador usb mi...
# 104             arp                                        2600 + 3620
# 105            korg                                               None
# 106            None                                     varios módulos
# 107          yamaha                                               None
# 108            None                             cambio tripode pro por
# 109       synthesis                  technology e370 quad morphing vco
# 110         teclado                                 sintetizador kawai
# 111            make                                              noise
# 112            nord                                             lead 4
# 113            nord                                         electro hp
# 114            None                    roland eg-101 groovekeyboard (o
# 115             arp                             2600m  nuevo ( tambien
# 116      intellijel                                               None
# 117         sonidos                              custom para nord lead
# 118         hammond                                           e-262 de
# 119         walforf                                            micro q
# 120           chipz                                             modulo
# 121      intellijel                                               None
# 122          roland                                            juno ds
# 123          yamaha                                             master
# 124         hammond                                           m100 año
# 125          yamaha                   cp40 con funda y pedal original.
# 126         teclado                                    waldorf blofeld
# 127            None                 proformance 1 módulo de sonidos de
# 128        elektron                                                 cv
# 129          roland                                                 tb
# 130        novation                                            impulse
# 131            None                                    compro kurzweil
# 132          studio                      electronics atc-1 2600 filter
# 133         mutable                                 instruments clouds
# 134       interface                               midi usb 4x4 m-audio
# 135             dsi                                               None
# 136          leslie                                      122 clásico y
# 137        analogue                                            systems
# 138            None                                       erica fusión
# 139         arturia                                          minibrute
# 140           piano                                             roland
# 141           wersi                    ex10r expander with 8-bit drums
# 142    electrovoice   fx70 (emulador leslie de rack, igual al dynacord
# 143           cellz                    cre8audio secuenciador eurorack
# 144            None                                             roland
# 145          módulo                                    de sonidos korg
# 146          yamaha                                              p-125
# 147        elektron                                   model:cycles (no
# 148          orejas   rack neutron, pro 1, k2 .. (80hp)(fin stock)(env
# 149            xaoc                               moskwa ii+ ostankino
# 150            adam                                        hall sks 22
# 151    sintetizador                            piano korg n1 88 teclas
# 152            None                                             roland
# 153           vendo                                               korg
# 154          yamaha                                               None
# 155         teclado                                          nord wave
# 156            korg                                    kaossilator pro
# 157        novation                                  launchpad mkiii +
# 158          roland                                               None
# 159            None                                   orejas rack korg
# 160           erica                                    synths bassline
# 161            None                               roland vs 24000 cd +
# 162           funda                                  para teclado de 5
# 163            grey                                              audio
# 164          roland                                       tr-707 / hka
# 165          roland                            jx 3p + mode machine dt
# 166             4ms                                        dual loopin
# 167          roland              d110 – sintetizador digital + tarjeta
# 168          yamaha                                  rm50 rhythm sound
# 169            caja                                               None
# 170            None                                            doepfer
# 171          modulo    eurorack after later audio benjolin v2 + morcom
# 172            None                                           novation
# 173         waldorf            blofeld negro + arturia minibrute (para
# 174         arturia         rackbrute 6 unidades + bolsa de transporte
# 175             mpc  live mk1 + deck saver + ssd con samples del ko...
# 176            akai                                      xe8 midi drum
# 177          roland                                             system
# 178         twisted                                   electrons acid 8
# 179           pedal                           de efecto neo ventilator
# 180          befaco                                               None
# 181          clavia                                       nord lead 2x
# 182         doepfer                              a-106-1 xtreme filter
# 183         tarjeta                             srx02 concert piano de
# 184         instruo                                      troika triple
# 185          buchla                                         208c easel
# 186          módulo  de sonidos y efectos sm pro audio vmachine rep...
# 187      flightcase                    19" thon rack 5u eco ii compact
# 188          yamaha                                    vrc 103 sustain
# 189          ketron                                               None
# 190        dreadbox                                               lil’
# 191       electribe                                   esx-1sd (versión
# 192          oferta                             rebajado roland fantom
# 193            None                                  doepfer a-103 vcf
# 194           mutes                                    divkid eurorack
# 195             kit  controlador para leslies de 6 pines 122 y 147 ...
# 196         teenage                                        engineering
# 197            akai    s3000xl + tarjeta eb16 + zip omega + manuales y
# 198         teclado                          midi mpe linnstrument 200
# 199               u                                              warps
# 200    sintetizador                                arp avatar original
# 201            None                              akai s1000 hd (floppy
# 202            None                                             compro
# 203         arturia                                            minilab
# 204          roland                                                 tr
# 205         vermona                    mkiii drm1 version triggers con
# 206          roland                                               None
# 207          roland                    xp-80 + maleta aluminio (portes
# 208           vendo                                             roland
# 209          clavia                                       nord lead a1
# 210        komplete                      kontrol s61 mk2 y komplete 13
# 211         teenage                           enginering + decksaver +
# 212          kodamo            essence fm – sintetizador multitímbrico
# 213      synthstrom                                           deluge +
# 214       behringer                                   neutron + orejas
# 215            akai                                   s3000xl + unidad
# 216        elektron                                        analog four
# 217        maschine                                                 mk
# 218           doboz                          touch sensing note memory
# 219       frequency                                            central
# 220      eloquencer                                               midi
# 221         doepfer                                               None
# 222         soporte                                   teclado ultimate
# 223         eminent                          solina string ensemble mk
# 224        dreadbox                                               None
# 225          befaco                                              crush
# 226            None                                            teenage
# 227             jen                                            sx-2000
# 228          keytar                                     roland ax-edge
# 229         polyend                                               None
# 230        novation                                               None
# 231    sintetizador                                    roland boutique
# 232         arturia                                     keylab 49 mkii
# 233    kassutronics                                                vco
# 234             vco                     eurorack analogico magerit (tb
# 235          alesis                       sr-16 caja de ritmos 16 bits
# 236            nord                                      electro 6d 73
# 237      sequential                                            prophet
# 238           piano         eléctrico de escenario kawai mp-5 + fligth
# 239            None                                        mpc live2 x
# 240         critter                                            guitari
# 241          befaco                                                 vc
# 242            None                                          behringer
# 243             mfb                                               None
# 244         waldorf                                            blofeld
# 245          roland                                                 eg
# 246            boss                                            flanger
# 247          roland                                         v-synth gt
# 248           casio                                                 cz
# 249          varios                                               None
# 250          roland                                     mt-32 lista de
# 251      detachment                                               None
# 252           bastl                                    instruments bit
# 253        elektron                             analog rytm mkii con 8
# 254          roland                                                 tb
# 255          roland                                    verselab mv-1 +
# 256          squarp                                            pyramid
# 257             cme  uf7 controlador midi de 76 teclas teclado midi...
# 258        tarjetas                                  de memoria roland
# 259        tarjetas                         voice crystal 1+2 para sq2
# 260            None                                               None
# 261            korg                                              volca
# 262            korg   microkorg xl synthesizer-vocoder limited edition
# 263        elektron                                        analog rytm
# 264            akai                                            mpc one
# 265            moog                                      subsequent 37
# 266          libros                         de desarrollo de plugins y
# 267          roland                                                 tr
# 268          roland                                               None
# 269             arp                                            odyssey
# 270            akai                                               None
# 271            None                 placa principal motherboard roland
# 272    sintetizador                                 modular completo a
# 273             emu                        proteus 1 – sintetizador en
# 274          yamaha                        psr 3000 - librería para ni
# 275             tip                                            top mix
# 276            akai                     cd-rom sound library mpc2000xl
# 277            None                                           godspeed
# 278         doepfer                                    a-160 -5v clock
# 279            caja                                   de ritmos yamaha
# 280         teclado                                          korg ds-8
# 281            clon                             de mutable instruments
# 282         instruo                                               None
# 283       transient                                         modules 8s
# 284            korg                                         kossilator
# 285           virus                                                ti2
# 286          yamaha                              rm50 (versión rack de
# 287       frequency                                central bartos flur
# 288           piano                             digital yamaha p140 en
# 289        eurorack                                                vca
# 290           funda                   cubrepolvo a la medida para korg
# 291           vendo                                             toraiz
# 292        dreadbox                                               None
# 293      intellijel                                               None
# 294    amplificador                                        type leslie
# 295          yamaha                                               moxf
# 296        elektron                                        analog keys
# 297            None                                      compro roland
# 298            None                                  roland alpha juno
# 299            korg                                                 m1
# 300         nerdseq                                             y midi
# 301            lemi                                               midi
# 302           sound                    labs raagini digital electronic
# 303          filtro                                            6u uvcf
# 304         joystic                                               None
# 305    sintetizador                                               None
# 306         cirklon                                               None
# 307         teclado                                  maestro behringer
# 308           modal                                             cobalt
# 309        tarjetas              roland srx srx-05 supreme dance - 100
# 310          befaco                                               midi
# 311          roland                                                 tr
# 312            None                                             rhodes
# 313          órgano                                hammond the sounder
# 314          winter                                            modular
# 315        elektron                                       analog rythm
# 316           temps                                               None
# 317          roland                                  d-550 + bancos de
# 318          roland                                              vr700
# 319           kawai                                   vpc1 en perfecto
# 320    sintetizador                                  ver­mona drm1 mk3
# 321           bastl                           instruments micro granny
# 322            korg                                               sq10
# 323        elektron                                               None
# 324         teclado                                              kawai
# 325           piano                       digital kurzweil x-pro up 88
# 326        eurorack                              performance case 84hp
# 327           box11                                        cabinet mas
# 328       behringer                                           121 dual
# 329         ableton                                     push - primera
# 330         waldorf                                       iridium rack
# 331            None                                            shuttle
# 332      antimatter                                              audio
# 333           vendo                                          ms matrix
# 334          nektar                               impact lx49+ teclado
# 335         twisted                                          electrons
# 336           pedal                                       de expresión
# 337            None                                           orbit v2
# 338          yamaha                                           motif xs
# 339            akai                                              s6000
# 340         teclado                                               korg
# 341          leslie                                               None
# 342         doepfer                         a-106-5 sem filter special
# 343      sequential                                            prophet
# 344          roland                                                 kc
# 345            akai                                               None
# 346          access                                          virus ti2
# 347          roland                                               juno
# 348       endorphin                                              milky
# 349         doepfer                                  a 116 vc waveform
# 350            None                                              total
# 351        novation                                       launchkey 37
# 352          extras                                           kurzweil
# 353            None                                 presets bancos  de
# 354         teclado                                             yamaha
# 355            None                  laterales de aluminio para roland
# 356         quiklok       m-2  para teclado complementario. add-on for
# 357          befaco                                jumpskiff caja para
# 358          roland                                               None
# 359          alesis                                          andromeda
# 360        novation                                       bass station
# 361          yamaha                                              motif
# 362         waldorf                                              pulse
# 363          befaco                                               None
# 364           error                                                box
# 365            None                                      ginkosynthese
# 366           casio                                            vl-tone
# 367         hammond                                  c3 1961 chop down
# 368          analog                       xperience para yamaha modx y
# 369           volca                                               None
# 370            korg                                               None
# 371           erica                                synths black spring
# 372            None                                          akai ax73
# 373           casio                       vl-5 (vl1 poly) con lector y
# 374    sintetizador                                  nord lead virtual
# 375       behringer                                               wasp
# 376            moog                                             mother
# 377             mpc                                live para reparar o
# 378           piano                               electrónico celviano
# 379         waldorf                                       blofeld para
# 380         mochika                                                 x2
# 381        kurzweil                                               None
# 382            None                                     odyssey módulo
# 383        tarjetas                            expansion roland y korg
# 384        dreadbox                                               None
# 385          tascam                                          246 pinch
# 386    sintetizador                                             yamaha
# 387          roland                                                 tr
# 388     delptronics                           trigger man, ldb 2e, ldb
# 389            None                                         e-mu orbit
# 390          roland                                       vocoder plus
# 391            korg                                              volca
# 392            moog                                               None
# 393        cartucho                                         rom yamaha
# 394          modcan                                             triple
# 395           jomox                                            airbase
# 396            None                                               None
# 397         doepfer                                            a-130-2
# 398               m                                audio keystation 61
# 399            korg                                               m3-m
# 400          yamaha                            vrc 102 wind instrument
# 401            korg                                               None
# 402    secuenciador                            analógico befaco slicer
# 403     joranalogue                                           generate
# 404          eowave                                               None
# 405         strymon                                                aa1
# 406          módulo                         de sonidos pianobox usb de
# 407        dreadbox                                             erebus
# 408         vermona                                  qmi eurorack como
# 409          roland                 jx-3p - librería para ni kontakt y
# 410            korg                                    arp odyssey rev
# 411          roland                                             jd-800
# 412          modulo                                de sonido proteus 1
# 413         teclado                  controlador novation launchkey 61
# 414            moog                           moogerfooger mf-102 ring
# 415               e                                     mu xtreme lead
# 416          roland                                         r8 caja de
# 417             ems                              synthi filter rs 500e
# 418           modal                                             cobalt
# 419           vendo  roland superjupiter mks 80 + programmer mpg 80...
# 420            None                                compro korg pa4x 76
# 421          roland                                            fantom0
# 422          flight                                               case
# 423         hammond                                               None
# 424            akai                                                mpc
# 425            korg                                                01w
# 426            korg                                              sq-64
# 427         arturia                                             matrix
# 428    sintetizador                                             yamaha
# 429           virus                                             indigo
# 430        elektron                                              model
# 431         doepfer                                            a 110 1
# 432        analogue                                   solutions vostok
# 433        rebajado                   vendo mutable instruments clouds
# 434            korg                                           p3 piano
# 435          befaco                                     muxlicer + mex
# 436           vendo                                  kurzweil k2600 xs
# 437              se                                         vende king
# 438    sintetizador                                      tama techstar
# 439         arturia                                               None
# 440           noise           engineering basimilus iteritas alter bia
# 441            None                                               korg
# 442         hammond                                                xk3
# 443         soporte                                               None
# 444         waldorf                                     m sintetizador
# 445            korg                                         karma full
# 446         knobula                                               poly
# 447          yamaha                                             dx7s .
# 448            akai                                            advance
# 449             mfb                                            tanzbar
# 450        maschine                         plus. y komplete kontrol a
# 451            step      fader is a dual sequencer, here is a cv basic
# 452          yamaha  cp70 pianos para yamaha motif xf, moxf, montage y
# 453        dreadbox                                               None
# 454            None                                 squarp instruments
# 455         jaspers                                               None
# 456            None                                             sensel
# 457         teclado  korg m-1(pila nueva y revision completa en s.t...
# 458          befaco                                   knurlies m3 x100
# 459    sintetizador                       monofónico korg ms-10 de los
# 460  electrofaustus                                   blackfly + mooer
# 461            korg                                               None
# 462            korg                                              volca
# 463            None                                 kurzweil k2600 (76
# 464        proyecto                              eurorack inacabado 6u
# 465         hammond                                   a100  con leslie
# 466           casio                                          hz-600 sd
# 467         leploop                                         multicassa
# 468           casio                                             ct6000
# 469         waldorf                                               None
# 470          roland                                               None
# 471         soporte  teclados / sintetizadores k&amp;m spider pro. ...
# 472            midi                                            fighter
# 473        elektron                                             analog
# 474         arturia                                               None
# 475      perceptron                    atomo synth semimodular(tambien
# 476              mm                                               None
# 477          yamaha                              sy 77  +  tarjetas de
# 478              ik                 multimedia uno synth pro desktop +
# 479            None                                      mutable inst.
# 480            None                                     compro: alesis
# 481            None             busco alguno de estos sintes y caja de
# 482          roland                                                 sh
# 483            korg                                               pa4x
# 484        diskette                       sonidos para el sampler korg
# 485          roland                                           pn gr 50
# 486            korg                                             triton
# 487         sonidos          roland jupiter x/xm series y zenology pro
# 488            nord                                         stage 2 ha
# 489        ultimate                                          ax 48 pro
# 490             swr                                  big ben subwoofer
# 491          roland                                                 fa
# 492         mutable                                        instruments
# 493            dave                                              smith
# 494         módulos                         mutant hihats &amp; mutant
# 495         doepfer                                               None
# 496           grand                                   piano yamaha dgx
# 497           stand            digitakt + digitone (ultima unidad)(env
# 498          befaco                                               None
# 499         módulos                                eurorack + cables y
# 500        novation                           bass station ii + maleta
# 501          keytar                                        inalámbrico
# 502          yamaha                                               None
# 503        cassette                                    datos para korg
# 504        digitone                                               None
# 505            nano                        rand qu-bit módulo eurorack
# 506           casio                                  xw-p1 (con funda)
# 507         arturia                                               None
# 508            korg                                           radias -
# 509              tg                                                500
# 510            moog                                             system
# 511          befaco                                               None
# 512       sonicware                               elz_1 - sintetizador
# 513            korg                                              volca
# 514    sintetizador                                   teclado oberheim
# 515           piano                     rhodes 88 mark ii eighty eight
# 516           vendo                o cambio kurzweil pc3a8 + funda con
# 517       colección                            volca  (casi completa)+
# 518           kawai                                        card ram dc
# 519          access                                              virus
# 520          roland                                             fantom
# 521          roland                                               None
# 522        analogue                                  solutions leipzig
# 523         doepfer                                       a-199 spring
# 524          roland                                             pn d50
# 525         arturia                                           beatstep
# 526            nord                                         stage 2 ex
# 527          roland                                               juno
# 528            korg                                               None
# 529            eric                             synths pico system iii
# 530      procesador          de efectos yamaha emp-100 para guitarra /
# 531            korg                                               None
# 532     convertidor                             negativo a +5v nodrain
# 533            None                                        mfb tanzbar
# 534            akai                                            pro mpd
# 535       quasimidi                                               None
# 536           vendo                                               None
# 537         teclado                controlador ni komplete kontrol mk3
# 538            korg                    m3 - librería para ni kontakt y
# 539          access                                              virus
# 540            None                                               None
# 541          yamaha  rx-17. caja de ritmos desktop digital. posteri...
# 542            motu                                     midi timepiece
# 543             ajh                                 synth dual contour
# 544      eloquencer                                               None
# 545        cassette                                    datos para korg
# 546            None                             compro roland boutique
# 547        elektron                                        analog rytm
# 548    sintetizador                                   roland jupiter-4
# 549           placa                        sampler smp-r para kurzweil
# 550            None                                     con sonidos de
# 551            trío                              de controladores korg
# 552            icon                             ikeyboard 5x - teclado
# 553          roland                                         fa06 black
# 554        dreadbox                                               None
# 555            None                                      keystation 49
# 556            soma                         lyra 8 limited edition the
# 557    secuenciador                analogue systems rs-200 y quantiser
# 558          alesis                                               None
# 559            star                                 instruments synare
# 560            moog                                             dfam +
# 561     controlador                                               None
# 562          yamaha                                               None
# 563            korg                                               None
# 564          access                                              virus
# 565            moog                              voyager electric blue
# 566            korg                                         trident mk
# 567          maleta                                       sintetizador
# 568            None                        noise engineering basimilus
# 569          roland                        vp 03 + k-25m + decksaver +
# 570           rebel                                 technology chronos
# 571        hardcase                      con ruedas para teclado de 76
# 572          roland                                            jupiter
# 573            None   tarjeta korg wavestation wsc-3s synth &amp; time
# 574         teclado  kawai ph50. sonido 100% kawai k1 y 100% como k...
# 575         arturia                                               None
# 576           funda                   cubrepolvo a la medida para moog
# 577      sequential                                           circuits
# 578       behringer                                                 ms
# 579          yamaha                                        sk20 string
# 580             uno                                              synth
# 581            mini                      korg 700 fs ( tambien cambios
# 582       casiotone                                               None
# 583          órgano                        realejo de tubos totalmente
# 584            clon                             de mutable instruments
# 585           piano                     electrico vertical thomann dp-
# 586        material                            a la venta en moogchild
# 587         arturia                                 drumbrute impact +
# 588         teclado                                            midi 61
# 589             4ms                                                row
# 590        novation                                               None
# 591   audiothingies                                 ced tuner/afinador
# 592         teclado                   controlador midi / m-audio axiom
# 593          keylab                                             49 mk2
# 594            korg  pa2x - pa 3x  tarjeta ram 128mb  - manual de o...
# 595          leslie                                              760 n
# 596          yamaha                                       vrc 106 data
# 597            korg                                              volca
# 598            korg                                  minikorg 700 fs -
# 599            korg                                               None
# 600         thomann                                       keyboard bag
# 601          yamaha                                               None
# 602               2          buses y fuente para modular (la caja sale
# 603            None                                       2021 segunda
# 604             4ms                        ensemble oscillator ( black
# 605            korg                                           cx3 70's
# 606            akai                                                lpd
# 607         mutable                                        instruments
# 608          yamaha                                               None
# 609            None  compro sintetizadores antiguos averiados, no i...
# 610          clavia                                          nord lead
# 611            korg                                                drv
# 612         doepfer                        a-199 spring reverb vintage
# 613         arturia                                keylab essential 61
# 614        elektron                                          octatrack
# 615           erica                                         synths zen
# 616         doepfer                                      a-156 vintage
# 617            None  novation peak – sintetizador polifónico desktop +
# 618          roland                                            jupiter
# 619          módulo                                               u-he
# 620     studiologic                            vmk 176 plus midi piano
# 621            korg                                     05r/w – módulo
# 622            phat  analog iii para yamaha motif xs, motif xf, mox...
# 623          yamaha                                                 sy
# 624          roland                                         r8 caja de
# 625       behringer                                     960 sequential
# 626         arturia                         origin desktop en perfecto
# 627           acces                                              virus
# 628            nord                                          electro 6
# 629        taburete                                          de tambor
# 630            dave                                              smith
# 631          yamaha                                               None
# 632         arturia                                        minibrute 2
# 633           vendo                octatrack mk1+ tarjeta compactflash
# 634            elta              music solar 50 yellow + soft bag + 12
# 635         hammond                                      b3 portable +
# 636          befaco                                           chopping
# 637            moog                                          theremini
# 638        kurzweil                                                pc3
# 639            None                   k.o! &amp; po-24 office (teenage
# 640            None                                             audity
# 641           erica                         synths pico trigger patern
# 642        arranger                  roland e-5 síntesis l/a en estado
# 643        tarjetas                 roland sr-jv80 para sintetizadores
# 644           bastl       instruments rumburack 2 sintetizador modular
# 645      intellijel                                               None
# 646              c7    1  pianos para yamaha motif xf, moxf, montage y
# 647        elektron                                        analog four
# ...
# 569     380        346   pontevedra   2/8/2022  19/09/2022         ruipintado
# 570     135        364       girona   2/8/2022  05/09/2022           moog1406
# 571     100        533         lugo   2/8/2022  26/08/2022            galarga
# 572    5100       2736    barcelona   2/8/2022  31/08/2022             qbueno
# 573    None        669     gipuzkoa   2/8/2022  29/09/2022       mentemodular
# 574      60        294     alicante   2/8/2022  26/08/2022             stalvs
# 575    2300       1924     valencia   2/8/2022  16/08/2022           abstrack
# 576      10        204       madrid   2/8/2022  30/08/2022         grizzvolga
# 577    1790        350       madrid   2/8/2022  02/09/2022               cobe
# 578     280        355        cádiz   2/8/2022  28/08/2022            alinter
# 579    1375       1460       madrid   2/8/2022  01/09/2022             logan3
# 580     400       1052      granada   2/8/2022  27/09/2022     arpeggiatornik
# 581    1890        544       girona   2/8/2022  14/09/2022           moog1406
# 582     375        915       girona   2/8/2022  02/09/2022           moog1406
# 583    3000       1010        cádiz   2/8/2022  22/08/2022           organero
# 584     115        200        cádiz   2/8/2022  29/08/2022              moogi
# 585     300        166    barcelona   2/8/2022  11/09/2022              felix
# 586  111111      18976       madrid   2/8/2022  18/09/2022         synthdrome
# 587     200        127         león   2/8/2022  09/09/2022         tangential
# 588      40        104       murcia   2/8/2022  25/09/2022             tellie
# 589     140        378    tarragona   2/8/2022  29/08/2022              gorum
# 590     150        400    barcelona   2/8/2022  24/08/2022        voxmechanic
# 591      80        230       madrid   2/8/2022  21/08/2022             insula
# 592      90        290       málaga   2/8/2022  10/08/2022             sergey
# 593     330        950       madrid   2/8/2022  29/08/2022          minahonda
# 594      50         96      córdoba   2/8/2022  17/09/2022           sintexia
# 595     825       1794     zaragoza   2/8/2022  25/08/2022           windbass
# 596      59        268       girona   2/8/2022  26/09/2022           moog1406
# 597     130         90       málaga   2/8/2022  23/09/2022        caradusanto
# 598    1969        436       girona   2/8/2022  30/08/2022           moog1406
# 599     650       1119    barcelona   2/8/2022  23/09/2022            jordi61
# 600      15        824    barcelona   2/8/2022  30/08/2022            uprefer
# 601     280       1503    barcelona   2/8/2022  30/08/2022              drtek
# 602     145       4404    barcelona   2/8/2022  25/08/2022       gatovertical
# 603     900        157       murcia   2/8/2022  18/09/2022             garcía
# 604     295        174    barcelona   2/8/2022  03/08/2022             albert
# 605     600        138       madrid   2/8/2022  29/09/2022          buenmambo
# 606      25        130      badajoz   2/8/2022  21/09/2022         emilguitar
# 607     255       1179        araba   2/8/2022  25/08/2022              jabas
# 608     500        413       madrid   2/8/2022  29/08/2022        bastarreche
# 609    None       2350       madrid   2/8/2022  18/09/2022         synthdrome
# 610     930       3249       málaga   2/8/2022  23/09/2022         solotronik
# 611      95        772       girona   2/8/2022  12/08/2022           moog1406
# 612     100        154     valencia   2/8/2022  31/08/2022         selimorgan
# 613     225       1060       madrid   2/8/2022  26/09/2022            yoquese
# 614     950        124     valencia   2/8/2022  26/09/2022         angelmahon
# 615     470        128       madrid   2/8/2022  28/09/2022              david
# 616      95        316       girona   2/8/2022  25/09/2022           moog1406
# 617     950        391       madrid   2/8/2022  28/08/2022       alcachofazul
# 618     980       4051    tarragona   2/8/2022  25/08/2022               vjsj
# 619     245        208     alicante   2/8/2022  31/08/2022              sergi
# 620     180        295       málaga   2/8/2022  19/08/2022              diyer
# 621     150        174       madrid   2/8/2022  27/09/2022       alcachofazul
# 622      12       1112       madrid   2/8/2022  13/08/2022              bicho
# 623     220        277    barcelona   2/8/2022  12/09/2022             impact
# 624     200        452       girona   2/8/2022  14/08/2022           moog1406
# 625     110        378        cádiz   2/8/2022  29/08/2022              moogi
# 626    1590       2139       lleida   2/8/2022  24/08/2022       styl_brother
# 627     600        614     asturias   2/8/2022  17/08/2022         maldito_db
# 628    1400        212       madrid   2/8/2022  30/08/2022              joshy
# 629      35        627    barcelona   2/8/2022  29/08/2022               tana
# 630    1250        508       girona   2/8/2022  08/08/2022           moog1406
# 631     280        612   pontevedra   2/8/2022  24/08/2022              jaime
# 632     489        752       girona   2/8/2022  25/09/2022           moog1406
# 633     750        488     alicante   2/8/2022  05/08/2022           arkostek
# 634    1650        402       girona   2/8/2022  28/08/2022           moog1406
# 635    6000        814       madrid   2/8/2022  05/09/2022                doc
# 636     169        270       girona   2/8/2022  14/09/2022           moog1406
# 637     250        546     valencia   2/8/2022  20/08/2022             roy242
# 638     200        355         jaén   2/8/2022  20/09/2022            klavius
# 639     100        642      badajoz   2/8/2022  22/08/2022              edulo
# 640     295        520       girona   2/8/2022  24/08/2022           moog1406
# 641      89        646       girona   2/8/2022  23/09/2022           moog1406
# 642      90        443    barcelona   2/8/2022  27/08/2022          shad0wfax
# 643      70       2970       madrid   2/8/2022  20/08/2022              luisg
# 644    2150       1958       madrid   2/8/2022  19/08/2022          albornozz
# 645     200        432       girona   2/8/2022  20/09/2022           moog1406
# 646      19       2377       madrid   2/8/2022  15/08/2022              bicho
# 647    1100        740       girona   2/8/2022  18/09/2022           moog1406
# 648    1500        575     valencia   2/8/2022  09/08/2022              jesus
# 649     399        662    tarragona   2/8/2022  25/08/2022               jmgg
# 650     550        371    barcelona   2/8/2022  31/08/2022                f77
# 651     270        742     valencia   2/8/2022  13/08/2022         medapaloel
# 652     250        461    cantabria   2/8/2022  24/09/2022          kichiilik
# 653     245        128         None   2/8/2022  15/09/2022              edgar
# 654     150        741      sevilla   2/8/2022  15/08/2022             paugui
# 655     150        640    barcelona   2/8/2022  17/08/2022          traupiano
# 656     130        601    tarragona   2/8/2022  29/08/2022              gorum
# 657      60        103    cantabria   2/8/2022  31/08/2022              mario
# 658     150        916     baleares   2/8/2022  19/08/2022               inxu
# 659     350        294       madrid   2/8/2022  21/09/2022        aspiktongue
# 660     175        266       girona   2/8/2022  25/09/2022           moog1406
# 661     880        314       madrid   2/8/2022  22/08/2022          vulgatron
# 662    1000        832    barcelona   2/8/2022  30/08/2022           bluewave
# 663     220       2562    barcelona   2/8/2022  26/08/2022          thru_zero
# 664     399        209      sevilla   2/8/2022  30/09/2022          jdcoopers
# 665     425       1117    barcelona   2/8/2022  11/08/2022              supro
# 666     239        465       girona   2/8/2022  08/08/2022           moog1406
# 667     329        578       girona   2/8/2022  12/08/2022           moog1406
# 668     150        322       madrid   2/8/2022  06/09/2022        bastarreche
# 669     850        206    barcelona   2/8/2022  25/09/2022              emusa
# 670    1200       1430       madrid   2/8/2022  20/08/2022         mercurioso
# 671     220        301      granada   2/8/2022  13/09/2022            disface
# 672     150        608       girona   2/8/2022  08/09/2022         thebadbeat
# 673     550        531       lleida   2/8/2022  16/09/2022           minimilk
# 674    1700        349      almería   2/8/2022  30/08/2022               dave
# 675      90        164    barcelona   2/8/2022  08/09/2022               xavi
# 676      60        392         None   2/8/2022  24/09/2022         sergiommms
# 677      99         16       madrid   2/8/2022  30/09/2022            studios
# 678     150        244       madrid   2/8/2022  14/08/2022                mrf
# 679      90        165       málaga   2/8/2022  03/08/2022          metrolike
# 680     475        596       girona   2/8/2022  13/09/2022           moog1406
# 681     850       1508     zaragoza   2/8/2022  26/08/2022           windbass
# 682     309        405       girona   2/8/2022  25/09/2022           moog1406
# 683    1900         59    cantabria   2/8/2022  01/10/2022            amseven
# 684     400        523   pontevedra   2/8/2022  24/08/2022              souto
# 685    None        291     alicante   2/8/2022  18/08/2022           sanwiche
# 686    None        231         None   2/8/2022  12/08/2022           djcanosa
# 687      49        592       girona   2/8/2022  08/08/2022           moog1406
# 688      12       1515       madrid   2/8/2022  13/08/2022              bicho
# 689      20        134       madrid   2/8/2022  18/08/2022         polypodium
# 690    1400        436       madrid   2/8/2022  07/09/2022              gonso
# 691     750        850       madrid   2/8/2022  27/08/2022              aferr
# 692      70        972    barcelona   2/8/2022  27/08/2022          shad0wfax
# 693      75        266    cantabria   2/8/2022  24/09/2022          kichiilik
# 694     140        367      badajoz   2/8/2022  22/08/2022              edulo
# 695     329        452       girona   2/8/2022  24/09/2022           moog1406
# 696     110        390       madrid   2/8/2022  27/08/2022        aspiktongue
# 697      75        662    barcelona   2/8/2022  30/08/2022              drtek
# 698    1250       1618       toledo   2/8/2022  29/08/2022            arpegio
# 699     700        240      sevilla   2/8/2022  24/08/2022     tallersonico49
# 700     485        909    cantabria   2/8/2022  29/08/2022         yosualogan
# 701    None        138     baleares   2/8/2022  23/09/2022               maxi
# 702      24       5479       madrid   2/8/2022  13/08/2022              bicho
# 703     300        374  guadalajara   2/8/2022  20/08/2022            puertas
# 704    1850       1295     zaragoza   2/8/2022  28/08/2022           windbass
# 705     200        665    barcelona   2/8/2022  02/08/2022       rammsysounds
# 706      15       2435        cádiz   2/8/2022  04/08/2022             fugazi
# 707     350        532     alicante   2/8/2022  23/09/2022              bauzá
# 708     620        642       girona   2/8/2022  03/09/2022           moog1406
# 709      99        533       girona   2/8/2022  27/08/2022           moog1406
# 710      90        224   pontevedra   2/8/2022  30/08/2022           øliveira
# 711     390        314    barcelona   2/8/2022  27/09/2022               deka
# 712      80        274      córdoba   2/8/2022  28/08/2022           sintexia
# 713      85        370       girona   2/8/2022  26/09/2022           moog1406
# 714     750       1104        araba   2/8/2022  23/08/2022            vicen51
# 715      75        394    barcelona   2/8/2022  15/09/2022          radioskaf
# 716    1300         53    cantabria   2/8/2022  01/10/2022            amseven
# 717    4000        176    barcelona   2/8/2022  02/09/2022            jordi61
# 718      70        344       girona   2/8/2022  28/08/2022           moog1406
# 719     400       1333     valencia   2/8/2022  29/08/2022          belenguer
# 720     198        530       girona   2/8/2022  08/08/2022           moog1406
# 721      13        118         None   2/8/2022  30/08/2022           rembukai
# 722      50        339       girona   2/8/2022  08/08/2022           moog1406
# 723     180        236       madrid   2/8/2022  27/08/2022              joule
# 724     240        624     valencia   2/8/2022  23/08/2022              ramos
# 725     172        193    barcelona   2/8/2022  07/08/2022              jordi
# 726     350        577       madrid   2/8/2022  29/09/2022            edaurdo
# 727     300        197     baleares   2/8/2022  06/09/2022              dbxer
# 728     175        518    barcelona   2/8/2022  15/09/2022          radioskaf
# 729    1365        538       girona   2/8/2022  07/08/2022           moog1406
# 730      35        276    barcelona   2/8/2022  17/08/2022          traupiano
# 731      80        947       madrid   2/8/2022  01/09/2022           siropene
# 732    1200        358       madrid   2/8/2022  28/08/2022         grizzvolga
# 733     519        580       madrid   2/8/2022  25/08/2022             alvmad
# 734      35        134     alicante   2/8/2022  28/09/2022          stanislao
# 735    1449        988       girona   2/8/2022  08/08/2022           moog1406
# 736      40        194     valencia   2/8/2022  07/08/2022           balaguer
# 737    1775        363       málaga   2/8/2022  29/08/2022             rbrosm
# 738      30        184      córdoba   2/8/2022  31/08/2022             zyon35
# 739    None       4087     alicante   2/8/2022  10/09/2022            deesser
# 740    2495        833       girona   2/8/2022  21/08/2022           moog1406
# 741     199       1562       cuenca   2/8/2022  05/09/2022             bloson
# 742     295        498       girona   2/8/2022  20/08/2022           moog1406
# 743     220        586       madrid   2/8/2022  16/09/2022    javierdepascual
# 744     699        946      sevilla   2/8/2022  15/08/2022             paugui
# 745     100        350      granada   2/8/2022  22/08/2022            disface
# 746      12        159    tarragona   2/8/2022  09/09/2022             radius
# 747      20        160    barcelona   2/8/2022  19/09/2022            modular
# 748     190        216     valencia   2/8/2022  25/09/2022          jorge8989
# 749     180        460       girona   2/8/2022  22/08/2022           moog1406
# 750    None      16610         lugo   2/8/2022  26/08/2022            galarga
# 751     100        244       málaga   2/8/2022  31/08/2022             amador
# 752    None        464      córdoba   2/8/2022  01/09/2022             zyon35
# 753    1490       1808       girona   2/8/2022  08/08/2022           moog1406
# 754     140        268       huelva   2/8/2022  31/08/2022                 ra
# 755    None       1149       madrid   2/8/2022  08/09/2022              oscar
# 756    1800       2242        araba   2/8/2022  23/08/2022            vicen51
# 757      35       1450       madrid   2/8/2022  25/08/2022           int3rc0m
# 758     145        890       madrid   2/8/2022  26/09/2022            yoquese
# 759     490        354        cádiz   2/8/2022  28/08/2022            alinter
# 760     650        745         None   2/8/2022  24/09/2022         sergiommms
# 761     600       1124       madrid   2/8/2022  30/09/2022           erissoma
# 762     150        134       madrid   2/8/2022  27/09/2022       alcachofazul
# 763     320        306     alicante   2/8/2022  09/09/2022           arkostek
# 764    None        191       madrid   2/8/2022  29/08/2022     creativestudio
# 765     450        248    barcelona   2/8/2022  30/08/2022             fzappy
# 766     490        938       girona   2/8/2022  08/08/2022           moog1406
# 767     300        606      almería   2/8/2022  30/08/2022               dave
# 768     130        390         None   2/8/2022  14/08/2022    davidfunkdacion

# %%
df['expires'].isnull().sum() # a row with no values
# Out:
# 0

# %%
df[df['expires'].isnull()]
# Out:
# Empty DataFrame
# Columns: [brand, model, price, times_seen, city, scrap_date, expires, user]
# Index: []

# %%
df.dropna(inplace=True) # we delete the row

# %%
df.to_csv('df_hispasonic.csv'.format(date=date_scrapped), index = False)

# %%
hispasonic = pd.read_csv("/htmls/fixed_feliz_cumple_dataframe.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2d3d48fd4f7f> in <module>
# ----> 1 hispasonic = pd.read_csv("/htmls/fixed_feliz_cumple_dataframe.csv")
#
# ~/anaconda3/envs/dataquest/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/envs/dataquest/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/anaconda3/envs/dataquest/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/anaconda3/envs/dataquest/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/anaconda3/envs/dataquest/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /htmls/fixed_feliz_cumple_dataframe.csv does not exist: '/htmls/fixed_feliz_cumple_dataframe.csv'

# %%
hispasonic
# Out:
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic
