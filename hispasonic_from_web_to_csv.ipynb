# %% [markdown]
# # Hispasonic (from web to csv)
#
#
# <br>
#
# A website about musical instruments, recording stuff, and everything related to the world of music. In this place there is also a second-hand market where users sell, buy, change or give their musical instruments.
#
# In this first part of the project focuses on obtaining relevant ad information, the category I have focused on has been the one that refers to electronic musical instruments.
#
# <br>
#
# Before start obtaining information, the first thing we must know is to understand how the announcement page is organized.
#
# ***
#
# - *Image of one of the pages of hispasonic*
#
#
# ![hispa_1e.png](hispa_1e.png)
#
# <br>
#
# <br>
#
# We can see several important things:
#
# - Selected category is on "teclados y sintetizadores".
#
# - Know the number of pages that we are going to analyze to get **all the ads**.
#
#
#
# ## 1. Function library loading.

# %%
import requests               # Is an elegant and simple HTTP library for Python
from bs4 import BeautifulSoup # library for pulling data out of HTML and XML files
import re                     # regular expressions operations
import pandas as pd           # A fast, powerful, flexible and easy to use open source data analysis tool
import os                     # A versatile way to use operating system-dependent functionality.
import datetime as dt         # module for manipulating dates and times.
import time

pd.set_option("display.max_rows", None)

# %% [markdown]
# ### First contact
#
# First of all we must to know if we have a proper response from the server.

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# These are the main possible answers we can get from the server:
#
# |||
# |:--|:--|
# |**1xx informational response –** |the request was received, continuing process|
# |**2xx successful –** |the request was successfully received, understood, and accepted|
# |**3xx redirection –** |further action needs to be taken in order to complete the request|
# |**4xx client error –** |the request contains bad syntax or cannot be fulfilled|
# |**5xx server error –** |the server failed to fulfil an apparently valid request|

# %%
# Enter the address and see the response from the server.

url = "https://www.hispasonic.com/anuncios/teclados-sintetizadores"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %% [markdown]
# #### *<Response [200]> means correct connection.*
#
# ## 2. Number of pages to analyze.
#
# Once we have communication, we have to know how to determine how to obtain the **total number of pages** to scrap.
#
# In each of the pages are the ads that we want to analyze, so it is very important to know how to obtain that value, since it can vary depending on the number of ads that are offered.
#
# ![cantidad_iteraciones.png](cantidad_iteraciones.png)
#
# The item is identified as follows.
#
#        'ul', class_='pagination'
#
# <br>
#
# It means 'unordered list' with a class name called `pagination`.
#
#
# To determine the number of iterations, that is, the number of pages on which to extract the information, I must:
#
# - Find this element inside the html content.
#
# - Know the value.
#
# We will do this with *Beautifulsoup* use to extract the contents of an element.

# %%
soup = BeautifulSoup(page.content, 'html.parser')
# soup <- all site code

# %% [markdown]
# So inside `soup` variable we are looking for `'ul', class_='pagination'`
#
# The following code refers to:
#
# - **first 5 links of the pages**
#
# - the **next 10 pages** and the **last one**, which is the one that interests us.
#
# Save it in a variable, called `unordered_list`

# %%
unordered_list = soup.find('ul', class_='pagination') # into variable
unordered_list = unordered_list.contents # tag's children available in a list called .content. from variable to list
unordered_list
# Out:
# ['\n',
#  <li>
#  <span class="selected">1</span>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina2" rel="next">2</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina3">3</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina4">4</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina5">5</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina11" title="Siguientes 10 páginas">›</a>
#  </li>,
#  '\n',
#  <li>
#  <a href="/anuncios/teclados-sintetizadores/pagina34" title="Última página">»</a>
#  </li>,
#  '\n']

# %% [markdown]
# ### 2.1 Exploring `unordered_list` variable.
#
# We can see that it is a list therefore know what its length is and know in what position the elements that compose it are.

# %%
len(unordered_list) # number of elements
# Out:
# 15

# %%
unordered_list[0] # first element
# Out:
# '\n'

# %%
unordered_list[-1] # last element
# Out:
# '\n'

# %%
unordered_list[-2] # this is the one I'm interested in
# Out:
# <li>
# <a href="/anuncios/teclados-sintetizadores/pagina34" title="Última página">»</a>
# </li>

# %% [markdown]
# ### 2.2 How to get the value number from `unordered_list`?
#
# <br>
#
# As what I need is to access the value within the list the strategy that will be the following:
#
# - Convert the list to a text string.
#
# - Filter the characters that correspond to numeric values, the max ones.
#
# - Convert those numeric characters to numbers
#
# I will convert the contents of the list into a text string and have the numeric characters extracted together with highest values by using regular expressions.
#
# Converting the content of `paginas` into a text string.

# %%
test = str(unordered_list[-2])
test
# Out:
# '<li>\n<a href="/anuncios/teclados-sintetizadores/pagina34" title="Última página">»</a>\n</li>'

# %% [markdown]
# `extractMax` A function that gets the numbers contained in the lowercase text and converts them to integer numbers.

# %%
def extractMax(input):
     # get a list of all numbers separated by 
     # lower case characters 
     # \d+ is a regular expression which means
     # one or more digit
     # output will be like ['100','564','365']
    numbers = re.findall('\d+',input)
     # now we need to convert each number into integer
     # int(string) converts string into integer
     # we will map int() function onto all elements 
     # of numbers list
    numbers = map(int,numbers)
    return max(numbers) # devuelve un entero

# %%
page_numbers = extractMax(test)
page_numbers
# Out:
# 34

# %% [markdown]
# We already have the number of pages that we will have to analyze.
#
# ***

# %% [markdown]
# ## 3. Getting and save all links (ads and not ads)
#
# Once we have the number of pages in which we must extract the ads, the next step is to extract those ads from each of the pages looking inside the code of each of them.
#
# So what we have to do is:
#
# - Extracting everything that is a link.
#
#
# - From the links extracted, the most important thing is get the final number which is the way to identify those who are ads and what are not.

# %%
links_ads = []        # all the ads on the page
listado_enlaces = []  # all the links on the page

pattern="([0-9]{4,9})" # filtering all links with number, that mean choosing the page number related to and ad.

for pagina in range(page_numbers, 0, -1): 
    url = "https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina{pagina}".format(pagina=pagina)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    
    for link in soup.find_all('a'):       # filter everything that is a link on soup variable
        links_ads.append(link.get('href'))
        fecha = soup.find_all('span', class_='miniicon miniicon-date')
        
    
    for s in links_ads:                   # of those links what I do is stay with what ends in number
        if re.search(pattern, s):
            listado_enlaces.append(s)
# Out:
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina34
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina33
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina32
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina31
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina30
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina29
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina28
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina27
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina26
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina25
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina24
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina23
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina22
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina21
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina20
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina19
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina18
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina17
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina16
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina15
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina14
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina13
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina12
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina11
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina10
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina9
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina8
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina7
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina6
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina5
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina4
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina3
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina2
# https://www.hispasonic.com/anuncios/teclados-sintetizadores/pagina1

# %% [markdown]
# #### This is a small sample of the contents of the lists
#
# It can be seen as being links in both cases, in the first we only have links that do not interest us.

# %%
links_ads[5:20] # example: row 5 to 20 of everything is a link on soup variable
# Out:
# ['/musica',
#  '/productos',
#  '/anuncios',
#  '/anuncios/todo',
#  '/anuncios/todo/f/compra-protegida',
#  '/anuncios',
#  '/anuncios/compraventa',
#  '/anuncios/teclados-sintetizadores',
#  '/anuncios/todo/f/compra-protegida',
#  '/compra-protegida',
#  '/anuncios/todo/f/compra-protegida',
#  '/index.php?controller=ad&action=new_ad_form',
#  '/anuncios/teclados-sintetizadores',
#  '/anuncios/teclados-sintetizadores/pagina24',
#  '/anuncios/teclados-sintetizadores/pagina30']

# %% [markdown]
# However in the second list `listado_enlaces` what we have are the links we want to get in each of the pages.

# %%
listado_enlaces[5:20] # example: of those links what I do is stay with what ends in number
# Out:
# ['/anuncios/doepfer-a189-1/989203',
#  '/anuncios/dopefer-152/989112',
#  '/anuncios/dopefer-152/989112',
#  '/anuncios/error-box-adm03/989038',
#  '/anuncios/error-box-adm03/989038',
#  '/anuncios/befaco-crush-delay/988293',
#  '/anuncios/befaco-crush-delay/988293',
#  '/anuncios/qu-bit-pulsar/986999',
#  '/anuncios/qu-bit-pulsar/986999',
#  '/anuncios/roland-pn-d50-02/986830',
#  '/anuncios/roland-pn-d50-02/986830',
#  '/anuncios/kawai-card-ram-dc-16/986822',
#  '/anuncios/kawai-card-ram-dc-16/986822',
#  '/anuncios/roland-sonic-cell-tarjeta-sonido-envio-incluido/983405',
#  '/anuncios/roland-sonic-cell-tarjeta-sonido-envio-incluido/983405']

# %% [markdown]
# ## 3.1 Cleaning links.
#
# Taking a look into `listado_enlaces` it is striking that there are links that are repeated and we need to do a couple of things.
#
#             '...
#             '/anuncios/korg-vocoder-vc10/866556',
#              '/anuncios/korg-vocoder-vc10/866556',
#              '/anuncios/polyend-tracker/1057403',
#              '/anuncios/polyend-tracker/1057403',
#              '/anuncios/trajetas-teclados/949462',
#              '/anuncios/trajetas-teclados/949462',
#                                              ...',
#
#
#
# - 1. Extract the brand name from the url using regular expressions.
#
# <br>
#
#
# ![regex_expression.png](regex_expression.png)
#
# <br>
#
#
# - 2. Filter the amount of url repeated.
#
# <br>
#
# To get **not repeated url**, we will make a filter with a dictionary.
#
# The main idea is filter the url repeated as `key` and asign it a synth brand for this unique url as `value`.

# %%
os.chdir('/home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls') # folder to save htmls.

# %%
diccionario_enlaces = {} # dict

listado_marcas = []      # synth_brand

patron_marca = "((?<=anuncios\/)[1-9][a-z]{1,})|((?<=anuncios\/)[a-z]{1,})" # filter brand regex

for enlace in listado_enlaces:
    if enlace not in diccionario_enlaces:  
        try:
            marca = re.search(patron_marca, enlace).group()
            diccionario_enlaces[enlace] = marca
        except AttributeError:
            #marca = re.search(patron_marca, enlace)
            pass # voy a ver si funciona, lo que aprendi del try except

# %% [markdown]
# With the dictionary that we have just created we are going to download all the ads locally.
#
# The reason is not to overload the server and run the risk of being banned.

# %% [markdown]
# ## 3.2 Download all the ads.
#
#
# To avoid the inconvenience that would suppose the overload of the server, we will download all the ads in local mode adding a delay in the download time. In this way we will work with more comfort.

# %%
# %%time

main_path='https://www.hispasonic.com'
local_path = '/home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/'

for enlace in diccionario_enlaces:
    time.sleep(1)                           # Sleep for 3 seconds
    page = requests.get(main_path + enlace) # https://www.hispasonic.com/anuncios/polyend-tracker/1057403.html
    #print(main_path + enlace)
    enlace = enlace.split("/")              # filter for extracting
    enlace= enlace[2]                       # name ad

    with open(local_path + enlace + '.html',"w+") as f:
        f.write(page.text)
        
    print(local_path + enlace)
# Out:
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-fa-08
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modcan-triple-oscilator
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-a189-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dopefer-152
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/error-box-adm03
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-crush-delay
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/qu-bit-pulsar
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-pn-d50-02
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kawai-card-ram-dc-16
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-sonic-cell-tarjeta-sonido-envio-incluido
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-controlador-midi-cme-xkey-25-silver-cme-supernova-transportecme-xkey-25-silver-25-
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/busco-compro-cambio-roland-mc-505-groovebox-despiece
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-microsampler
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-vc-adsr
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-tb-3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/transient-8s-secuenciador-eurorack-8-pasos
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-pearl-river-pd180d
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-eurorack-synthesis-technology-e560-deflector-shield
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tascam-246-pinch-roller
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/soniccell-roland
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-vocoder-vc10
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-midi-m-audio-axiom-pro-49
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-eg-101
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-118-noise
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-chopping-kinky
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/grey-audio-3340
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/twisted-electrons-cells
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/eminent-solina-string-ensemble-mk-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-vrc-102-wind-instrument-group
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-rampage
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/voodoo-lab-pedal-power-2-plus
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-demora
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/midi-fighter-3d
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-pn-d50-00
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-s6000-v2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/drawner-mx-30
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-vrc-103
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-matrixbrute
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arp-odyssey-mkiii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/synthesizerscom-q128-switch
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-little-phatty-stage-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-vrc-106-data-rom
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-yamaha-mo6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-vrc-101
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-master-group
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-chopping-kinky
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tip-top-mix-z
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/clavia-nord-lead-a1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-arp-odyssey
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-110-1-vco
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/erica-synths-bass-drums
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kurzweil-forte-88-teclas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-drv-2000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/varios-modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/frequency-central-bartos-flur-ii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-muxlicer
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-eurorack-corsynth-c105e-vc-noise-fi-maquine
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nord-micro-wave
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-wasp-deluxe
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/endorphines-airstreamer
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/endorphines-godspeed
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/syntrotek-fold
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/transient-modules-8s-sequencer
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tubeohm-smr4p
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-lich
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/marantz-av8801
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nuevo-estrenar-soporte-2-teclados-quicklok-sl-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/oportunidad-teclado-roland-exr-7-interactive-arranger-poco-uso
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/winter-modular-eloquencer
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/eurorack-case-70hp-model-d
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/ultimate-ax-48-pro-b
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/endorphines-total-recall
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-tb-3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kurzweil-k2000r
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-system-1m
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-matrixbrute-noir
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-xv-5080
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/flight-case-gator
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/organo-korg-cx-3-flightcase-medida
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-116-vc-waveform-processor
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-d-50
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/erica-synths-dual-fx
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/maschine-plus
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kawai-ca-91
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/ladik-q-010-easy-quantizer
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-pn-gr-50-01
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/waldorf-blofeld-black-edition
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/intellijel-rubicon
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/intellijel-metropolis
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/filtro-estereo-eurorack-cwejman-dmf-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sequenz-standard-m-sv-medium
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/frequency-central-chronograf
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/organo-lowrey-genie-tenie
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/compro-modulos-percusion-pearl-sc-20-sc-40-drum-x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/monome-40h
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/komplete-mkii-s49
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-jupiter-80-flight-case-medida
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kenton-pro-dcb-roland-juno-60-jupiter-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-electrico-yamaha-ypt-200
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/waldorf-pulse-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-bass-station-rack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-korg-ds-8-1987
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-88-contrapesadas-roland-hp1800s
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/acordeon-stela-34-teclas-60-bajos
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-t3-workstation
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-tr-8s
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-jupiter-xm
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/synth-pro
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/proteus-2-mu-systems-16-bit-multi-timbral-digital-sound-module-xr
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nord-rack-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-160-5v-clock-multiplier
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-156-vintage-edition
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-tb-03
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/hammond-b3-portable-leslie
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/paratek-neon-black
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-kickall
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-impulse-25
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-sv-1-88-teclas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-mother-32
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/adam-hall-sks-22-xb
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vermona-drm-mkii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-todos-modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/icon-ikeyboard-5x-teclado-midi
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-keylab-essential-61-black
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-kossilator-pro
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-microlab
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/bheringer-umx-61
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/op-z-teenage-engineering
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-tr-08
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/electrovoice-fx70-emulador-leslie-rack-igual-dynacord-dls223
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-yamaha-sy22
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tiptop-z-dsp
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/cambio-access-virus-ti-bancos-comerciales-2018
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/varios-modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/lemi-midi-mixer
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-prodigy
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-mc-505-groovebox
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/compro-sintetizadores-antiguos-averiados-no-importa-estado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/material-venta-moogchild-synthdrome
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-trident-mk-i
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-yamaha-psr-e263
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/axoloty-completo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-mpk-88
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-analog-four-mkii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-varios-modulos-make-noise-mutable-cwejman-estado-impecable
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-fantom0-7
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-sg01v
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-grandmother-dark-decksaver
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-sp250-nuevo-uso-atril-banqueta
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nord-electro-hp-5
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/waldorf-blofeld-reparar
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-digitone
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sequential-circuits-pro-one
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/jen-sx-2000-synthetone
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-pro-mpd-32
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-mpk61
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/boss-flanger-bf3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mxr-analog-chorus
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-kawi
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/op-lab
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-sy77
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/swissonic-easykey-25
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-keylab-61-mkii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/waldorf-pulse-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-521
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mutable-instruments-grids-modular-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dreadbox-nyx
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/synth-tech-motm-490
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-ex5
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-moxf-6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mpc-live-reparar-piezas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-deepmind-12d
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-polysix
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-sy-55
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/busco-tintes-caja-ritmo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-dx7s
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-apc-key25-buen-estado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/keytar-inalambrico-alesis
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/intellijel-buff-multiple
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dsi-mono-evolver
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/quasimidi-sirius
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-triton-le
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-d-550
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-enhancia-neova-3-unidades-disponibles
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/antonus-step-brother
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-fantom-s-61
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/lote-10-revistas-keyboard-musica-tecnologia
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/soma-lyra-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nerdseq-midi-expander
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-casio-vintage-sk-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-roland-jupiter-4-compuphonic
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sequential-prophet-6-desktop
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-boutique-tr-08-erica-synths-pico-vco2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/cirklon-v10
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/pioneer-cs3070
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-fantom-6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/controlador-midi-usb-m-audio-oxygen-88-teclas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-beatstep-pro
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/goodmans-mezzo-speakers
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/banananuts-pack-befaco-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/bastl-instruments-bit-ranger
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/waldorf-blofeld-negro-arturia-minibrute-reparar
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/electrofaustus-blackfly
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/emu-sp1200-extras
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-digitone
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/op-1-2021-segunda-generacion
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/eurorack-case-aluminio-3-filas-85hp-yarns-mutable-instruments
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-roland-boutique-02
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/peoyecto-eurorack-inacabado-6u-84hp
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-pa2x-pa-3x-tarjeta-ram-128mb-manual-operario-korg-pa2x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/alesis-qx49-controlador-midi
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-triton-extreme-88
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-01w-fd
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/pedal-efecto-neo-ventilator-ii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-origin
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/summit-audio-100
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/asm-hydrasynth
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/analogue-systems-rs390
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/km-18860-spider-pro-si
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-keystep
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mm-micromust
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mu-xtreme-lead-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/bastl-instruments-micro-granny-20
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/twisted-electrons-acid-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sensel-morph
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/ableton-push-primera-version
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-midi-de
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/maleta-sintetizador-61
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/maleta-sintetizador-61-aluminio
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-volca-bass
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-rytm-mki
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mutable-instruments-plaits
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-tr-505
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/access-virus-snow
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/critter-guitari-organelle
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-minilab-mkii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-electrico-vertical-thomann-dp-51
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/buchla-easel-doubler-card
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/clavia-nord-lead-1-rack-12-voces
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/the-orb-future-retro-secuenciador-midi-cv-gate
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-lpd-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-system-1m
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mutable-instruments-beads-modulo-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/keith-mcmillen-k-board-pro-4
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-cs1x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/temps-utile
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-monofonico-korg-ms-10-70s-korg-sq1-midi
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/zoom-arq-anillo-sintetizador-nuevo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-sq10-secuenciador
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/eloquencer-winter-modular
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/secuenciador-analogico-slicer-v3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-origin-desktop-perfecto-estado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-sub-phatty
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/waldorf-quantum
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-drumbrute-impact
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sonidos-custom-para-nord-lead-a1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-maestro-behringer-umx490
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-yc30
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mu-orbit-v2-9090
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/pack-digitone-digitakt-inmejorable
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-pianos-roland-p-330
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-kc-200
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/organo-hammond-the-sounder
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-psr-f51
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-launchkey-37-mk3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mutable-instruments-clouds-completo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-pa4x-61
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/jupiter-x-b-stock
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/addac-804-audio-integrator
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-sintetizador-prophet-08-david-smith
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-mpk88
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kurzweil-k2600-76-teclas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akemie-castle-alm-busy-circuits
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-ms-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/jomox-t-resonator-mkii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mpc-live2-x-one
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-juno-ds-88
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-ns5r-modulo-sonido-korg-n264
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mpc-1000-jjos2-128-mb
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/caja-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/landscape-stereo-field
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-monopoly
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teenage-engineering-op-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mpc-live-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-midi-yamaha-p-95
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-t-8-aira-compact-beat-machine
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-volca-fm
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-p-125-b
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-minilogue
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/ketron-sd-1000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-controlador-komplete-kontrol-mk3-49
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-moog-subsequent-25-impoluto
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-krome-61
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-moxf8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/set-tres-sintes-analogicos-enracados-behringer
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-volca-bass
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/galactic-ascension-modx-montage-regalo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/phat-analog-iii-yamaha-motif-xs-motif-xf-moxf-montage-modx
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/analog-xperience-yamaha-modx
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-cp70-pianos-yamaha-motif-xf-moxf-montage
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/royal-1-pianos-para-yamaha-motif-xs-motif-xf-moxf-montage
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-beatstep-pro
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kawai-sx240
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-mv-30
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-midi-mpe-linnstrument-200-teclas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/electribe-2-sampler-roja-impoluta-extras
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-microkorg-xl
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-drumbrute
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-dw8000-korg-triton-le
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/squarp-pyramid-mk1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/caja-2-buses-fuente-modular
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-moog-minitaur
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-xe8-midi-drum-expander
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-digital-yamaha-p140
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kawai-vpc-1-perfecto-estado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-jd-800
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-sh-01a
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/prophet-sequential-x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/4ms-stereo-triggered-sampler
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-fantom-xr
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-mv30
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-m3-m-xpanded
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nord-modular-g1-midiman-software-edicion-550-euros
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tarjeta-srx02-concert-piano-roland
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-xp50-averiado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tarjeta-roland-sr-jv80-15
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-theremini-nuevo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-nord-lead-virtual-analogico
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/star-instruments-synare-3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-polysix-midi
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-sonidos-pianobox-usb-miditech
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-sonidos-efectos-sm-pro-audio-vmachine-reproductor-pluggins-vst
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/rd-8-mkii-berhinger
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/amplificador-teclados-peavey-kb-100
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-tr-727
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-cd-rom-sound-library-mpc2000xl-vol1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tarjeta-roland-sr-jv80-01-pop
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-controlador-roland-800-pro
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-eurorack-doepfer-110-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/eloquencer-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doboz-touch-sensing-note-memory-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/audiothingies-ced-tuner-afinador-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulos-befaco-sinte-modular
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-121-dual-vcf
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/extras-kurzweil-k2000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-kaossilator-pro
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-drumbrute-impact-decksaver
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-minikorg-700-fs-nuevo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-yamaha-motif-es8-88-teclas-contrapesadas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-digital
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dreadbox-hades
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-01-wfd
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/groovebox-mc-303
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/cambio-tripode-pro-sintetizador
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mu-orbit-3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/erica-synths-bassline-db-01
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/compro-cambio-mu-orbit-v3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kawai-vpc1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/c7-1-pianos-yamaha-motif-xf-moxf-montage-modx
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-kx-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-nanokey-studio
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-bcr2000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/compro-cambio-modulos-mutable-instruments
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-digital-kawai-cn25
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kurzweil-pc3-le8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kurzweil-pc3-le8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/oto-machines-oto-bam
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-minilab-mk2-edicion-limitada-deep-black
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/cassette-datos-korg-dw6000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-he-cvilazation
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-muxlicer-mex-modulos
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/electribe-sx
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/alesis-micron
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-sy99
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-microbrute
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/soma-lyra-8-white-angel
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kurzweil-k2500x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-ms-20-fs-negro-version-montada-no-version-kit
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/multi-efectos-the-dust-collector-finegear
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/microkorg-s
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/casio-vl-tone-vl-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dreadbox-white-line-system
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/make-noise-system
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/polyend-tracker
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-minilogue-xd
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-karma-full-expanded
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-jd-xa-reestreno
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-p3-piano-module
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/acidlab-drumatix
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-alpha-juno-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-casio-501
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tarjetas-roland-sn-u110-02-12
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mutable-instruments-ambika
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-minilab-mk2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-kawai-sx-210
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-mo6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-jd-800
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-model-cycles-no-cambio
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/poly-beebo-no-cambio
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-fa-06
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-roland-spv-355
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-modular-completo-estrenar
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vermona-qmi-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/neutron-semimodular-analogico
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/hydrasynth
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tarjeta-exb-moss
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mochika-x2-atomosynth
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-mc-303
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/studiologic-sl88-grand
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-fantom-g6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/m-audio-keystation-61-mk3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-m3-libreria-kontakt-reason
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dsi-prophet-08-libreria-kontakt-reason
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-jx-3p-libreria-kontakt-reason
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-psr-3000-libreria-kontakt
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-modx6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-deepmind-12
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/bolsa-blanda-sintetizador-yamaha-mx49-similar
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-mc-909-sampling-groovebox
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-emu-audity-2000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/funda-yamaha-mox6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-dx9
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mini-korg-700-fs
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-r8-caja-ritmos
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-rm50-version-rack-ry30
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/diskette-sonidos-sampler-korg-dsm1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-rs-5
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-ms20-mini
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/leslie-344
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-motif-xf8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/hardcase-ruedas-teclado-76-teclas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-ketron-audya-5
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/hammond-a100-leslie-760
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/leslie-815-proline
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/amplificador-type-leslie-142-145
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-piano-korg-n1-88-teclas-contrapesadas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/delay-korg-monotron
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-reface-dx-cs
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/instruo-ts-l
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulos-mutant-hihats-mutant-bassdrum
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nord-lead-3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dreadbox-hypnosis
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-roland-jx3p
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-roland-jp-8000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-circuit-rythm
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-rd300sx-buen-estado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modal-electronics-cobalt-5s
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/analog-four-mki
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kurzweil-pc3-le7
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-rev-500
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-mc-707
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-summit
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/xaoc-moskwa-ii-ostankino-ii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/zip-scsi-iomega
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-digitakt
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/hammond-xk3c
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tukra-tesseract-modular-generador-baterias-secuenciador-midi-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-controlador-oberheim-mc-3000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/euclidean-circles-six-switches-expansion
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-modular
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-eurorack-behringer-911-envelope-generator
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-eurorack-doepfer-142-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/critter-guitari-organelle-digital-synth
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-circuit-rythm
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-rhodes-88-mark-ii-eighty-eight-suitcase
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-ultranova
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-supernova-ii-teclado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-dsi-tetra
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mpc-live-ssd-250-envio-incluido
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulo-befaco-rampage
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/fuente-alimentacion-eurorack-bus-board
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/pack-proyecto-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-minibrute-2s
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-summit
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/acces-virus-c
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/analogue-solutions-leipzig-s
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/varios-modulos
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-krome-61
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/taburete-tambor-acolchado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-nord-wave-2-cambio-hammond-sk-pro
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclas-otras-piezas-para-korg-yamaha-actualizado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/leslie-760-n-autonomo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/amplificador-122-type-classictone
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/leslie-122-clasico-autonomo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-160-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-106-5-sem-filter
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-103-vcf-6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-192-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-jupiter-4
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/noed-lead-4
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/proteus-2000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/studiologic-numa-compact-2-impecable-uso
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-korg-x3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/maleta-flight-case-estuche-teclado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/thomann-keyboard-bag-6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-fa-08
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-volca-fm
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-sk20-string-machine
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-sc-33
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mt-32-lista-presets
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/wersi-ex10r-expander-with-8-bit-drums-1985
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-moog-granmother
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modulos-eurorack-case-cables
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-analog-keys
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kodamo-essence-fm-sintetizador-multitimbrico-fm
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-05r-w-modulo-sintetizador
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-d110-sintetizador-digital-tarjeta-pn-d10-01
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/emu-proteus-1-sintetizador-rack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/alesis-micron
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-digitone
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/piano-electrico-escenario-kawai-mp-5-fligth-case
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tip-top-audio
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mpc-stuff-live-mpd-mpk-force-maschine
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/ob-06-sonidos-pago
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-system-15
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-25-sl-mk2-custom-moog
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-ms20-ic
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-motif-xf7
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/montage-6-desembalar
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/native-instruments-maschine-mark-1-controlador-usb-midi-dj
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/motif-rack-xs
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-msq-700-secuenciador-vintage
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-an1x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/funda-medida-korg-monopoly
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/funda-medida-moog-prodigy
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-analogico-oberheim-matrix-6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/perceptron-atomo-synth-semimodular
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/funda-teclado-5-octavas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tarjeta-smart-media-128mb-adaptador
# ...
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-s-220-sampler
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/qcb11-box11-cabinet-fuente-alimentacion
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-apr-2500-varios
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/novation-mininova
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/libros-desarrollo-plugins-audio
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-roland-xv-2020
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-werkstatt-01-cv-expander
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-tenori-on
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-psr-sx-600
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mutable-instruments-clouds
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-elka-omb5-caja-ritmosacompanamiento-automatico
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-modamp-module-1005
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-piano-yamaha-cpv-301
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-ds-1h-pedal-sustain-made-in-japan
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/access-virus-ti2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/erica-synths-black-spring-reverb
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-ms-20-mini-modificado-pwm-sync
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/packs-sonidos-maquinas-elektron
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/bass-station-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/verbos-electronics-producer-configuration-system
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/erica-synths-black-output-v2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/shakmat-modular-time-wizard
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-analogico-arturia-microbrute
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-juno-106
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/casio-vl-5-vl1-poly-lector-funda
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/synthesis-technology-e370-quad-morphing-vco-black
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/ik-multimedia-synth-pro-desktop
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tip-top-audio-circadian-rhythm
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mu-systems-procussion
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-101-2-lpg-vactrol-lowpasgate
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-keystep
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/eurorack-amplificador-auriculares-haunted-pliers-destino-3hp-diy
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/m-audio-oxygen-pro-mini
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-motif-xs8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/medeli-akx10
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/teclado-tyros3-yamaha-buenas-condiciones
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/antimatter-audio-crossfold
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/studiologic-numacompact-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/makenoise-st0
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-psr-s770
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dual-filter-soundforce
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-one-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/op-z-teenage-engineering
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tarjeta-korg-wavestation-wsc-3s-synth-time-slice
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-sound-library-pcm1-06-baroque
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/laterales-aluminio-roland-system-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/cambio-modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-142-2-vca-dual-adsr-ducking
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/campio-acces-virus-ti-polar
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/alm017-pamelas-new-workout
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-305-output-module
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tc-electronics-nova-delay
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-beat-step-pro
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vermona-drm1-mk2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/jomox-xbase-999
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-vc-adsr
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/befaco-midi-thing
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/blue-lantern-diode-operator-station-vcf-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-waldorf-streichfett-string-machine
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-nts-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-130-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/eurorack-dreadbox-ataxia
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nord-lead-4-rack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/lista-modulos-eurorack-mueble-custom-800hp
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/casio-cz-101
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/waldorf-quantum
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/rebajado-roland-v-combo-vr700-nuevo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-karma
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-modular
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-motif-xf-x-maleta
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-slim-phaty
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/studio-electronics-atc-1-2600-filter-cartridge
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tarjetas-roland-sr-jv80-sintetizadores-jv_xv_xp
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-rm1x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-minilogue-xd-module
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-cs1x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mu-proformance-1-modulo-sonidos-piano-envio-inc
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/lote-manuales-emu-korg-roland-kawai
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-r-8-2-unidades
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/clavia-nord-electro-6d-73
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kawai-mp-11
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-130-2-dual-vca
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mfb-dominion-club-nuevo-envio-incluido
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dynacord-percuter-s-vdrum-triggers
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-eb-16-eb16-fx-card-2000-xl
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nord-drum-synth
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/bastl-instruments-rumburack-2-sintetizador-modular-nuevo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-analog-keys-nuevo
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-yamaha-dx7s
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-korg-wavestation-ex
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/motu-midi-timepiece-ii
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-pro-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/elektron-analog-heat
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/soma-pulsar-23
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-vc340
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-dx7-breath-controler-bc1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-d50-d-50-sintetizador
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/komplete-kontrol-s61-mk2-vapor-gray
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/monsoon-similar
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-modulos-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-genos-20-funda-scc-profesional
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintetizador-analogico
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamana-moxf6
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/mutable-instruments-braids-clone
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/toms-000-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/delptronics-trigger-man-ldb-2e-ldb-2x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kore-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/intellijel-shapeshifter
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/flightcase-yamaha-p-80
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nord-electro-2-quizas-cambio-tb
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/hammond-skx
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/filtro-eurorack-magerit-vcf
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-switched-multiple-182-1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/alesis-v61-soporte-tijera
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/dreadbox-nyx-v1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-sd-400-signal-delay
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-199-spring-reverb-vintage-edition
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-keystep-black-edition
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-an1x
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-ju-06-a
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-tg33-tone-generator-vector-synth
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/secuenciador-korg-sq64
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-modx6-excelente-estado-extras
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/ferrofish-a32-ad-da-converter
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/waldorf-micro-q-keyboard
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-gw8l
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-106-5-sem-filter
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/faltar-studio-880-sl
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-mpc-renaissance
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-jx-3p-mode-machine-dt-200
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/doepfer-100-lc1-case-eurorack
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/casio-ct6000
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-modwave-librerias
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-960-sequential-controller
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/clon-mutable-instruments-frames
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-odyssey-envio-incluido
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-di20-madrid-capital
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/moog-mother-32
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sequential-prophet-x-300-8dio-voucher-libreria-gratis
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/modal-argon8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-tx-7
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-volca-bass
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-volca-keys
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/tessseract-truka
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/kit-controlador-leslies-6-pines-122-147-familias-6h-6w
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/hammond-m100-ano-1962
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/hammond-c3-1961-chop-down-portable
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/hammond-262-1968
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-roland-superjupiter-mks-80-programmer-mpg-80-perfecto-estado
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/waldorf-streichfett
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/vendo-virus-ti
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sintes-mucho-mas
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-rm50-rhythm-sound-module
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-dx7ii-d
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/korg-volca-kick
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/expert-sleepers-disting-mk1
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/maschine-micro-mk3
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/secuenciador-roland-mv30-studio-m
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/procesador-efectos-yamaha-emp-100
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/behringer-1050-mix-sequencer
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/compro-placa-base-roland-mc-505
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/alesis-ion
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-verselab-mv-1-decksaver
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-s3000xl
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/sequential-prophet-rev2-8
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/m-audio-oxygen-pro-49
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/make-noise-wogglebug
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/nord-stage-3-compact-electro-6d-73
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/akai-mpc-live-2
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-v50
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/stardust-synth-cover-korg-arp-odyssey-mini
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/roland-mc707
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/arturia-beatstep-pro-black
# /home/ion/Documentos/albertjimrod/personal_proj_hispasonic/htmls/yamaha-genos-maleta
# CPU times: user 13.5 s, sys: 697 ms, total: 14.2 s
# Wall time: 19min 4s

# %% [markdown]
# ## 3.3 It's not all about sales.
#
# <br>
#
# When ads have been downloaded, the next step is doing a quick scan inside the downloaded ads, so there's no only sales.
#
#
# A starting point is to look in the description of the titles and see if some of these words exist.
#
#
# By using `find` and `grep` together we can see if these words we are looking for are inside the files.
#
# <br>
#
#
#
# ![vendo.png](vendo.png)
#
# - **vendo : *sell***
#
# <br>
#
#
# ![busco_piezas.png](busco_piezas.png)
#
# - **busco, se busca: *looking for*** and - **piezas: *parts***
#
# <br>
#
#
# ![cambio.png](cambio.png)
#
# - **cambio: *change***
#
# <br>
#
# ![compro.png](compro.png)
#
# - **compro: *buy***
#
# <br>
#
# ![regalo.png](regalo.png)
#
# - **regalo: *for free***
#
# <br>
#
# This information will be very useful because these are the actions, and it will allow us to classify if the ad is for sale, purchase or any other concept that we have discovered.
#
# ## 3.4 Elements of the ad that we are going to extract.
#
# <br>
# Another step to take into account is to obtain:
#
# - **description**, **user**, **price**, **brand**, **city** , **date published** ,**date expire** ,**times seen**
#
# <br>
#
#
# ![hispa_4.png](hispa_4.png)
#
#
#
# <br>
#
# This is an ad as example and the fields we want to get:

# %% [markdown]
# ## 3.5 Extraction of the "action" and the synthesizer name from the description.
#
#
# <br>
#
# ### 3.5-1 Extraction of action
#
# <br>
#
#
# The extraction contained in the fields is not very complicated, however in the description we find a problem to solve and it is about how to differentiate a sale, a purchase or a change.
#
#
# To do this, the solution carried out has been to use a series of keywords in the meaning of the ad as triggers of an **accion: *action*** in the event that those words exist in the description of the advertisement.
#
#
# In the same way as we (humans) would do to see if the ad is a sale or on the contrary a gift.

# %%
accion = ["compro","cambio","vendo","regalo","busco","busca",'reparar','piezas']

# %% [markdown]
# Once we have the `accion` keywords list, the next step is to make them as a trigger, that is, manage to make a certain action.
#
# <br>
#
# Using the words contained in `accion` list as the key, and the value of the dictionary a call to a function depending the action on acción.
#
# <br>
#
#     func_dict = {                      # the key give us the action (function)
#         "compro":func_compro,
#         "cambio":func_cambio,
#         ...
#
#
#     def func_compro(clave_func_dict):  # if `compro` means I am not selling, and so on...
#
#     if list_compro[-1] == "0":
#         list_vendo.pop(-1)
#         list_vendo.append("0")
#         list_compro.pop(-1)
#         list_compro.append("1")
#     else:
#         pass
#
#
#
# <br>
#
# ### 3.5-1 Extraction of synthesizer name.
#
# <br>
#
#
# The next step we must implement is all the possible brands of synthesizer manufacturers that we can find in the ads.
#
#
# To do this by doing an internet search I could find a list of a large number of them, at least to date.
#
#
# However due to the time I have been working with the project I already have a list of names `sintes` with which I have been working but that when I reached this point I realized that I had to modify and merge with the new list.
#
# link where I obtain the brand synth: https://www.perfectcircuit.com/modular-synths
#
# #### Synthesizer manufacturers.

# %%
sintes = ['0 coast', '0-coast', '000', '4ms', 'a-v-p synth', 'acces', 'access', 'acidlab', 'akai', 'alembic', 'alesis', 'allen & heath', 'allen&heath', 
'analogaudio1', 'analogue solutions', 'analogue systems', 'arp', 'arturia', 'asm', 'asm (ashun sound machines)', 'atomo synth', 'atomosynth', 'audio damage', 
'audiophile circuits league', 'axoloty', 'balaguer', 'baloran', 'bastl instruments', 'befaco', 'behringer', 'behringer', 'bheringer', 'bitbox', 
'black corporation', 'boss', 'bubblesound instruments', 'buchla', 'bÃ¶hm', 'casio', 'charlie lab', 'charvel', 'chronograf', 'circuit abbey', 'clavia', 
'club of the knobs', 'coast', 'corsynth', 'cre8audio', 'crumar', 'custom made synths', 'cyclone', 'cyclone analogic', 'dave jones design', 'dave smith', 
'dave smith instruments', 'deepmind', 'deepmind 12', 'deepmind 6', 'delptronics', 'delta music', 'denon dj', 'dexibell', 'dexibell', 'digitack', 'doepfer', 
'dreadbox', 'dubreq', 'dynacord', 'e mu', 'e-mu', 'e-mu', 'e:m:c', 'elby designs', 'electribe', 'electronic music laboratories (eml)', 
'electrovoice', 'elektron', 'elka', 'emc', 'emu', 'endorphin.es', 'endorphines', 'ensoniq', 'eowave', 'epiphone', 'erica synth', 'erica synths', 
'ernie ball music man', 'esp ltd', 'eurorack', 'eventide', 'evh', 'evolver', 'exodus digital', 'farfisa', 'fender', 'fishman', 'fodera', 'formanta', 
'frap tool', 'frequency central', 'fretlight', 'friedman', 'future retro', 'futuresonus', 'gator', 'gemini', 'generalmusic', 'gibson', 'godin', 'gotharman', 
'graph tech', 'gretsch', 'guild', 'hammond', 'hartmann', 'hexinverter', 'hinton instruments', 'hofner', 'hypersynth', 'hÃ¶fner', 'ibanez', 'ik', 'instruo', 
'intellijel', 'iomega', 'isla', 'jackson', 'jaspers', 'john bowen synth design', 'jomox', 'kawai', 'kenton', 'ketron', 'kilpatrick audio', 'knobula', 
'koma elektronik', 'komplete', 'korg', 'kramer', 'kurzweil', 'kurzweil', 'lakland', 'line 6', 'linn electronics', 'livid', 'logan electronics', 'm-audio', 
'macbeth studio systems', 'make', 'malekko', 'manikin electronic', 'maschine', 'mellotron', 'mfb', 'micro modular', 'miditech', 'modal', 'modal electronics', 
'models', 'modor', 'modular', 'modulus', 'monome', 'moog', 'mpc', 'mpc', 'mutable instruments', 'mutant', 'native instruments', 'neutron', 'noise engineering', 
'nord', 'nord electro', 'nord lead 2 rack', 'nord lead 3', 'nord lead 3', 'nord lead 4', 'nord micro modular', 'nord modular', 'nord rack', 'nord stage', 
'nord wave', 'novation', 'numark', 'oberheim', 'octatrack', 'orthogonal devices', 'paratek', 'pearl', 'peavey', 'pioneer dj', 'pittsburgh', 'pittsburgh modular', 
'polyend', 'polygraf', 'ppg (palm products gmbh)', 'prs', 'qu bit', 'qu-bit', 'qu-bit electronix', 'quasimidi', 'qubit', 'quiklok', 'radikal technologies', 
'rhodes', 'rickenbacker', 'roland', 'roli', 'sanson', 'schecter', 'sensel', 'sequencial', 'sequential', 'sequential', 'sequential circuits', 
'sequential circuits', 'sequentix', 'shakmat', 'simmons', 'soma', 'sonicware', 'special waves', 'spector', 'spectral audio', 'sputnik', 'squarp instruments', 
'squier', 'ssff', 'stanton', 'steinberger', 'sterling', 'strymon', 'studio electronics', 'studiologic', 'studiologic music', 'synamodec', 'synthesis technology', 
'synthrotek', 'synthstrom', 'synthstrom', 'synthtech','swissonic', 'tascam', 'taylor', 'technos', 'teenage', 'teenage engineering', 'tiptop', 'tiptop audio', 
'traveler guitar', 'udo audio', 'uno synth ', 'vermona', 'vermona', 'virus', 'viscount', 'volca', 'vox', 'waldorf', 'warwick', 'washburn', 'waves grendel', 
'wersi', 'wersi music', 'winter modular', 'wmd', 'wmd / ssf', 'wurlitzer', 'yamaha', 'yocto', 'zeppelin design labs', 'zoom','1010 music', '2hp', '4ms', 'acid rain technology', 
'acl', 'addac system', 'after later audio', 'aion modular', 'ajh synth', 
'alm busy circuits', 'alright devices', 'analogue solutions', 'bastl instruments', 'befaco', 'blackhole cases', 'blue lantern', 'boredbrain music', 
'bubblesound', 'buchla', 'cosmotronic', 'cre8audio', 'divkid', 'dnipro modular', 'doepfer', 'dreadbox', 'e-rm', 'electrosmith', 'emblematic systems', 
'empress effects', 'endorphin.es', 'eowave', 'erica synths', 'erogenous tones', 'eskatonic modular', 'eventide', 'five12', 'frap tools', 'future sound systems', 
'gieskes', 'grayscale', 'hexinverter', 'industrial music electronics', 'instruo', 'intellijel designs', 'io instruments', 'jomox', 'joranalogue', 'klavis', 
'koma elektronik', 'l-1', 'lmntl', 'low-gain electronics', 'lzx industries', 'make noise', 'malekko heavy industry', 'manhattan analog', 'meng qi', 
'michigan synth works', 'modbap modular', 'moog', 'mordax', 'mosaic', 'mrseri', 'mutable instruments', 'nano modules', 'noise engineering', 
'patching panda', 'percussa', 'pittsburgh modular', 'plankton electronics', 'poly effects', 'qu-bit electronix', 'random source', 'ritual electronics', 
'rossum', 'schlappi engineering', 'shakmat modular', 'soundforce', 'soundmachines', 'squarp', 'steady state fate', 'strymon', 'studio electronics', 
'supercritical', 'synthesis technology', 'system 80', 'tall dog electronics', 'tasty chips', 'tenderfoot electronics', 'tesseract modular', 'tiptop audio', 
'trogotronic', 'tubbutec', 'u-he', 'verbos electronics', 'vermona', 'voicas', 'vpme.de', 'winter modular', 'wmd', 'worng electronics', 'xaoc devices', 
'xor electronics', 'zlob modular',"ASM","Elektron","Moog","Sequential","Teenage Engineering","SOMA Laboratory","Korg","Novation","Modal Electronics",
"Black Corporation","Roland","Arturia","Critter & Guitari","Polyend","UDO","Waldorf","Nord","Yamaha","Vermona","Crumar","JMT Synth","Modor",
"Studio Electronics","Trogotronic","Gieskes","Akai","Dreadbox","Herbs and Stones","IK Multimedia","Tasty Chips","Buchla","Soundmachines",
"Access","Grp","Analogue Solutions","The Division Department","Norand","Jomox","Sonicware","Radikal Technologies","Playtime Engineering",
"1010 Music","Fred's Lab","Kilpatrick Audio","Eowave","Electrosmith","Meng Qi","Studiologic","Suzuki","Nonlinear Labs","Dato","Artiphon",
"Malekko Heavy Industry","Kodamo","Hikari Instruments","Manikin Electronic","Second Sound","","Arturia","Squarp","Polyend","Novation","Akai",
"Roger Linn Design","Conductive Labs","Native Instruments","Faderfox","Sensel","Roland","Keith McMillen","Pioneer","E-RM","Expressive E","Korg",
"M-Audio","Alesis","JouÃ©","Soundforce","Yamaha","Genki","Erica Synths","SOMA Laboratory","Make Noise","Doepfer","Elektron","Moog",
"Teenage Engineering","1010 Music","Expert Sleepers","BASTL Instruments","Kenton","Circuit Happy","MOTU","MIDI Solutions","Solid State Logic",
"Nord","Malekko Heavy Industry","Koma Elektronik","Random Source","Eowave","Zoom","Crumar","Electro-Harmonix","Grp","Michigan Synth Works",
"Analogue Solutions","Knas","iConnectivity","Soundmachines","Eurodesk-Z","Presonus","Torso Electronics","IK Multimedia","ESI Audiotechnik",
"Low-Gain Electronics","Kilpatrick Audio","Artiphon","Instruments of Things","Apogee","SND","Future Retro","Moffenzeef","CME","Embodme",
"Tech 21","Snyderphonics","Tricks Magic Shop","","","Strymon","Vermona","OTO Machines","Dreadbox","Chase Bliss Audio","Boss","GFI","Meris",
"Eventide","SOMA Laboratory","Echo Fix","Fairfield Circuitry","Universal Audio","Gamechanger Audio","EarthQuaker Devices","Death By Audio",
"Sherman","Electro-Harmonix","Old Blood Noise Endeavors","Knas","Red Panda","Malekko Heavy Industry","Kemper","DigiTech","JAM Pedals",
"Erica Synths","Elektron","WMD","1010 Music","Roland","Korg","Poly Effects","Jomox","Thermionic Culture","Decksaver","Warm Audio",
"Zoom","Boredbrain Music","Meng Qi","Electrosmith","Benidub","BAE","Trogotronic","MIDI Solutions","Plankton Electronics","Vongon",
"ART","Hungry Robot","Walrus Audio","Enjoy Electronics","CIOKS","TK Audio","Source Audio","API","Kilpatrick Audio","Voodoo Lab",
"FMR Audio","JHS Pedals","MOD Devices","Cooper FX","Finegear","Ezhi & Aka","Truetone","LastGasp Art Laboratories","Origin Effects",
"Rainger FX","Line 6","PedalTrain","Dr. Scientist","Elta Music","Keeley","Recovery","Glou-Glou","Retro Mechanical Labs","Electro-Faustus",
"Animal Factory","Hologram","Caroline Guitar Company","MXR","Second Sound","Xotic","Dunlop","Adventure Audio","ISP Technologies",
"Industrialectric","Tech 21","Collision Devices","Orgeldream","Universal Audio","API","Solid State Logic","Rupert Neve Designs","Shure","MOTU",
"Warm Audio","Focusrite","Vermona","Focal","Neumann","Roland","Thermionic Culture","Arturia","Zoom","Presonus","Adam","ART","Yamaha",
"TASCAM","Furman","Antelope Audio","Dangerous Music","Pioneer","Echo Fix","Native Instruments","Decksaver","Eventide","Allen & Heath",
"Meris","Sherman","dbx","BAE","Maag Audio","Empirical Labs","Avantone Pro","iConnectivity","Mackie","Audient","beyerdynamic","TK Audio",
"IK Multimedia","Black Lion Audio","RME","Keith McMillen","Golden Age Project","Audio-Technica","Fredenstein","A-Designs","Rosson Audio",
"Daking","Looptrotter","Rode","Prism Sound","Samson","Cranborne Audio","ESI Audiotechnik","Elysia","HEDD","FMR Audio","Heritage Audio",
"Avedis Audio","Sennheiser","Lindell Audio","Blue Microphones","Apogee","Recovery","M-Audio","Zeppelin Design Labs","KRK","AKG",
"Cloud Microphones","Steinberg","Alesis","Dynaudio","Austrian Audio","Auralex","IsoAcoustics","Aston Microphones","Auratone","sE Electronics","SE Electronics",
"Tech 21","Lauten Audio","Cascade Microphones","Soundrise","Pioneer","Allen & Heath","Pro-Ject","PLAYdifferently","U-Turn Audio","Audio-Technica",
"Thorens","Audioengine","Technics","Rane","AKG","Music Hall","Native Instruments","Numark","Sennheiser","Jesse Dean Designs","Ortofon","Decksaver",
"Rosson Audio","MWM","Gator","IK Multimedia","ART","Yamaha","Ultimate Support","RME","Roland","KRK","Austrian Audio","Shure","Odyssey",
"Teenage Engineering","Denon","Record Props","Presonus","Hosa","Hosa","Mogami ","Roland ","Voodoo Lab ","CIOKS ","LMNTL ","Warm Audio "
"Teenage Engineering ","myVolts ","Gator ","Truetone ","Strymon ","Eurodesk-Z","Furman","Elektron","Tiptop Audio","Retrokits","4MS","EBS",
"Pomona Electronics","Modbang","Intellijel Designs","Plankton Electronics","Radial Engineering","1010 Music","Native Instruments",
"Expert Sleepers","Buchla","iConnectivity","Modbap Modular","Boredbrain Music","Make Noise","Korg","Moog ","Rode ","Shure ",
"LabLab Audio ","Zoom ","Doepfer ","Koma Elektronik ","ADDAC System ","Frap Tools ","Endorphin.es ","ART s","Yamaha ","Walrus Audio",
"ALM Busy Circuits ","Analogue Solutions ","Trogotronic ","Befaco ","Boss ","Soundmachines ","LZX Industries ","Cyclone Analogic ",
"M-Audio ","E-RM ","Pulp Logic ","Electro-Harmonix ","ESI Audiotechnik ","Eskatonic Modular ","Eventide ","Instruo ","Keith McMillen",
"Malekko Heavy Industry ","Dunlop"]

# %%
# removing whole names in list.

lista_criba = []

for marca in sintes:
    marca = marca.lower()
    if marca not in lista_criba:
        lista_criba.append(marca)

# %%
lista_criba[2:10]
# Out:
# ['000', '4ms', 'a-v-p synth', 'acces', 'access', 'acidlab', 'akai', 'alembic']

# %% [markdown]
# - Once I clean the list of possible repeated names, what I do next is that the names composed of two terms are a list of two elements.

# %%
# split double names in list

lista_sintes= []

for marca in lista_criba:
    marca = marca.lower()
    if marca not in lista_sintes:
        marca=marca.split()
        lista_sintes.append(marca)

# %%
lista_sintes[2:10]
# Out:
# [['000'],
#  ['4ms'],
#  ['a-v-p', 'synth'],
#  ['acces'],
#  ['access'],
#  ['acidlab'],
#  ['akai'],
#  ['alembic']]

# %% [markdown]
# ## 3.6 How to identify manufacturer brands?.
#
#
#
#
# <br>
#
# There are many names with two or three terms and some of them are unique, but others have the first name in common.
#
# for example:
#
# <br>
#
#     ...analogue systems, analogue solutions...
#
# <br>
#
# To solve this problem we have to do:
#
#
# - Building a manufacturers' dictionary.
#
# - Implement an algorithm that differentiates between multiple manufacturer brands
#
#
# As an example we will use this small dictionary as if it were our dictionary of synthesizer manufacturers:
#
#   - Manufacturers' dictionary:
#
#
#     sint3 = {"analogue":["solutions","systems"]}
#
#
#
# The implementation of the algorithm will be based on detecting:
#
# - *single names*: `Roland`
#
# - *double and unique names*:  `Dave Smith`
#
# - *double names with a first name common to different manufacturers*: `Analogue Systems or Analogue Solutions`
#
#
#
#
#
# <br>
#
# The particularity of **this** example is that it allows us to see one of the most controversial cases when it comes to the extraction of a name.
#
# ### example of algorithm implementation:
#
# With this example what is intended is just to detect the correct name in the variable of the description, ie:
#
# - `Analogue Systems`

# %%
# How to detect manufacturer brands with same name and different 'surname'


texto_descript = ''

# Our manufaturer brand in a dictionary!
sint3 = {"analogue":["solutions","systems"]}  

# Example description ad
descrip = ['analogue', 'systems', 'woggeblug', '+', 'morphagene', '+', 'optomix'] 

texto_marca_compuesta =''
kompare = ''

list_temp = []
list_brand = []                                     # steps

for idx in descrip:                                 # 1. #7. 
    if idx in kompare:                              # 2. #8.
                                                    
        list_temp.append(idx)                            # 9. 
        for palabritas in list_temp:                 
            texto_descript += ' '+ palabritas            # 10.

        #list_brand.append(texto_descript)               # 11.
        kompare = ''                                     # 12.
        list_temp.clear()                                # 13.

        

    elif idx in sint3:                              # 3.
        if len(sint3[idx]) > 1:                     # 4.
            list_temp.append(idx)                   # 5.
            print(sint3[idx])
            kompare = sint3[idx]                    # 6.

        
print(texto_descript)
# Out:
# ['solutions', 'systems']
#  analogue systems

# %% [markdown]
# - We have the correct name: `analogue systems` thru the dictionary where they share a "name".

# %%
# 1. for starts                   # 7. the idx already has the second name of the synth.

# 2. if idx coincides with the content of a kompare, else go to next elif.

                                # 8. if comparing the idx with the variable that contains the match if true
                                # 9. Saving the second match in the temporary list
                                # 10. I convert the items in the list to a text string


                                # 11  Assign the string into the brand list
                                # 12. clean the value of the kompare variable and texto_marca_compuesta
                                # 13. clean the contents of the temporary list

        

# 3. if the index is contained in the sint3 dictionary 
# 4. and the length of the dictionary key value is greater than 1 means we have at least two possible marks.
# 5. I store this first match in a temporary list

# 6. And save the list of possible matches in a variable, which was initially void with ''

# %% [markdown]
# in the previous example we made use of a small dictionary that we could make by hand, but we need to implement a dictionary with all manufacturers.
#
#
# ## Building the manufacturer's dictionary

# %%
marcas_nombres = []


def sint_word(sintex):
    marcas_nombres.append(sintex)
    return [marcas_nombres[-1]]

def sint_more_word_rep(sintex):
    # no es necesario que devueva una lista ya que dentro del diccionario ya la tengo!
    marcas_nombres.append(sintex)
    return marcas_nombres[-1]


dict_funct = {"sint_word":sint_word,
            "sint_more_word_rep":sint_more_word_rep
}

dict_marca = {}

tag_mark = ''
for marcas in lista_sintes:
    if len(marcas) == 1:
        if marcas[0] not in dict_marca:
            tag_mark = 'sint_word'
            brand = marcas[0]
            ret = dict_funct[tag_mark](brand)
            
            dict_marca[brand] = ret
            #print("x")
    elif len(marcas) > 1:                           # aqui la marca tiene este formato: ['0', 'coast']
        if marcas[0] not in dict_marca:
            tag_mark = 'sint_word'
            #print(marcas[0])
            #print(marcas[1])

           
            ret = dict_funct[tag_mark](marcas[1])
            dict_marca[marcas[0]] = ret

        elif marcas[0] in dict_marca:
            tag_mark = 'sint_more_word_rep'
            ret = dict_funct[tag_mark](marcas[1])
            dict_marca[marcas[0]].append(ret)
            #print("x")

# %%
print(dict_marca)
# Out:
# {'0': ['coast'], '0-coast': ['0-coast'], '000': ['000'], '4ms': ['4ms'], 'a-v-p': ['synth'], 'acces': ['acces'], 'access': ['access'], 'acidlab': ['acidlab'], 'akai': ['akai'], 'alembic': ['alembic'], 'alesis': ['alesis'], 'allen': ['&'], 'allen&heath': ['allen&heath'], 'analogaudio1': ['analogaudio1'], 'analogue': ['solutions', 'systems', 'solutions'], 'arp': ['arp'], 'arturia': ['arturia'], 'asm': ['asm', '(ashun'], 'atomo': ['synth'], 'atomosynth': ['atomosynth'], 'audio': ['damage'], 'audiophile': ['circuits'], 'axoloty': ['axoloty'], 'balaguer': ['balaguer'], 'baloran': ['baloran'], 'bastl': ['instruments'], 'befaco': ['befaco'], 'behringer': ['behringer'], 'bheringer': ['bheringer'], 'bitbox': ['bitbox'], 'black': ['corporation', 'lion'], 'boss': ['boss'], 'bubblesound': ['instruments'], 'buchla': ['buchla'], 'bã¶hm': ['bã¶hm'], 'casio': ['casio'], 'charlie': ['lab'], 'charvel': ['charvel'], 'chronograf': ['chronograf'], 'circuit': ['abbey', 'happy'], 'clavia': ['clavia'], 'club': ['of'], 'coast': ['coast'], 'corsynth': ['corsynth'], 'cre8audio': ['cre8audio'], 'crumar': ['crumar'], 'custom': ['made'], 'cyclone': ['cyclone', 'analogic', 'analogic'], 'dave': ['jones', 'smith', 'smith'], 'deepmind': ['deepmind', '12', '6'], 'delptronics': ['delptronics'], 'delta': ['music'], 'denon': ['dj'], 'dexibell': ['dexibell'], 'digitack': ['digitack'], 'doepfer': ['doepfer'], 'dreadbox': ['dreadbox'], 'dubreq': ['dubreq'], 'dynacord': ['dynacord'], 'e': ['mu'], 'e-mu': ['e-mu'], 'e:m:c': ['e:m:c'], 'elby': ['designs'], 'electribe': ['electribe'], 'electronic': ['music'], 'electrovoice': ['electrovoice'], 'elektron': ['elektron'], 'elka': ['elka'], 'emc': ['emc'], 'emu': ['emu'], 'endorphin.es': ['endorphin.es'], 'endorphines': ['endorphines'], 'ensoniq': ['ensoniq'], 'eowave': ['eowave'], 'epiphone': ['epiphone'], 'erica': ['synth', 'synths'], 'ernie': ['ball'], 'esp': ['ltd'], 'eurorack': ['eurorack'], 'eventide': ['eventide'], 'evh': ['evh'], 'evolver': ['evolver'], 'exodus': ['digital'], 'farfisa': ['farfisa'], 'fender': ['fender'], 'fishman': ['fishman'], 'fodera': ['fodera'], 'formanta': ['formanta'], 'frap': ['tool', 'tools', 'tools'], 'frequency': ['central'], 'fretlight': ['fretlight'], 'friedman': ['friedman'], 'future': ['retro', 'sound'], 'futuresonus': ['futuresonus'], 'gator': ['gator'], 'gemini': ['gemini'], 'generalmusic': ['generalmusic'], 'gibson': ['gibson'], 'godin': ['godin'], 'gotharman': ['gotharman'], 'graph': ['tech'], 'gretsch': ['gretsch'], 'guild': ['guild'], 'hammond': ['hammond'], 'hartmann': ['hartmann'], 'hexinverter': ['hexinverter'], 'hinton': ['instruments'], 'hofner': ['hofner'], 'hypersynth': ['hypersynth'], 'hã¶fner': ['hã¶fner'], 'ibanez': ['ibanez'], 'ik': ['ik', 'multimedia'], 'instruo': ['instruo'], 'intellijel': ['intellijel', 'designs'], 'iomega': ['iomega'], 'isla': ['isla'], 'jackson': ['jackson'], 'jaspers': ['jaspers'], 'john': ['bowen'], 'jomox': ['jomox'], 'kawai': ['kawai'], 'kenton': ['kenton'], 'ketron': ['ketron'], 'kilpatrick': ['audio'], 'knobula': ['knobula'], 'koma': ['elektronik', 'elektronik'], 'komplete': ['komplete'], 'korg': ['korg'], 'kramer': ['kramer'], 'kurzweil': ['kurzweil'], 'lakland': ['lakland'], 'line': ['6'], 'linn': ['electronics'], 'livid': ['livid'], 'logan': ['electronics'], 'm-audio': ['m-audio'], 'macbeth': ['studio'], 'make': ['make', 'noise'], 'malekko': ['malekko', 'heavy', 'heavy'], 'manikin': ['electronic'], 'maschine': ['maschine'], 'mellotron': ['mellotron'], 'mfb': ['mfb'], 'micro': ['modular'], 'miditech': ['miditech'], 'modal': ['modal', 'electronics'], 'models': ['models'], 'modor': ['modor'], 'modular': ['modular'], 'modulus': ['modulus'], 'monome': ['monome'], 'moog': ['moog'], 'mpc': ['mpc'], 'mutable': ['instruments'], 'mutant': ['mutant'], 'native': ['instruments'], 'neutron': ['neutron'], 'noise': ['engineering'], 'nord': ['nord', 'electro', 'lead', 'lead', 'lead', 'micro', 'modular', 'rack', 'stage', 'wave'], 'novation': ['novation'], 'n ...

# %% [markdown]
# It will give us:
#
# <br>
#
# - What was inside of `sint3[idx]` ['solutions', 'systems'] thanks to a print.
#
#
# - Finally we have the we have the right name of the description, as we expected.
#
# <br>
#
# Once we understand the operation we are going to implement the necessary code.
#
#
# ## 3.7 Detecting manufacturer brands.

# %%
compare = ''                    #variable where the middle name is saved
marca_del_sinte = ''            # empty variable for store synth brand 
texto_descriptivo = ''          #ad descriptive text
list_temp = []                  #temporary list to detect the middle name 

                                # buy, sell, change... lists.
list_compro = []
list_cambio = []
list_vendo = []
list_regalo = []
list_busco = []
list_rebaja = []
list_reparar = []
list_piezas = []
list_urgente = []
list_oferta = []

list_brand = []                 # manufacturers synth brand
list_descripcion = []           # final ad description on dataframe output 
texto_descriptivo_salida = []   # esto es lo que se vera como contenido del anuncio

list_price = []                 # price
list_user = []                  # user
list_city = []                  # city
list_published = []             # date published
list_expire = []                # data expire ad
list_times_seen= []             # times seen ad

lista_palabras_para_eliminar = [] # remove words from description list

def func_compro(clave_func_dict): 

    if list_compro[-1] == "0":
        list_vendo.pop(-1)
        list_vendo.append("0")
        list_compro.pop(-1)
        list_compro.append("1")
    else:
        pass


def func_cambio(clave_func_dict):
    if list_cambio[-1] == "0":
        list_vendo.pop(-1)
        list_vendo.append("0")
        list_cambio.pop(-1)
        list_cambio.append("1")

    else:
        pass

def func_vendo(clave_func_dict):
    if list_vendo[-1] == "0":
        list_vendo.pop(-1)
        list_vendo.append("1")
    else:
        pass

def func_regalo(clave_func_dict): 
    if list_regalo[-1] == "0":
        list_vendo.pop(-1)
        list_vendo.append("0")
        list_regalo.pop(-1)
        list_regalo.append("1")
    else:
        pass

def func_busco(clave_func_dict):  # if looking for, then is not a sell...
    if list_busco[-1] == "0":
        list_vendo.pop(-1)
        list_vendo.append("0")
        list_busco.pop(-1)
        list_busco.append("1")
    else:
        pass

def func_reparar(clave_func_dict):
    if list_busco[-1] == "0":
        list_reparar.pop(-1)
        list_reparar.append("1")
    else:
        pass

def func_piezas(clave_func_dict):
    if list_busco[-1] == "0":
        list_piezas.pop(-1)
        list_piezas.append("1")
    else:
        pass

def func_rebaja(clave_func_dict):
    if list_rebaja[-1] == "0":
        list_vendo.pop(-1)
        list_vendo.append("0")
        list_rebaja.pop(-1)
        list_rebaja.append("1")
    else:
        pass

def func_oferta(clave_func_dict):
    if list_oferta[-1] == "0":
        list_oferta.pop(-1)
        list_oferta.append("1")
    else:
        pass



func_dict = {                     # function dictionary
    "compro":func_compro,
    "cambio":func_cambio,
    "vendo":func_vendo,
    "vende":func_vendo,
    "regalo":func_regalo,
    "busco":func_busco,
    "busca":func_busco,
    "reparar":func_reparar,
    "piezas":func_piezas,
    "rebajado":func_rebaja,
    "rebaja":func_rebaja,
    "oferta":func_oferta
    
}

def remove_compro(clave_func_dict):
    #list_compro.append(clave_func_dict
    list_compro.remove(clave_func_dict)


#rmv_func = {"compro":remove_compro}


def urgente():                     # if some "accion" word is repeated on description, means urgency
    list_urgente.remove('0')
    list_urgente.append("1")


def eliminar_signos(txt):          # cleaning text
    description = txt.replace(":"," ")
    descripcion = description.replace(";"," ")
    descripcion_1 = descripcion.replace("("," ")
    descripcion_2 = descripcion_1.replace(")"," ")
    descripcion_3 = descripcion_2.replace("/"," ")
    descripcion_4 = descripcion_3.replace("."," ").lower()
    descripcion_5 = descripcion_4.split()
    return descripcion_5


def default_atributes():         # default actions, means all is selling, if not then function will be called.
    list_cambio.append("0")
    list_compro.append("0")
    list_urgente.append("0")
    list_vendo.append("1")
    list_regalo.append("0")
    list_reparar.append("0")
    list_piezas.append("0")
    list_busco.append("0")
    list_brand.append("-")



### Inicio


for pagina_anuncio in os.listdir('.'):       # '.' current folder
    #if "kurzweil" in pagina_anuncio:                               #compro-cambio
    
    with open(pagina_anuncio, 'r') as pagina_bruto:

        pagina_analizar = pagina_bruto.read()
        soup = BeautifulSoup(pagina_analizar, 'html.parser')


        node = soup.find('h1') 

    if  node is not None:                       # avoiding skipping an error related to None
        descripcion = node.text 
        descripcion = eliminar_signos(descripcion)
        #print(descripcion)

        default_atributes()


        for word_1 in descripcion:
            if word_1 in accion:
                func_dict[word_1](word_1)
                lista_palabras_para_eliminar.append(word_1)

            elif word_1 in compare:
                list_temp.append(word_1)

                for marca_sinte in list_temp:
                    marca_del_sinte += marca_sinte + ' '
                    lista_palabras_para_eliminar.append(marca_sinte) # delete the compound name of the sinte in the description.

                #marca_del_sinte = ''
                list_brand.pop(-1)
                list_brand.append(marca_del_sinte)

                compare = '' # variable with the second part of the name, so I clean it here.

            elif word_1 in dict_marca:
                size_brand = len(dict_marca[word_1])

                if ((size_brand == 1) and (list_brand != "-")) :
                    list_brand.pop(-1)
                    list_brand.append(word_1)


                elif ((size_brand == 1) and (list_brand == "-")) :
                    list_descripcion.append(word_1)

                elif size_brand > 1:
                    compare = dict_marca[word_1]
                    list_temp.append(word_1)

                elif list_brand != "-":
                    list_descripcion.append(word_1)

            marca_del_sinte = ''

        list_temp.clear()

        duplicates = [element for element in lista_palabras_para_eliminar if lista_palabras_para_eliminar.count(element) > 1]
        unique_duplicates = list(set(duplicates))

        size_unique_duplicates = len(duplicates)

        if size_unique_duplicates > 1:
            urgente()


        for eliminar in lista_palabras_para_eliminar:
            try:
                descripcion.remove(eliminar)
            except:
                pass

        for palabras in descripcion:
            texto_descriptivo += palabras + ' '


        texto_descriptivo_salida.append(texto_descriptivo)

        texto_descriptivo =''


        # --- price

        try:
            price = soup.find('div',class_='ad-price').text
            price = int(price.split()[0])
            list_price.append(price)
        except:
            price = 0
            list_price.append(price)
            

        # --- user name

        user = soup.find('div',class_='col-lg-7').a.text
        list_user.append(user)
        

        # --- city

        city = soup.find('div',class_='col-lg-7').div.strong.text
        list_city.append(city)

        # --- published



        published = soup.find('div',class_='col-lg-7').div.text.split()[-5:-2]

        for indx in published:
            if '/' in indx:
                #print(indx)
                publish = indx
            elif 'hace' in indx:
                a = published.index(indx)
                #print(published[a+1] + ' ' + published[a+2])
                publish = published[a+1] + ' ' + published[a+2]

            
        list_published.append(publish)

        # --- expire 

        expire = soup.find('div',class_="expira").text.split()[1]
        list_expire.append(expire)

        # --- times seen
        
        seen = soup.find('div',class_="expira").text.split()[4]
        list_times_seen.append(seen)

        lista_palabras_para_eliminar.clear()
        #print(pagina_anuncio)

# %% [markdown]
# ## 3.8 Date extraction
#
# The next step is to know what is the extraction date. This is an important fact since because it will serve as a reference to know how long means 3 days, 1 week, 5 hours since the records were made.

# %%
hoy = dt.datetime.now()
year=str(hoy.year)

month=str(hoy.month)
day=str(hoy.day)

date_scrapped = day + '/' + month + '/' + year

# ex: date_scrapped = '26' + '/' + '08' + '/' + '2022' 

date_scrapped
# Out:
# '1/9/2022'

# %% [markdown]
# - Dataframe created in `df` variable.

# %%
df = pd.DataFrame({'urgent':list_urgente,
                   'buy':list_compro,
                   'change':list_cambio,
                   'sell':list_vendo,
                   'price':list_price,
                   'gift':list_regalo,
                   'search':list_busco,
                   'repair':list_reparar,
                   'parts':list_piezas,
                   'synt_brand':list_brand,
                   'description':texto_descriptivo_salida,
                   'user':list_user,
                   'city':list_city,
                   'published':list_published,
                   'expire':list_expire,
                   'date_scrapped':date_scrapped,
                   'seen':list_times_seen
                  },index = list(range(1,len(texto_descriptivo_salida)+1)))

# %%
df
# Out:
#     urgent buy change sell   price gift search repair parts  \
# 1        0   0      0    1     350    0      0      0     0
# 2        0   0      0    1     350    0      0      0     0
# 3        0   0      0    1     900    0      0      0     0
# 4        0   0      0    1    1100    0      0      0     0
# 5        0   0      0    1     480    0      0      0     0
# 6        0   0      0    1     105    0      0      0     0
# 7        0   0      0    1    1300    0      0      0     0
# 8        0   0      1    0       0    0      0      0     0
# 9        0   0      0    1      80    0      0      0     0
# 10       0   0      0    1    2600    0      0      0     0
# 11       0   0      0    1     500    0      0      0     0
# 12       0   0      0    1      23    0      0      0     0
# 13       0   0      0    1     320    0      0      0     0
# 14       0   1      0    0       0    0      0      0     0
# 15       0   0      0    1     600    0      0      0     0
# 16       0   0      0    1     260    0      0      0     0
# 17       0   0      0    1    4500    0      0      0     0
# 18       0   0      0    1     500    0      0      0     0
# 19       0   0      0    1     200    0      0      0     0
# 20       0   0      0    1    1000    0      0      0     0
# 21       0   0      1    0     410    0      0      0     0
# 22       0   0      0    1     975    0      0      0     0
# 23       0   0      0    1     380    0      0      0     0
# 24       0   0      0    1    1111    0      0      0     0
# 25       0   0      0    1     150    0      0      0     0
# 26       0   0      0    1     729    0      0      0     0
# 27       1   0      0    1     600    0      0      0     0
# 28       0   0      0    1    2000    0      0      0     0
# 29       0   0      0    1      55    0      0      0     0
# 30       0   0      0    1     175    0      0      0     0
# 31       0   0      0    1     240    0      0      0     0
# 32       0   0      0    1     525    0      0      0     0
# 33       0   0      0    1      45    0      0      0     0
# 34       0   0      0    1     370    0      0      0     0
# 35       0   0      0    1     140    0      0      0     0
# 36       0   0      0    1     430    0      0      0     0
# 37       0   0      1    1       0    0      0      0     0
# 38       0   0      1    0       0    0      0      0     0
# 39       0   0      0    1     460    0      0      0     0
# 40       0   0      0    1      50    0      0      0     0
# 41       0   0      0    1     525    0      0      0     0
# 42       0   0      0    1     300    0      0      0     0
# 43       0   0      0    1     900    0      0      0     0
# 44       0   0      0    1     120    0      0      0     0
# 45       0   0      0    1     175    0      0      0     0
# 46       0   0      0    1     500    0      0      0     0
# 47       0   1      0    0       0    0      0      0     0
# 48       0   0      0    1      25    0      0      0     0
# 49       0   0      0    1      30    0      0      0     0
# 50       0   0      0    1     115    0      0      0     0
# 51       0   0      0    1     260    0      0      0     0
# 52       0   0      0    1     800    0      0      0     0
# 53       0   0      0    1     250    0      0      0     0
# 54       0   0      0    1    3349    0      0      0     0
# 55       0   0      0    1    1000    0      0      0     0
# 56       0   0      0    1     800    0      0      0     0
# 57       0   0      0    1     450    0      0      0     0
# 58       0   0      0    1      65    0      0      0     0
# 59       0   0      0    1     450    0      0      0     0
# 60       0   0      0    1      60    0      0      0     0
# 61       0   0      0    1    1200    0      0      0     0
# 62       0   0      0    1      49    0      0      0     0
# 63       0   0      0    1     250    0      0      0     0
# 64       0   0      0    1     259    0      0      0     0
# 65       0   0      0    1      55    0      0      0     0
# 66       0   0      0    1     550    0      0      0     0
# 67       0   0      0    1     250    0      0      0     0
# 68       0   0      0    1     219    0      0      0     0
# 69       0   0      0    1     460    0      0      0     0
# 70       0   0      0    1     250    0      0      0     0
# 71       0   0      0    1    2050    0      0      0     0
# 72       0   0      0    1      59    0      0      0     0
# 73       0   0      0    1       0    0      0      0     0
# 74       0   0      1    0       0    0      0      0     0
# 75       0   0      0    1     499    0      0      0     0
# 76       0   0      0    1     249    0      0      0     0
# 77       0   0      0    1     680    0      0      0     0
# 78       0   0      0    1      50    0      0      0     0
# 79       0   0      0    1    2800    0      0      0     0
# 80       0   0      0    1     350    0      0      0     0
# 81       0   0      0    1     580    0      0      0     0
# 82       0   0      0    1      45    0      0      0     0
# 83       0   0      0    1      65    0      0      0     0
# 84       0   0      0    1     130    0      0      0     0
# 85       0   0      0    1     930    0      0      0     0
# 86       0   0      0    1     160    0      0      0     0
# 87       0   0      0    1    1350    0      0      0     0
# 88       0   0      0    1     430    0      0      0     0
# 89       0   0      0    1      80    0      0      0     0
# 90       0   0      0    1    1070    0      0      0     0
# 91       0   0      0    1     930    0      0      0     0
# 92       0   0      0    1     210    0      0      0     0
# 93       0   0      0    1     125    0      0      0     0
# 94       0   0      0    1      70    0      0      0     0
# 95       0   0      0    1     119    0      0      0     0
# 96       0   0      1    0       0    0      0      0     0
# 97       0   0      0    1     395    0      0      0     0
# 98       0   1      0    0       0    0      0      0     0
# 99       0   0      0    1     100    0      0      0     0
# 100      0   0      0    1     310    0      0      0     0
# 101      0   0      0    1     379    0      0      0     0
# 102      0   0      0    1     495    0      0      0     0
# 103      0   0      0    1     600    0      0      0     0
# 104      0   0      0    1     750    0      0      0     0
# 105      0   1      0    0       0    0      0      0     0
# 106      0   0      0    1    1175    0      0      0     0
# 107      0   0      0    1    5200    0      0      0     0
# 108      1   0      0    1     430    0      0      0     0
# 109      0   0      0    1     260    0      0      0     0
# 110      0   0      0    1     180    0      0      0     0
# 111      0   0      0    1     385    0      0      0     0
# 112      0   0      0    1     350    0      0      0     0
# 113      0   0      0    1      80    0      0      0     0
# 114      0   0      0    1   12500    0      0      0     0
# 115      0   1      0    0       0    0      0      0     0
# 116      0   0      0    1     550    0      0      0     0
# 117      0   0      1    0       0    0      0      0     0
# 118      0   0      0    1      40    0      0      0     0
# 119      0   0      0    1     999    0      0      0     0
# 120      0   0      0    1     339    0      0      0     0
# 121      0   0      0    1     370    0      0      0     0
# 122      0   0      0    1    1300    0      0      0     0
# 123      0   0      0    1    1829    0      0      0     0
# 124      0   0      0    1     500    0      0      0     0
# 125      0   0      0    1      75    0      0      0     0
# 126      0   0      0    1      24    0      0      0     0
# 127      0   0      0    1      19    0      0      0     0
# 128      0   0      0    1     400    0      0      0     0
# 129      0   0      0    1    1800    0      0      0     0
# 130      0   0      0    1     100    0      0      0     0
# 131      0   0      0    1      50    0      0      0     0
# 132      0   0      0    1     459    0      0      0     0
# 133      0   0      0    1     600    0      0      0     0
# 134      0   0      0    1      59    0      0      0     0
# 135      0   0      0    1    1390    0      0      0     0
# 136      0   0      0    1    1000    0      0      0     0
# 137      0   0      0    1     600    0      0      0     0
# 138      0   0      0    1      80    0      0      0     0
# 139      0   0      0    1      50    0      0      0     0
# 140      0   0      0    1     255    0      0      0     0
# 141      0   0      0    1     100    0      0      0     0
# 142      0   0      0    1     600    0      0      0     0
# 143      0   0      0    1     800    0      0      0     0
# 144      0   0      0    1     115    0      0      0     0
# 145      0   0      0    1     100    0      0      0     0
# 146      0   0      0    1     245    0      0      0     0
# 147      0   0      0    1     550    0      0      0     0
# 148      0   0      0    1    1850    0      0      0     0
# 149      0   0      0    1      30    0      0      0     0
# 150      0   0      1    0       0    0      0      0     0
# 151      0   0      0    1      75    0      0      0     0
# 152      0   0      0    1     359    0      0      0     0
# 153      0   0      0    1      50    0      0      0     0
# 154      0   0      0    1     325    0      0      0     0
# 155      0   0      0    1     225    0      0      0     0
# 156      0   0      0    1     560    0      0      0     0
# 157      0   0      1    0     199    0      0      0     0
# 158      0   0      0    1      20    0      0      0     0
# 159      0   0      0    1     390    0      0      0     0
# 160      0   0      0    1      60    0      0      0     0
# 161      0   0      0    1      95    0      0      0     0
# 162      0   0      0    1     450    0      0      0     0
# 163      0   0      1    0       0    0      0      0     0
# 164      0   0      0    1     600    0      0      0     0
# 165      0   0      0    1    1750    0      0      0     0
# 166      0   0      0    1     390    0      0      0     0
# 167      0   0      0    1     260    0      0      0     0
# 168      0   0      0    1     239    0      0      0     0
# 169      0   1      0    0       0    0      0      0     0
# 170      0   0      0    1     120    0      0      0     0
# 171      0   0      0    1     575    0      0      0     0
# 172      0   0      0    1     190    0      0      0     0
# 173      0   0      0    1     400    0      0      0     0
# 174      0   0      1    0       0    0      0      0     0
# 175      0   0      0    1      50    0      0      0     0
# 176      0   0      0    1      35    0      0      0     0
# 177      0   0      0    1      79    0      0      0     0
# 178      1   0      0    1     550    0      0      0     0
# 179      0   0      0    1    5444    0      0      0     0
# 180      0   0      0    1      45    0      0      0     0
# 181      0   0      0    1     400    0      0      0     0
# 182      0   0      0    1     139    0      0      0     0
# 183      0   0      0    1     150    0      0      0     0
# 184      0   1      0    0       0    0      0      0     0
# 185      0   0      0    1     300    0      0      0     0
# 186      0   1      1    0       0    0      0      0     0
# 187      0   0      0    1     490    0      0      0     0
# 188      0   0      0    1     185    0      0      0     0
# 189      0   0      0    1     220    0      0      0     0
# 190      0   0      0    1     949    0      0      0     0
# 191      0   0      0    1      50    0      0      0     0
# 192      0   0      0    1     225    0      0      0     0
# 193      0   1      0    0       0    0      0      0     0
# 194      0   0      0    1     790    0      0      0     0
# 195      0   0      0    1    1000    0      0      0     0
# 196      0   1      0    0       0    0      0      0     0
# 197      0   0      0    1     650    0      0      0     0
# 198      0   0      0    1    1450    0      0      0     0
# 199      0   0      0    1     300    0      0      1     0
# 200      0   0      0    1     130    0      0      0     0
# 201      0   0      0    1     465    0      0      0     0
# 202      0   0      0    1     200    0      0      0     0
# 203      0   0      0    1     399    0      0      0     0
# 204      0   0      0    1      90    0      0      0     0
# 205      0   0      0    1     179    0      0      0     0
# 206      0   0      0    1     250    0      0      0     0
# 207      0   0      0    1      50    0      0      0     0
# 208      0   0      0    1     300    0      0      0     0
# 209      0   0      0    1      75    0      0      0     0
# 210      0   0      0    1      59    0      0      0     0
# 211      0   0      0    1     580    0      0      0     0
# 212      0   1      0    0       0    0      0      0     0
# 213      0   0      0    1     290    0      0      0     0
# 214      0   0      0    1     899    0      0      0     0
# 215      0   0      0    1     390    0      0      0     0
# 216      0   0      0    1     600    0      0      0     0
# 217      0   0      0    1    1200    0      0      0     0
# 218      0   0      0    1     510    0      0      0     0
# 219      0   0      0    1     370    0      0      0     0
# 220      0   0      0    1     500    0      0      0     0
# 221      0   0      1    0     950    0      0      0     0
# 222      0   0      0    1      60    0      0      0     0
# 223      0   0      0    1     229    0      0      0     0
# 224      0   0      0    1     389    0      0      0     0
# 225      0   0      0    0       0    1      0      0     0
# 226      0   0      0    1     975    0      0      0     0
# 227      0   0      0    1    1050    0      0      0     0
# 228      0   0      0    1      55    0      0      0     0
# 229      0   0      0    1     100    0      0      0     0
# 230      0   0      0    1    4990    0      0      0     0
# 231      0   0      0    1     180    0      0      0     0
# 232      0   0      0    1     145    0      0      0     0
# 233      0   0      0    1      75    0      0      0     0
# 234      0   0      0    1    1700    0      0      0     0
# 235      0   0      0    1     170    0      0      0     0
# 236      0   0      0    1     205    0      0      0     0
# 237      0   0      0    1     325    0      0      0     0
# 238      0   0      0    1     345    0      0      0     0
# 239      0   0      0    1     400    0      0      0     0
# 240      0   0      0    1     260    0      0      0     0
# 241      0   0      0    1     350    0      0      0     0
# 242      0   0      0    1     360    0      0      0     0
# 243      0   0      0    1     350    0      0      0     0
# 244      0   0      0    1     120    0      0      0     0
# 245      0   0      0    1    3249    0      0      0     0
# 246      0   0      0    1     850    0      0      0     0
# 247      0   0      1    0       0    0      0      0     0
# 248      0   0      0    1     400    0      0      0     0
# 249      0   0      0    1     150    0      0      0     0
# 250      0   0      0    1     100    0      0      0     0
# 251      0   1      0    0       0    0      0      0     0
# 252      0   0      0    1     379    0      0      0     0
# 253      0   0      0    1      80    0      0      0     0
# 254      0   0      0    1    1550    0      0      0     0
# 255      0   0      0    1     420    0      0      0     0
# 256      0   0      0    1     420    0      0      0     0
# 257      0   0      0    1      20    0      0      0     0
# 258      0   0      0    1     250    0      0      0     0
# 259      0   0      0    1    1500    0      0      0     0
# 260      0   0      0    1     300    0      0      0     0
# 261      0   0      0    1     311    0      0      0     0
# 262      0   0      0    1     900    0      0      0     0
# 263      0   0      0    1     499    0      0      0     0
# 264      0   0      0    1     430    0      0      0     0
# 265      0   0      0    1     180    0      0      0     0
# 266      0   0      0    1     129    0      0      0     0
# 267      0   0      0    1      95    0      0      0     0
# 268      0   0      0    1     320    0      0      0     0
# 269      0   0      0    1     290    0      0      0     0
# 270      0   0      0    1     850    0      0      0     0
# 271      0   0      0    1      90    0      0      0     0
# 272      0   0      0    1     390    0      0      0     0
# 273      0   0      0    1     400    0      0      0     0
# 274      0   0      0    1     530    0      0      0     0
# 275      0   0      0    1      30    0      0      0     0
# 276      0   0      0    1     545    0      0      0     0
# 277      0   0      0    1    1990    0      0      0     0
# 278      0   0      0    1      40    0      0      0     0
# 279      0   0      0    1    1300    0      0      0     0
# 280      0   0      0    1     650    0      0      0     0
# 281      0   0      0    1     130    0      0      0     0
# 282      1   0      0    1      20    0      0      0     0
# 283      0   0      0    1     320    0      0      0     0
# 284      0   0      0    1      69    0      0      0     0
# 285      0   0      0    1      25    0      0      0     0
# 286      0   0      0    1     650    0      0      0     0
# 287      0   0      0    1     204    0      0      0     0
# 288      0   0      0    1      79    0      0      0     0
# 289      0   0      0    1       1    0      0      0     0
# 290      0   0      0    1     350    0      0      0     0
# 291      0   0      0    1     200    0      0      0     0
# 292      0   0      0    1     115    0      0      0     0
# 293      0   0      0    1     179    0      0      0     0
# 294      0   0      0    1     150    0      0      0     0
# 295      0   0      0    1     145    0      0      0     0
# 296      0   0      0    1     800    0      0      0     0
# 297      0   0      0    1     480    0      0      0     0
# 298      0   1      0    0       0    0      0      0     0
# 299      0   0      0    1      10    0      0      0     0
# 300      0   0      0    1     380    0      0      0     0
# 301      0   0      0    1     350    0      0      0     0
# 302      0   0      0    1    1750    0      0      0     0
# 303      0   1      0    0       0    0      0      0     0
# 304      0   0      0    1     600    0      0      0     0
# 305      0   0      0    1     899    0      0      0     0
# 306      0   0      0    1     700    0      0      0     0
# 307      0   0      0    1     650    0      0      0     0
# 308      0   0      0    1      49    0      0      0     0
# 309      0   0      0    1    1450    0      0      0     0
# 310      0   0      0    1      60    0      0      0     0
# 311      0   0      0    1     490    0      0      0     0
# 312      0   0      0    1      50    0      0      0     0
# 313      0   0      0    1    2950    0      0      0     0
# 314      0   0      0    1     100    0      0      0     0
# 315      0   0      0    1     550    0      0      0     0
# 316      0   0      0    1      80    0      0      0     0
# 317      0   0      0    1     399    0      0      0     0
# 318      0   0      0    1     110    0      0      0     0
# 319      0   0      0    1     300    0      0      0     0
# 320      0   0      0    1    2500    0      0      0     0
# 321      0   0      0    1    2500    0      0      0     0
# 322      1   0      0    1      70    0      0      0     0
# 323      0   0      0    1     160    0      0      0     0
# 324      0   0      0    1     195    0      0      0     0
# 325      0   0      0    1      38    0      0      0     0
# 326      0   0      0    1    5500    0      0      0     0
# 327      0   0      0    1      60    0      0      0     0
# 328      0   1      0    0       0    0      0      0     0
# 329      0   0      0    1     519    0      0      0     0
# 330      0   0      0    1     100    0      0      0     0
# 331      0   0      0    1     160    0      0      0     0
# 332      0   0      0    1     825    0      0      0     0
# 333      0   0      0    1     750    0      0      0     0
# 334      0   0      0    1     650    0      0      0     0
# 335      0   0      0    1     135    0      0      0     0
# 336      0   0      0    1     200    0      0      0     0
# 337      0   0      0    1    1290    0      0      0     0
# 338      0   0      0    1     399    0      0      0     0
# 339      0   0      0    1      40    0      0      0     0
# 340      0   0      0    1     450    0      0      0     0
# 341      0   0      0    1     300    0      0      0     0
# 342      0   0      0    1     550    0      0      0     0
# 343      0   0      0    1    1690    0      0      0     0
# 344      0   0      0    1     150    0      0      0     0
# 345      0   0      0    1      60    0      0      0     0
# 346      0   0      0    1    1400    0      0      0     0
# 347      0   0      0    1     180    0      0      0     0
# 348      0   0      0    1     240    0      0      0     0
# 349      0   0      0    1     100    0      0      0     0
# 350      0   0      0    1     199    0      0      0     0
# 351      0   0      0    1     195    0      0      0     0
# 352      0   0      0    1    1600    0      0      0     0
# 353      0   0      0    1     315    0      0      0     0
# 354      0   0      0    1     950    0      0      0     0
# 355      0   0      0    1     625    0      0      0     0
# 356      0   0      0    1     265    0      0      0     0
# 357      0   0      0    1     600    0      0      0     0
# 358      0   0      0    1     300    0      0      0     0
# 359      0   0      0    1    2650    0      0      0     0
# 360      0   0      0    1     390    0      0      0     0
# 361      0   0      0    1     220    0      0      0     0
# 362      0   0      0    1     240    0      0      0     0
# 363      0   0      0    1     139    0      0      0     0
# 364      0   0      0    1      53    0      0      0     0
# 365      0   0      0    1     350    0      0      0     0
# 366      0   0      0    1     300    0      0      0     0
# 367      0   0      0    1     144    0      0      0     0
# 368      0   0      0    1     135    0      0      0     0
# 369      0   0      0    1      20    0      0      0     0
# 370      0   0      0    1     300    0      0      0     0
# 371      0   0      0    1     110    0      0      0     0
# 372      0   1      0    0       0    0      0      0     0
# 373      0   0      0    1     350    0      0      0     0
# 374      0   0      0    1      95    0      0      0     0
# 375      0   0      0    1      90    0      0      0     0
# 376      0   0      0    1    4500    0      0      0     0
# 377      0   0      0    1     200    0      0      0     0
# 378      0   0      0    1    1750    0      0      0     0
# 379      0   0      0    1     320    0      0      0     0
# 380      0   0      0    1     169    0      0      0     0
# 381      0   0      0    1     149    0      0      0     0
# 382      0   0      1    0       0    0      0      0     0
# 383      0   0      0    1      55    0      0      0     0
# 384      0   0      0    1    5300    0      0      0     0
# 385      0   0      0    1      25    0      0      0     0
# 386      0   0      0    1     200    0      0      0     0
# 387      0   0      0    1     285    0      0      0     0
# 388      0   0      0    1     125    0      0      0     0
# 389      0   0      0    1    1050    0      0      0     0
# 390      0   0      0    1     110    0      0      0     0
# 391      0   0      0    1     950    0      0      0     0
# 392      0   0      0    1    1950    0      0      0     0
# 393      0   0      0    1     190    0      0      0     0
# 394      0   0      0    1    1200    0      0      0     0
# 395      0   0      0    1     600    0      0      0     0
# 396      0   0      0    1     200    0      0      0     0
# 397      0   0      0    1     239    0      0      0     0
# 398      0   0      0    1     420    0      0      0     0
# 399      0   0      0    1     300    0      0      1     1
# 400      0   0      0    1    1260    0      0      0     0
# 401      0   0      0    1     180    0      0      1     0
# 402      0   0      0    1     275    0      0      0     0
# 403      0   0      0    1     360    0      0      0     0
# 404      0   0      0    1     700    0      0      0     0
# 405      0   0      0    1     450    0      0      0     0
# 406      0   0      0    1    3500    0      0      0     0
# 407      0   0      0    1     150    0      0      0     0
# 408      0   0      0    1     260    0      0      0     0
# 409      0   0      0    1     300    0      0      0     0
# 410      0   0      0    1      35    0      0      0     0
# 411      0   0      0    1     450    0      0      0     0
# 412      0   0      0    1     200    0      0      0     0
# 413      0   1      0    0       0    0      0      0     0
# 414      0   0      0    1     105    0      0      0     0
# 415      0   0      0    1      40    0      0      0     0
# 416      0   0      0    1     200    0      0      0     0
# 417      0   0      0    1     329    0      0      0     0
# 418      0   0      0    1     800    0      0      0     0
# 419      0   1      0    0       0    0      0      0     0
# 420      0   0      0    1      90    0      0      0     0
# 421      0   0      0    1     485    0      0      0     0
# 422      0   0      0    1     500    0      0      0     0
# 423      0   0      0    1      59    0      0      0     0
# 424      0   0      0    1     100    0      0      0     0
# 425      0   0      0    1     190    0      0      0     0
# 426      0   0      0    1     120    0      0      0     0
# 427      0   0      0    1     219    0      0      0     0
# 428      0   0      0    1      20    0      0      0     0
# 429      0   0      0    1    1800    0      0      0     0
# 430      0   0      0    1     260    0      0      0     0
# 431      0   0      0    1     375    0      0      0     0
# 432      0   0      0    1      80    0      0      0     0
# 433      0   0      0    1     220    0      0      0     0
# 434      0   1      0    0       0    0      0      0     0
# 435      0   0      0    1     590    0      0      0     0
# 436      0   1      1    0       0    0      0      0     0
# 437      0   0      0    1    3750    0      0      0     0
# 438      0   0      0    1     150    0      0      0     0
# 439      0   0      0    1    2250    0      0      0     0
# 440      0   0      0    1    1450    0      0      0     0
# 441      0   0      0    1     345    0      0      0     0
# 442      0   0      0    1     189    0      0      0     0
# 443      0   0      0    1    1500    0      0      0     0
# 444      0   0      0    1     400    0      0      0     0
# 445      0   0      0    1    1430    0      0      0     0
# 446      0   1      0    0       0    0      0      0     0
# 447      0   0      0    1     500    0      0      0     0
# 448      0   0      0    1     104    0      0      0     0
# 449      0   0      0    1    3990    0      0      0     0
# 450      0   0      0    1     200    0      0      0     0
# 451      0   0      0    1     125    0      0      0     0
# 452      0   0      0    1     800    0      0      0     0
# 453      0   0      0    1     220    0      0      0     0
# 454      0   0      0    1    1469    0      0      0     0
# 455      0   1      0    0       0    0      0      0     0
# 456      0   0      1    0       0    0      0      0     0
# 457      0   0      0    1    1679    0      0      0     0
# 458      0   0      0    1     900    0      0      0     0
# 459      0   0      1    0     500    0      0      0     0
# 460      0   0      0    1     225    0      0      0     0
# 461      0   0      0    1    1150    0      0      0     0
# 462      0   0      0    1       1    0      0      0     0
# 463      0   0      0    1      50    0      0      0     0
# 464      0   0      0    1     259    0      0      0     0
# 465      0   0      0    1     800    0      0      0     0
# 466      0   0      0    1     140    0      0      0     0
# 467      0   0      0    1     110    0      0      0     0
# 468      0   0      0    1      12    0      0      0     0
# 469      0   0      0    1     500    0      0      0     0
# 470      0   0      0    1     300    0      0      0     0
# 471      0   1      0    0       0    0      0      0     0
# 472      0   0      0    1      30    0      0      0     0
# 473      0   0      0    1     699    0      0      0     0
# 474      0   0      0    1     120    0      0      0     0
# 475      0   0      0    1     550    0      0      0     0
# 476      0   1      0    0       0    0      0      0     0
# 477      0   1      0    0       0    0      0      0     0
# 478      0   0      0    1     150    0      0      0     0
# 479      0   0      0    1     150    0      0      0     0
# 480      0   0      0    1     450    0      0      0     0
# 481      0   0      0    1    6000    0      0      0     0
# 482      0   0      0    1     850    0      0      0     0
# 483      0   0      0    1    2500    0      0      0     0
# 484      0   0      0    1     150    0      0      0     0
# 485      0   0      0    1    1390    0      0      0     0
# 486      0   0      0    1    3200    0      0      0     0
# 487      0   0      0    1     600    0      0      0     0
# 488      0   0      0    1     190    0      0      0     0
# 489      0   0      0    1     900    0      0      0     0
# 490      0   0      0    1      45    0      0      0     0
# 491      0   0      0    1     700    0      0      0     0
# 492      0   0      0    1     950    0      0      0     0
# 493      0   0      1    0     500    0      0      0     0
# 494      0   0      0    1      90    0      0      0     0
# 495      0   0      0    1     339    0      0      0     0
# 496      0   0      0    1     200    0      0      0     0
# 497      0   0      1    0       0    0      1      0     0
# 498      0   0      0    1    2000    0      0      0     0
# 499      0   0      0    1    2200    0      0      0     0
# 500      0   0      0    1      20    0      0      0     0
# 501      0   0      0    1      60    0      0      0     0
# 502      0   0      0    1     390    0      0      0     0
# 503      0   0      0    1      22    0      0      0     0
# 504      0   0      0    1    2300    0      0      0     0
# 505      0   0      0    1       1    0      0      0     0
# 506      0   0      0    1      95    0      0      0     0
# 507      0   0      0    1     950    0      0      0     0
# 508      0   0      0    1     389    0      0      0     0
# 509      0   0      0    1     220    0      0      0     0
# 510      0   0      0    1     349    0      0      0     0
# 511      0   0      0    1     570    0      0      0     0
# 512      0   0      0    1      49    0      0      0     0
# 513      0   0      0    1     150    0      0      0     0
# 514      0   0      0    1     128    0      0      0     0
# 515      0   0      0    1     235    0      0      0     0
# 516      0   0      0    1     150    0      0      0     0
# 517      0   0      0    1       4    0      0      0     0
# 518      0   0      0    1     479    0      0      0     0
# 519      0   0      0    1     199    0      0      0     0
# 520      0   0      0    1     295    0      0      0     0
# 521      0   0      0    1      20    0      0      0     0
# 522      0   0      0    1     530    0      0      0     0
# 523      0   0      0    1      80    0      0      0     0
# 524      1   0      0    1     300    0      0      0     0
# 525      0   0      0    1     300    0      0      0     0
# 526      0   0      1    0       0    0      0      0     0
# 527      0   0      0    1    1050    0      0      0     0
# 528      0   0      0    1     330    0      0      0     0
# 529      0   0      0    1    1300    0      0      0     0
# 530      0   0      0    1   12000    0      0      0     0
# 531      0   0      0    1     249    0      0      0     0
# 532      0   0      0    1      98    0      0      0     0
# 533      0   0      0    1     495    0      0      0     0
# 534      0   0      0    1    5500    0      0      0     0
# 535      0   0      0    1    1550    0      0      0     0
# 536      0   0      0    1      90    0      0      0     0
# 537      0   0      0    1      90    0      0      0     0
# 538      0   0      0    1      75    0      0      0     0
# 539      0   0      0    1     333    0      0      0     0
# 540      0   0      0    1     375    0      0      0     0
# 541      0   0      0    1     779    0      0      0     0
# 542      0   1      0    0       0    0      0      0     0
# 543      0   0      0    1      85    0      0      0     0
# 544      0   0      0    1     190    0      0      0     0
# 545      0   0      0    1     250    0      0      0     0
# 546      0   0      0    1    1850    0      0      0     0
# 547      0   0      0    1     375    0      0      0     0
# 548      0   0      0    1     179    0      0      0     0
# 549      0   0      0    1    1350    0      0      0     0
# 550      0   0      0    1     180    0      0      0     0
# 551      0   0      0    1      80    0      0      0     0
# 552      0   0      0    1     860    0      0      0     0
# 553      0   0      0    1     450    0      0      0     0
# 554      0   0      0    1     550    0      0      0     0
# 555      0   0      0    1      50    0      0      0     0
# 556      0   0      0    1     300    0      0      0     0
# 557      0   0      0    1     270    0      0      0     0
# 558      0   0      0    1      35    0      0      0     0
# 559      1   0      0    1     550    0      0      0     0
# 560      0   0      0    1     175    0      0      0     0
# 561      0   0      0    1     125    0      0      0     0
# 562      0   0      0    1     230    0      0      0     0
# 563      0   1      1    0       0    0      0      0     0
# 564      0   0      0    1     430    0      0      0     0
# 565      0   0      0    1     550    0      0      0     0
# 566      0   0      0    1      20    0      0      0     0
# 567      0   0      0    1    4500    0      0      0     0
# 568      0   0      0    1      75    0      0      0     0
# 569      0   0      0    1    2900    0      0      0     0
# 570      0   0      0    1     700    0      0      0     0
# 571      0   0      0    1      60    0      0      0     0
# 572      0   0      1    0       0    0      0      0     0
# 573      0   0      0    1      90    0      0      0     0
# 574      0   0      0    1     300    0      0      0     0
# 575      0   0      0    1    1150    0      0      0     0
# 576      0   0      0    1     400    0      0      0     0
# 577      0   0      0    1      50    0      0      0     0
# 578      0   0      0    1     460    0      0      0     0
# 579      0   0      0    1     500    0      0      0     0
# 580      0   0      0    1     100    0      0      0     0
# 581      0   0      0    1     900    0      0      0     0
# 582      0   0      0    1      90    0      0      0     0
# 583      0   0      0    1     100    0      0      0     0
# 584      0   0      0    1    4250    0      0      0     0
# 585      0   0      0    1     110    0      0      0     0
# 586      0   0      0    1     100    0      0      0     0
# 587      0   0      0    1     240    0      0      0     0
# 588      0   0      1    0       0    0      0      0     0
# 589      0   0      0    1     135    0      0      0     0
# 590      0   0      0    1     100    0      0      0     0
# 591      0   0      0    1    5100    0      0      0     0
# 592      0   1      0    0       0    0      0      0     0
# 593      0   0      0    1    2300    0      0      0     0
# 594      0   0      0    1      10    0      0      0     0
# 595      0   0      0    1     250    0      0      0     0
# 596      0   0      0    1    1750    0      0      0     0
# 597      0   0      0    1     320    0      0      0     0
# 598      0   0      0    1    1500    0      0      0     0
# 599      0   0      0    1     400    0      0      0     0
# 600      0   0      0    1     675    0      0      0     0
# 601      0   0      0    1    6000    0      0      0     0
# 602      0   0      0    1    1890    0      0      0     0
# 603      0   0      0    1     375    0      0      0     0
# 604      0   0      0    1     115    0      0      0     0
# 605      0   0      0    1     300    0      0      0     0
# 606      0   0      0    1     410    0      0      0     0
# 607      0   0      0    1  111111    0      0      0     0
# 608      0   0      0    1    1100    0      0      0     0
# 609      0   0      0    1     180    0      0      0     0
# 610      0   0      0    1      40    0      0      0     0
# 611      0   0      0    1     140    0      0      0     0
# 612      0   0      0    1      80    0      0      0     0
# 613      0   0      0    1     600    0      0      0     0
# 614      0   0      0    1     500    0      0      0     0
# 615      0   0      0    1     330    0      0      0     0
# 616      0   0      0    1     300    0      0      0     0
# 617      0   0      0    1      50    0      0      0     0
# 618      0   0      0    1     825    0      0      0     0
# 619      0   0      0    1      59    0      0      0     0
# 620      0   0      0    1    1969    0      0      0     0
# 621      0   0      0    1    1250    0      0      0     0
# 622      0   0      0    1      15    0      0      0     0
# 623      0   0      0    1     180    0      0      0     0
# 624      0   0      0    1     800    0      0      0     0
# 625      0   0      0    1     280    0      0      0     0
# 626      0   0      0    1     145    0      0      0     0
# 627      0   0      0    1     480    0      0      0     0
# 628      0   0      0    1     900    0      0      0     0
# 629      1   0      0    1     600    0      0      0     0
# 630      0   0      0    1      25    0      0      0     0
# 631      0   0      0    1     255    0      0      0     0
# 632      0   1      0    0       0    0      0      0     0
# 633      0   0      0    1     840    0      0      0     0
# 634      0   0      0    1     349    0      0      0     0
# 635      0   0      0    1      90    0      0      0     0
# 636      0   0      0    1     225    0      0      0     0
# 637      0   0      0    1     165    0      0      0     0
# 638      0   0      0    1     700    0      0      0     0
# 639      0   0      0    1     550    0      0      0     0
# 640      0   0      0    1       0    0      0      0     0
# 641      0   0      0    1      95    0      0      0     0
# 642      0   0      0    1     400    0      0      0     0
# 643      0   0      0    1    1169    0      0      0     0
# 644      0   0      0    1     245    0      0      0     0
# 645      0   0      0    1     150    0      0      0     0
# 646      0   1      0    0       0    0      0      0     0
# 647      0   0      0    1      12    0      0      0     0
# 648      0   0      0    1     220    0      0      0     0
# 649      0   0      0    1      65    0      0      0     0
# 650      0   0      0    1     200    0      0      0     0
# 651      0   0      0    1     110    0      0      0     0
# 652      0   0      0    1    1600    0      0      0     0
# 653      0   0      0    1     580    0      0      0     0
# 654      0   1      0    0       0    0      0      0     0
# 655      0   0      0    1     550    0      0      0     0
# 656      0   0      0    1      35    0      0      0     0
# 657      1   1      0    0       0    0      0      0     0
# 658      0   0      0    1     200    0      0      0     0
# 659      0   1      0    0       0    0      0      0     0
# 660      0   0      0    1     489    0      0      0     0
# 661      0   0      0    1      60    0      0      0     0
# 662      0   0      0    1    6000    0      0      0     0
# 663      0   0      0    1     169    0      0      0     0
# 664      0   0      0    1     250    0      0      0     0
# 665      0   0      0    1      90    0      0      0     0
# 666      0   0      0    1      89    0      0      0     0
# 667      0   0      0    1     160    0      0      0     0
# 668      0   0      0    1      70    0      0      0     0
# 669      0   0      0    1    2099    0      0      0     0
# 670      0   0      0    1     200    0      0      0     0
# 671      0   0      0    1     160    0      0      0     0
# 672      0   0      0    1      19    0      0      0     0
# 673      0   0      0    1    1100    0      0      0     0
# 674      0   0      0    1     750    0      0      0     0
# 675      0   0      0    1    1500    0      0      0     0
# 676      0   0      0    1     500    0      0      0     0
# 677      0   0      0    1     600    0      0      0     0
# 678      0   0      0    1     349    0      0      0     0
# 679      0   0      0    1     925    0      0      0     0
# 680      0   0      0    1     460    0      0      0     0
# 681      0   0      0    1     245    0      0      0     0
# 682      0   0      0    1     150    0      0      0     0
# 683      0   0      0    1     670    0      0      0     0
# 684      0   0      0    1     130    0      0      0     0
# 685      0   0      0    1      25    0      0      0     0
# 686      0   0      0    1      60    0      0      0     0
# 687      0   0      0    1     350    0      0      0     0
# 688      0   0      0    1     175    0      0      0     0
# 689      0   0      0    1     300    0      0      0     0
# 690      0   0      0    1     880    0      0      0     0
# 691      0   0      0    1     110    0      0      0     0
# 692      0   0      0    1     150    0      0      0     0
# 693      0   0      0    1    1100    0      0      0     0
# 694      0   0      0    1     200    0      0      0     0
# 695      0   0      0    1     399    0      0      0     0
# 696      0   0      0    1      70    0      0      0     0
# 697      0   0      0    1     195    0      0      0     0
# 698      0   0      0    1      60    0      0      0     0
# 699      0   0      0    1     239    0      0      0     0
# 700      0   0      0    1    1800    0      0      0     0
# 701      0   0      0    1     329    0      0      0     0
# 702      1   0      0    1     850    0      0      0     0
# 703      0   0      1    0       0    0      0      0     0
# 704      0   0      0    1     299    0      0      0     0
# 705      0   0      0    1    1200    0      0      0     0
# 706      0   0      0    1     220    0      0      0     0
# 707      0   0      0    1     150    0      0      0     0
# 708      0   0      0    1      65    0      0      0     0
# 709      0   0      0    1    1650    0      0      0     0
# 710      0   0      0    1      60    0      0      0     0
# 711      0   0      0    1      99    0      0      0     0
# 712      0   0      0    1     150    0      0      0     0
# 713      0   0      0    1      90    0      0      0     0
# 714      0   0      0    1     475    0      0      0     0
# 715      0   0      0    1     390    0      0      0     0
# 716      0   0      0    1     200    0      0      0     0
# 717      0   0      0    1     850    0      0      0     0
# 718      0   0      0    1     309    0      0      0     0
# 719      0   0      0    1    1900    0      0      0     0
# 720      0   0      0    1     370    0      0      0     0
# 721      0   1      0    0       0    0      0      0     0
# 722      0   0      0    1     500    0      0      0     0
# 723      0   0      0    1      49    0      0      0     0
# 724      0   0      0    1     180    0      0      0     0
# 725      0   0      0    0      12    1      0      0     0
# 726      0   0      0    1    1800    0      0      0     0
# 727      0   0      0    1      20    0      0      0     0
# 728      0   0      0    1    1400    0      0      0     0
# 729      0   0      0    1    1450    0      0      0     0
# 730      0   0      0    1      75    0      0      0     0
# 731      0   0      0    1     330    0      0      0     0
# 732      0   0      0    1     329    0      0      0     0
# 733      0   0      0    1     110    0      0      0     0
# 734      0   0      0    1      75    0      0      0     0
# 735      0   0      0    1    1250    0      0      0     0
# 736      0   0      0    1      65    0      0      0     0
# 737      0   0      0    1    1800    0      0      0     0
# 738      0   0      0    1     320    0      0      0     0
# 739      0   0      0    1     299    0      0      0     0
# 740      0   0      0    1     485    0      0      0     0
# 741      0   0      0    1      24    0      0      0     0
# 742      0   0      0    1    1850    0      0      0     0
# 743      0   0      0    1     200    0      0      0     0
# 744      0   0      0    1     530    0      0      0     0
# 745      0   0      0    1     300    0      0      0     0
# 746      0   0      0    1     450    0      0      0     0
# 747      0   0      0    1      99    0      0      0     0
# 748      0   0      0    1      85    0      0      0     0
# 749      0   0      0    1     450    0      0      0     0
# 750      0   0      0    1     750    0      0      0     0
# 751      0   0      0    1      75    0      0      0     0
# 752      0   0      0    1     550    0      0      0     0
# 753      0   0      0    1    1200    0      0      0     0
# 754      0   0      0    1    4000    0      0      0     0
# 755      0   0      0    1     389    0      0      0     0
# 756      0   0      0    1      70    0      0      0     0
# 757      0   0      1    0     400    0      0      0     0
# 758      0   0      0    1     198    0      0      0     0
# 759      0   0      0    1    3200    0      0      0     0
# 760      0   0      0    1      50    0      0      0     0
# ...
# 214      1/9/2022    823
# 215      1/9/2022    432
# 216      1/9/2022    222
# 217      1/9/2022    322
# 218      1/9/2022    178
# 219      1/9/2022    134
# 220      1/9/2022   1295
# 221      1/9/2022    261
# 222      1/9/2022    268
# 223      1/9/2022   1053
# 224      1/9/2022   2000
# 225      1/9/2022    290
# 226      1/9/2022    376
# 227      1/9/2022    552
# 228      1/9/2022     99
# 229      1/9/2022   2518
# 230      1/9/2022    380
# 231      1/9/2022    300
# 232      1/9/2022    432
# 233      1/9/2022    482
# 234      1/9/2022   1391
# 235      1/9/2022    940
# 236      1/9/2022    416
# 237      1/9/2022   1358
# 238      1/9/2022    408
# 239      1/9/2022    134
# 240      1/9/2022   1034
# 241      1/9/2022    530
# 242      1/9/2022    834
# 243      1/9/2022    242
# 244      1/9/2022    228
# 245      1/9/2022   3817
# 246      1/9/2022    257
# 247      1/9/2022    170
# 248      1/9/2022    244
# 249      1/9/2022    204
# 250      1/9/2022    631
# 251      1/9/2022    180
# 252      1/9/2022   1020
# 253      1/9/2022    263
# 254      1/9/2022   1489
# 255      1/9/2022    222
# 256      1/9/2022    558
# 257      1/9/2022    342
# 258      1/9/2022    124
# 259      1/9/2022   3366
# 260      1/9/2022    376
# 261      1/9/2022    402
# 262      1/9/2022    404
# 263      1/9/2022    456
# 264      1/9/2022    463
# 265      1/9/2022    192
# 266      1/9/2022    456
# 267      1/9/2022    362
# 268      1/9/2022    102
# 269      1/9/2022    834
# 270      1/9/2022    172
# 271      1/9/2022    290
# 272      1/9/2022    136
# 273      1/9/2022    134
# 274      1/9/2022    308
# 275      1/9/2022    565
# 276      1/9/2022    938
# 277      1/9/2022   1073
# 278      1/9/2022     92
# 279      1/9/2022   1141
# 280      1/9/2022    224
# 281      1/9/2022    370
# 282      1/9/2022    215
# 283      1/9/2022    474
# 284      1/9/2022    415
# 285      1/9/2022    352
# 286      1/9/2022    194
# 287      1/9/2022    465
# 288      1/9/2022    347
# 289      1/9/2022    593
# 290      1/9/2022    822
# 291      1/9/2022    204
# 292      1/9/2022    387
# 293      1/9/2022    419
# 294      1/9/2022    360
# 295      1/9/2022    402
# 296      1/9/2022    206
# 297      1/9/2022    256
# 298      1/9/2022    142
# 299      1/9/2022    316
# 300      1/9/2022    859
# 301      1/9/2022    362
# 302      1/9/2022   1462
# 303      1/9/2022    172
# 304      1/9/2022    406
# 305      1/9/2022   1494
# 306      1/9/2022    320
# 307      1/9/2022    273
# 308      1/9/2022     52
# 309      1/9/2022    144
# 310      1/9/2022    136
# 311      1/9/2022    282
# 312      1/9/2022    402
# 313      1/9/2022    304
# 314      1/9/2022   1176
# 315      1/9/2022    688
# 316      1/9/2022    112
# 317      1/9/2022   1948
# 318      1/9/2022    717
# 319      1/9/2022    184
# 320      1/9/2022    473
# 321      1/9/2022    175
# 322      1/9/2022    274
# 323      1/9/2022    201
# 324      1/9/2022    122
# 325      1/9/2022    114
# 326      1/9/2022    676
# 327      1/9/2022    552
# 328      1/9/2022     92
# 329      1/9/2022    636
# 330      1/9/2022    148
# 331      1/9/2022    504
# 332      1/9/2022   6471
# 333      1/9/2022    409
# 334      1/9/2022    206
# 335      1/9/2022    505
# 336      1/9/2022    599
# 337      1/9/2022    585
# 338      1/9/2022    312
# 339      1/9/2022    104
# 340      1/9/2022   2274
# 341      1/9/2022    197
# 342      1/9/2022    120
# 343      1/9/2022   1280
# 344      1/9/2022    440
# 345      1/9/2022    284
# 346      1/9/2022    670
# 347      1/9/2022    285
# 348      1/9/2022    270
# 349      1/9/2022    872
# 350      1/9/2022    533
# 351      1/9/2022    376
# 352      1/9/2022    600
# 353      1/9/2022    310
# 354      1/9/2022   4735
# 355      1/9/2022   3471
# 356      1/9/2022    914
# 357      1/9/2022    758
# 358      1/9/2022    167
# 359      1/9/2022    532
# 360      1/9/2022    398
# 361      1/9/2022    319
# 362      1/9/2022    234
# 363      1/9/2022    619
# 364      1/9/2022    330
# 365      1/9/2022    379
# 366      1/9/2022    126
# 367      1/9/2022    433
# 368      1/9/2022    246
# 369      1/9/2022   1446
# 370      1/9/2022    512
# 371      1/9/2022    760
# 372      1/9/2022    194
# 373      1/9/2022    116
# 374      1/9/2022    166
# 375      1/9/2022    607
# 376      1/9/2022    984
# 377      1/9/2022   1698
# 378      1/9/2022    382
# 379      1/9/2022    792
# 380      1/9/2022    322
# 381      1/9/2022    435
# 382      1/9/2022    512
# 383      1/9/2022   1092
# 384      1/9/2022   4574
# 385      1/9/2022   2126
# 386      1/9/2022     86
# 387      1/9/2022   1814
# 388      1/9/2022    499
# 389      1/9/2022    306
# 390      1/9/2022   1055
# 391      1/9/2022    472
# 392      1/9/2022    178
# 393      1/9/2022    154
# 394      1/9/2022    138
# 395      1/9/2022    493
# 396      1/9/2022    330
# 397      1/9/2022    946
# 398      1/9/2022     58
# 399      1/9/2022   1006
# 400      1/9/2022    236
# 401      1/9/2022    598
# 402      1/9/2022    396
# 403      1/9/2022    302
# 404      1/9/2022    415
# 405      1/9/2022    724
# 406      1/9/2022    266
# 407      1/9/2022     84
# 408      1/9/2022   1266
# 409      1/9/2022    222
# 410      1/9/2022    939
# 411      1/9/2022    296
# 412      1/9/2022    333
# 413      1/9/2022    224
# 414      1/9/2022    425
# 415      1/9/2022    419
# 416      1/9/2022    653
# 417      1/9/2022    433
# 418      1/9/2022    226
# 419      1/9/2022    192
# 420      1/9/2022    356
# 421      1/9/2022    166
# 422      1/9/2022   2116
# 423      1/9/2022    308
# 424      1/9/2022    547
# 425      1/9/2022    168
# 426      1/9/2022    596
# 427      1/9/2022    300
# 428      1/9/2022    185
# 429      1/9/2022   4331
# 430      1/9/2022    144
# 431      1/9/2022   1120
# 432      1/9/2022    315
# 433      1/9/2022    282
# 434      1/9/2022     88
# 435      1/9/2022    146
# 436      1/9/2022    687
# 437      1/9/2022    642
# 438      1/9/2022    176
# 439      1/9/2022    220
# 440      1/9/2022    840
# 441      1/9/2022    910
# 442      1/9/2022    474
# 443      1/9/2022   1583
# 444      1/9/2022    296
# 445      1/9/2022    944
# 446      1/9/2022    106
# 447      1/9/2022    596
# 448      1/9/2022    423
# 449      1/9/2022    596
# 450      1/9/2022   1319
# 451      1/9/2022   2098
# 452      1/9/2022    218
# 453      1/9/2022    260
# 454      1/9/2022    610
# 455      1/9/2022    152
# 456      1/9/2022    548
# 457      1/9/2022   1452
# 458      1/9/2022    774
# 459      1/9/2022    496
# 460      1/9/2022   1738
# 461      1/9/2022    408
# 462      1/9/2022    380
# 463      1/9/2022    116
# 464      1/9/2022    124
# 465      1/9/2022    368
# 466      1/9/2022    179
# 467      1/9/2022    719
# 468      1/9/2022   3396
# 469      1/9/2022    243
# 470      1/9/2022    745
# 471      1/9/2022    162
# 472      1/9/2022    324
# 473      1/9/2022   1792
# 474      1/9/2022    338
# 475      1/9/2022   3117
# 476      1/9/2022    190
# 477      1/9/2022    392
# 478      1/9/2022    352
# 479      1/9/2022     20
# 480      1/9/2022    120
# 481      1/9/2022   4242
# 482      1/9/2022    200
# 483      1/9/2022    110
# 484      1/9/2022   1078
# 485      1/9/2022    578
# 486      1/9/2022   3751
# 487      1/9/2022   2081
# 488      1/9/2022    819
# 489      1/9/2022    333
# 490      1/9/2022    291
# 491      1/9/2022    128
# 492      1/9/2022    692
# 493      1/9/2022   3965
# 494      1/9/2022    765
# 495      1/9/2022    516
# 496      1/9/2022    564
# 497      1/9/2022   2592
# 498      1/9/2022   1455
# 499      1/9/2022    340
# 500      1/9/2022    206
# 501      1/9/2022    416
# 502      1/9/2022   1286
# 503      1/9/2022    415
# 504      1/9/2022   3060
# 505      1/9/2022    138
# 506      1/9/2022    396
# 507      1/9/2022    214
# 508      1/9/2022    310
# 509      1/9/2022    861
# 510      1/9/2022    536
# 511      1/9/2022    967
# 512      1/9/2022   3990
# 513      1/9/2022    302
# 514      1/9/2022    615
# 515      1/9/2022    447
# 516      1/9/2022     38
# 517      1/9/2022   1541
# 518      1/9/2022    331
# 519      1/9/2022    260
# 520      1/9/2022    955
# 521      1/9/2022    208
# 522      1/9/2022    613
# 523      1/9/2022    148
# 524      1/9/2022    124
# 525      1/9/2022    205
# 526      1/9/2022    226
# 527      1/9/2022    360
# 528      1/9/2022    444
# 529      1/9/2022    150
# 530      1/9/2022   5720
# 531      1/9/2022    555
# 532      1/9/2022    324
# 533      1/9/2022    600
# 534      1/9/2022   1726
# 535      1/9/2022   2056
# 536      1/9/2022   2909
# 537      1/9/2022    414
# 538      1/9/2022   1129
# 539      1/9/2022    366
# 540      1/9/2022    446
# 541      1/9/2022    774
# 542      1/9/2022     70
# 543      1/9/2022    474
# 544      1/9/2022    110
# 545      1/9/2022   1143
# 546      1/9/2022    128
# 547      1/9/2022    940
# 548      1/9/2022    908
# 549      1/9/2022   1013
# 550      1/9/2022    202
# 551      1/9/2022    284
# 552      1/9/2022    314
# 553      1/9/2022    116
# 554      1/9/2022    759
# 555      1/9/2022   1444
# 556      1/9/2022    394
# 557      1/9/2022    388
# 558      1/9/2022    290
# 559      1/9/2022    804
# 560      1/9/2022     94
# 561      1/9/2022   1131
# 562      1/9/2022    577
# 563      1/9/2022    140
# 564      1/9/2022    466
# 565      1/9/2022    374
# 566      1/9/2022    204
# 567      1/9/2022    536
# 568      1/9/2022   2104
# 569      1/9/2022    604
# 570      1/9/2022    152
# 571      1/9/2022    538
# 572      1/9/2022    278
# 573      1/9/2022    494
# 574      1/9/2022    128
# 575      1/9/2022    488
# 576      1/9/2022   1668
# 577      1/9/2022     56
# 578      1/9/2022    276
# 579      1/9/2022    148
# 580      1/9/2022    323
# 581      1/9/2022    594
# 582      1/9/2022    100
# 583      1/9/2022    142
# 584      1/9/2022    944
# 585      1/9/2022    341
# 586      1/9/2022   1146
# 587      1/9/2022    184
# 588      1/9/2022   1381
# 589      1/9/2022    426
# 590      1/9/2022    607
# 591      1/9/2022   3027
# 592      1/9/2022    731
# 593      1/9/2022   2018
# 594      1/9/2022    334
# 595      1/9/2022     92
# 596      1/9/2022    466
# 597      1/9/2022    869
# 598      1/9/2022   1680
# 599      1/9/2022   1158
# 600      1/9/2022    438
# 601      1/9/2022    132
# 602      1/9/2022    696
# 603      1/9/2022   1047
# 604      1/9/2022    306
# 605      1/9/2022    262
# 606      1/9/2022    224
# 607      1/9/2022  20160
# 608      1/9/2022    402
# 609      1/9/2022    255
# 610      1/9/2022    218
# 611      1/9/2022    473
# 612      1/9/2022    306
# 613      1/9/2022    647
# 614      1/9/2022    202
# 615      1/9/2022   1112
# 616      1/9/2022    120
# 617      1/9/2022    192
# 618      1/9/2022   1912
# 619      1/9/2022    354
# 620      1/9/2022    524
# 621      1/9/2022     90
# 622      1/9/2022    974
# 623      1/9/2022    170
# 624      1/9/2022    481
# 625      1/9/2022   1845
# 626      1/9/2022   4528
# 627      1/9/2022    124
# 628      1/9/2022    302
# 629      1/9/2022    514
# 630      1/9/2022    214
# 631      1/9/2022   1295
# 632      1/9/2022   2430
# 633      1/9/2022   3737
# 634      1/9/2022    882
# 635      1/9/2022    340
# 636      1/9/2022   1177
# 637      1/9/2022    342
# 638      1/9/2022    119
# 639      1/9/2022    196
# 640      1/9/2022   5963
# 641      1/9/2022    406
# 642      1/9/2022     76
# 643      1/9/2022    838
# 644      1/9/2022    338
# 645      1/9/2022    402
# 646      1/9/2022     90
# 647      1/9/2022   1172
# 648      1/9/2022    419
# 649      1/9/2022    174
# 650      1/9/2022    600
# 651      1/9/2022    739
# 652      1/9/2022   2257
# 653      1/9/2022   1070
# 654      1/9/2022     76
# 655      1/9/2022    340
# 656      1/9/2022    705
# 657      1/9/2022    200
# 658      1/9/2022    775
# 659      1/9/2022    338
# 660      1/9/2022    870
# 661      1/9/2022     76
# 662      1/9/2022    977
# 663      1/9/2022    414
# 664      1/9/2022    686
# 665      1/9/2022    200
# 666      1/9/2022    732
# 667      1/9/2022    368
# 668      1/9/2022   3138
# 669      1/9/2022   2162
# 670      1/9/2022    516
# 671      1/9/2022    240
# 672      1/9/2022   2501
# 673      1/9/2022    848
# 674      1/9/2022    206
# 675      1/9/2022    749
# 676      1/9/2022    276
# 677      1/9/2022     80
# 678      1/9/2022   1004
# 679      1/9/2022    216
# 680      1/9/2022    120
# 681      1/9/2022    222
# 682      1/9/2022    865
# 683      1/9/2022    112
# 684      1/9/2022    711
# 685      1/9/2022    571
# 686      1/9/2022    199
# 687      1/9/2022    544
# 688      1/9/2022    320
# 689      1/9/2022    410
# 690      1/9/2022    560
# 691      1/9/2022    198
# 692      1/9/2022    151
# 693      1/9/2022   1034
# 694      1/9/2022   2848
# 695      1/9/2022    295
# 696      1/9/2022    150
# 697      1/9/2022    586
# 698      1/9/2022    132
# 699      1/9/2022    545
# 700      1/9/2022    266
# 701      1/9/2022    620
# 702      1/9/2022    450
# 703      1/9/2022    424
# 704      1/9/2022    114
# 705      1/9/2022   1550
# 706      1/9/2022    459
# 707      1/9/2022    788
# 708      1/9/2022    190
# 709      1/9/2022    817
# 710      1/9/2022    505
# 711      1/9/2022    345
# 712      1/9/2022    432
# 713      1/9/2022    241
# 714      1/9/2022    774
# 715      1/9/2022    170
# 716      1/9/2022     92
# 717      1/9/2022   1624
# 718      1/9/2022    533
# 719      1/9/2022    566
# 720      1/9/2022   1009
# 721      1/9/2022    369
# 722      1/9/2022    227
# 723      1/9/2022    711
# 724      1/9/2022     96
# 725      1/9/2022   1573
# 726      1/9/2022    220
# 727      1/9/2022    186
# 728      1/9/2022    530
# 729      1/9/2022    370
# 730      1/9/2022    390
# 731      1/9/2022    328
# 732      1/9/2022    540
# 733      1/9/2022    558
# 734      1/9/2022    870
# 735      1/9/2022   1756
# 736      1/9/2022    144
# 737      1/9/2022    322
# 738      1/9/2022    170
# 739      1/9/2022    244
# 740      1/9/2022   1209
# 741      1/9/2022   5597
# 742      1/9/2022   1371
# 743      1/9/2022    865
# 744      1/9/2022    146
# 745      1/9/2022    654
# 746      1/9/2022   1966
# 747      1/9/2022    583
# 748      1/9/2022    442
# 749      1/9/2022    578
# 750      1/9/2022   1219
# 751      1/9/2022    473
# 752      1/9/2022    296
# 753      1/9/2022    358
# 754      1/9/2022    256
# 755      1/9/2022    442
# 756      1/9/2022    423
# 757      1/9/2022   1529
# 758      1/9/2022    600
# 759      1/9/2022     76
# 760      1/9/2022    423
# 761      1/9/2022    748
# 762      1/9/2022    158
# 763      1/9/2022    679
# 764      1/9/2022    327
# 765      1/9/2022    765
# 766      1/9/2022    718
# 767      1/9/2022    212
# 768      1/9/2022    762
# 769      1/9/2022    802
# 770      1/9/2022    144
# 771      1/9/2022    104
# 772      1/9/2022   1058
# 773      1/9/2022    322
# 774      1/9/2022    220
# 775      1/9/2022    266
# 776      1/9/2022   4157
# 777      1/9/2022   1015
# 778      1/9/2022    272
# 779      1/9/2022   1696
# 780      1/9/2022    580
# 781      1/9/2022    754
# 782      1/9/2022    286
# 783      1/9/2022    207
# 784      1/9/2022    228
# 785      1/9/2022    474
# 786      1/9/2022     92
# 787      1/9/2022    504
# 788      1/9/2022  17048
# 789      1/9/2022    402
# 790      1/9/2022    678
# 791      1/9/2022   1954
# 792      1/9/2022   2332
# 793      1/9/2022   1534
# 794      1/9/2022    978
# 795      1/9/2022    218
# 796      1/9/2022    474
# 797      1/9/2022    958
# 798      1/9/2022   1308
# 799      1/9/2022    136
# 800      1/9/2022    366
# 801      1/9/2022     62
# 802      1/9/2022    422
# 803      1/9/2022     80
# 804      1/9/2022   1096
# 805      1/9/2022    968

# %% [markdown]
# ## 3.9 Clean the column of the publication dates.
#
#
# As we can see sometimes the format is correct and sometimes indicates moments related to the date we are on. so it has to be corrected.
#
# The solution is to create a function that reads that format and converts it to the correct date and format.
#
#
# For this we have to implement all the cases that can be given.

# %%
semanas = ['1 semana', '2 semanas', '3 semanas', '4 semanas']
dias = ['1 día', '2 días', '3 días', '4 días', '5 días', '6 días', '7 días']
horas = ['1 hora','2 horas', '3 horas', '4 horas', '5 horas', '6 horas',
        '7 horas','8 horas', '9 horas', '10 horas', '11 horas', '12 horas',
        '13 horas', '14 horas','15 horas', '16 horas', '17 horas', '18 horas',
        '19 horas', '20 horas', '21 horas', '22 horas','23 horas', '24 horas']

# %%
minutes=[]
for mint in range(1,61):
    if mint < 2:
        texto = str(mint) + ' minuto'
        minutes.append(texto)
    else:
        texto = str(mint) + ' minutos'
        minutes.append(texto)

# %% [markdown]
# - `nice_format` is the function that is responsible for identifying the time intervals that the web gives us and making a time conversion.

# %%
def nice_format(parameter):

    days_inweek = 7

    hoy = dt.datetime.now()
    year=str(hoy.year)

    month=str(hoy.month)
    day=str(hoy.day)

    date_scrapped = day + '/' + month + '/' + year
    
    current_datetime = dt.datetime.strptime(date_scrapped,"%d/%m/%Y") 
    
    
    if parameter in semanas:
        
        num_semana = parameter.split()
        num_semana = int(num_semana[0])
        cambio_semana = semanas[num_semana-1]
        
        dias_semana = (num_semana * days_inweek)
        
        
        fecha_real_semana = current_datetime - dt.timedelta(dias_semana)
        
        fecha_real_semana = fecha_real_semana.strftime("%d/%m/%Y")
        
                
        df['published'] = df['published'].replace( to_replace = cambio_semana, value = fecha_real_semana) #+ ' semana'
        
    elif parameter in dias:
        num_dia = parameter.split()
        num_dias = int(num_dia[0])
        cambio_dia = dias[num_dias-1]

        fecha_real_dia = current_datetime - dt.timedelta(num_dias)
        fecha_real_dia = fecha_real_dia.strftime("%d/%m/%Y")
        
        df['published'] = df['published'].replace( to_replace = cambio_dia, value = fecha_real_dia) #+ ' semana'
        
        
    elif parameter in horas:
        num_hora = parameter.split()
        num_hora = int(num_hora[0])
        
        if (parameter != '24 horas'):
            hora_real = current_datetime
            hora_real = hora_real.strftime("%d/%m/%Y")
            
            df['published'] = df['published'].replace(to_replace = parameter,
                                              value = hora_real)
        
        elif parameter == '24 horas':
            horas_24 = 1
            hora_real = current_datetime - dt.timedelta(horas_24)
            hora_real = hora_real.strftime("%d/%m/%Y")
            
            df['published'] = df['published'].replace( to_replace = parameter,value = hora_real ) #+ ' semana'
    
    
    elif parameter in minutes:
        horas_24 = 1
        hora_real = current_datetime - dt.timedelta(horas_24)
        hora_real = hora_real.strftime("%d/%m/%Y")
            
        df['published'] = df['published'].replace( to_replace = parameter,value = hora_real ) #+ ' semana'

# %%
df['published'].apply(nice_format)
print('')

# %% [markdown]
# ### 4. Anonimizing user names
#
# Although users in the forum use aliases, the most sensible thing is to create a function that anonymizes the name of the users

# %%
def anonimizer(value):
    variable = 0
    for letras in value:
        variable += int(ord(letras))
    return variable

# %%
df['anon_user'] = df['user'].apply(anonimizer)
print('')

# %%
df.drop("anon_user",axis ='columns')
print('')

# %% [markdown]
# ### Last step
#
# We already have all the data inside the dataframe now the only thing left to do is to save the content in a csv file

# %%
df.to_csv('df_hispa_1_09_2022.csv', index = True)
